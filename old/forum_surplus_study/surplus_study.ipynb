# %% [markdown]
# # Surplus Study  - Surplus/LVR Historic COW

# %% [markdown]
# **The purpose of this study is to measure the surplus for historic COW trades of a desired token pair.**
#
#
# **Definitions:**
# $X$ = reserves of token1
# $Y$ = reserves of token2
# $dx$ = trade quantity of token1 for a given trade  (Given by historic COW trade)
# $dy$ = trade quantity of token2 for a given trade (Given by historic COW trade)
# $dy_f$ = The calculated Feedlot price for a given dx
# $dx_f$ = The calculated Feedlot price for a given dy
# $Pfeedlot$ = internal price calculated based on reserves and cpmm formula for a given trade given by $dx_f / dy$
# $Pmarket$ = the COW trade execution price. Could also be called the $Pucp$ It is given by $dx / dy$
#
# **Surplus Calculations:**
#
# Surplus is defined by $(Pfeedlot - Pmarket) * quantity$
#
# There are two variables related to surplus used in the code: `surplus_price` and `surplus_volume` defined as:
#
#
# - `surplus_price`:
#     - $Surplusprice$ = $Pfeedlot - Pmarket$
#     - $Pfeedlot = dx_f / dy$ (or $dx/dy_f$ depending on which one is the sell token (input to pricing function))
#     - $Pmarket = dx / dy$
#
# - `surplus_volume`:
#     - $Surplusvolume = Surplusprice * dy$
#
#
# Convention: Define Surplus volume in terms of token1 (token x). Hence multiplying by $dy$ obtains surplus in terms of token $x$ (token1)
#
#
#
#
# **Methodology:**
# - Assume a Feedlot AMM with CPMM preferences that only trades COW orders. Given by $XY = K$
#     where:
#         $X$ = reserves of token1
#         $Y$ = reserves of token2
#         $K = X * Y$
#
# - Feedlot AMM trades at the COW settelement price (which is the solver price) if the trade offers satisfies the preferences (k_new > k_current) and retains any difference (surplus)
#
# - Given a dataset that represents the list of all trades that happened on COW Swap with value over USD 250 with first trade at timestamp $t_0$.
# - Model Inputs:
#     - `token1`: Token1 of token pair to be studied
#     - `Token2`: Token2 of token pair to be studied
#     - `token1_starting_reserves`: Starting reserves of the feedlot AMM pool.
#     - `fee_rate`: Fee rate charged to the trade
#
# - Initialize a feedlot AMM for token1 and token2, at $t_0$ with the price of the first trade at t0 of the COW dataset of token1 and token2, using the starting reserves given by the input (calculating token1_starting_reserves * price at $t_0$)
#
# - Loop through all trades and check at each trade if $Pfeedlot$ < $Pucp$. (in code it is given by `k_new > k`). If the price of feedlot was favourable then trade is executed on Feedlot AMM and new reserves are updated.

# %% [markdown]
# ### 1. Loading COW Dataset
#
# Copy the dataset file into the folder that contains this notebook.

# %%
from datastreams.datastream import Streamer

import matplotlib.pyplot as plt
import pandas as pd
import polars as pl

# These commands enlarge the column size of the dataframe so things like 0x... are not truncated
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %%
# instantiate Streamer class. Note that we need two separate streamer classes, otherwise the queries will be overwritten. 
cow_ds = Streamer('https://api.thegraph.com/subgraphs/name/cowprotocol/cow')

# %%
# DEFINE TIMESTAMP HERE. Minimum Timstamp is used for replication quality assurance purposes. Timestamp date: 
timestamp =  1646092800

# we set a fixed query size number. The Cow settlements and Uniswap swaps query are multiples larger than this initial query size.
query_size = 500000

#Filter size - We filter trades out that are smaller than $1000 USD size
filter_usd = 100

# %%
# query COW schema: trades
trades_fp = cow_ds.queryDict.get('trades')

# trades query path that gets token a -> token b trades. Query on query_size. 
trades_qp = trades_fp(
    first=query_size,
    orderBy='timestamp',
    orderDirection='desc',
    where = {
    'timestamp_gt': timestamp
    }
)

# run query
trades_df = cow_ds.runQuery(trades_qp)
# Out:
# FIELD - trades

# %%
#trades_df.to_csv('trades_df.csv', index=False)

# %%
#trades_df = pd.read_csv('trades_df.csv')

# %%
print(f'query returned {len(trades_df)} rows')
# Out:
# query returned 331802 rows

# %%
trades_df.head(5)
# Out:
#                                                                                                                                                                                    trades_id  trades_timestamp  trades_gasPrice  trades_feeAmount                                                       trades_txHash                                                trades_settlement_id  trades_buyAmount  trades_sellAmount                         trades_sellToken_id                          trades_buyToken_id                                                                                                     trades_order_id  trades_buyAmountEth  trades_sellAmountEth  trades_buyAmountUsd  trades_sellAmountUsd endpoint
# 0  0xa6f3d0560e61e77eace4e15ff44ff0743a4a48f28de85b9e31dd8aac1160c68c0582fc81f21686541623de723448c21e1e443522640ef9d0|0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942|145        1678697171      18901538318      5.774037e+19  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942      5.960373e+18       7.500040e+22  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xa6f3d0560e61e77eace4e15ff44ff0743a4a48f28de85b9e31dd8aac1160c68c0582fc81f21686541623de723448c21e1e443522640ef9d0             5.960373              0.000000          9638.606204              0.000000      cow
# 1  0x9fb2365e569b1c0d5a67ee6df4d2cfedcbd27e8428c85b9a689f7c9c827d81d85ac0210e0d6d03cbdf85511474f5f714d25ee183640ef9c2|0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942|145        1678697171      18901538318      4.110177e+18  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942      2.206228e+10       6.331736e+21  0xc0c293ce456ff0ed870add98a0828dd4d2903dbf  0xdac17f958d2ee523a2206206994597c13d831ec7  0x9fb2365e569b1c0d5a67ee6df4d2cfedcbd27e8428c85b9a689f7c9c827d81d85ac0210e0d6d03cbdf85511474f5f714d25ee183640ef9c2            13.642991             13.960649         22062.282427          22586.832422      cow
# 2  0x01677bcd2d56006fba89e82dc5d636000a33063e77740ab9726d39938642b980ecbaf5c200b290caa0ce63a098a34808ea8c46f7640ef97b|0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942|145        1678697171      18901538318      1.589782e+15  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942      8.439662e+15       1.003439e+16  0xae7ab96520de3a18e5e111b5eaab095312d7fe84  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0x01677bcd2d56006fba89e82dc5d636000a33063e77740ab9726d39938642b980ecbaf5c200b290caa0ce63a098a34808ea8c46f7640ef97b             0.008440              0.009981            13.647902             16.004119      cow
# 3   0xc39619df51e440d4deac17956afe5b18dec61d7b2b1f7bce28ebb1956314fb129fa6c303300ed23cefb0b1106ae898810dc01cc3640ee92e|0x6e872ab8fab8d5d7a5ba6314d09a3e58a1af2098f5c5d7337b5b3ffc0b3f1eed|46        1678697075      18059272064      3.883604e+06  0x6e872ab8fab8d5d7a5ba6314d09a3e58a1af2098f5c5d7337b5b3ffc0b3f1eed  0x6e872ab8fab8d5d7a5ba6314d09a3e58a1af2098f5c5d7337b5b3ffc0b3f1eed      4.275761e+20       1.195800e+09  0xdac17f958d2ee523a2206206994597c13d831ec7  0x03ab458634910aad20ef5f1c8ee96f1d6ac54919  0xc39619df51e440d4deac17956afe5b18dec61d7b2b1f7bce28ebb1956314fb129fa6c303300ed23cefb0b1106ae898810dc01cc3640ee92e             0.741334              0.739110          1208.206632           1195.800000      cow
# 4  0x13ad7e69413a0ac1c909fa302cd28716b56dfbbaff1737d9fa511a2d9034b1504179284c327b35ef08016f9112b8a4867207e79a640ee908|0x48f48d92be321b0f9d92c866c3e4517b59483dd9fae9368bb373dd5946281fdd|103        1678697039      15685415532      1.574740e+19  0x48f48d92be321b0f9d92c866c3e4517b59483dd9fae9368bb373dd5946281fdd  0x48f48d92be321b0f9d92c866c3e4517b59483dd9fae9368bb373dd5946281fdd      2.438391e+17       2.326906e+21  0xe60779cc1b2c1d0580611c526a8df0e3f870ec48  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0x13ad7e69413a0ac1c909fa302cd28716b56dfbbaff1737d9fa511a2d9034b1504179284c327b35ef08016f9112b8a4867207e79a640ee908             0.243839              0.000000           394.505522              0.000000      cow

# %%
# Set query size large enough to retrieve all tokens in the graph
query_size_token = 10000000

token_fp = cow_ds.queryDict.get('tokens')

# add parameters to the settlements_qp.
token_qp = token_fp(
    first=query_size_token,
)

# run query
token_df = cow_ds.runQuery(token_qp)
# Out:
# FIELD - tokens

# %%
# Merge1 on sell token address.  x = sell token 

merged_df = pd.merge(trades_df, token_df, left_on='trades_sellToken_id', right_on='tokens_address')

# %%
# Merge2 on buy token address.  y = buy token 
merged_df2 = pd.merge(merged_df, token_df, left_on='trades_buyToken_id', right_on='tokens_address')

# %%
df = merged_df2.rename(columns={
    "tokens_symbol_x": "sell_token_symbol",
    "tokens_symbol_y":"buy_token_symbol",
    "tokens_decimals_x": "sell_token_decimal", 
    "tokens_decimals_y": "buy_token_decimal"})

# %%
df.head(5)
# Out:
#                                                                                                                                                                                    trades_id  trades_timestamp  trades_gasPrice  trades_feeAmount                                                       trades_txHash                                                trades_settlement_id  trades_buyAmount  trades_sellAmount                         trades_sellToken_id                          trades_buyToken_id                                                                                                     trades_order_id  trades_buyAmountEth  trades_sellAmountEth  trades_buyAmountUsd  trades_sellAmountUsd endpoint_x                                 tokens_id_x                            tokens_address_x  tokens_firstTradeTimestamp_x              tokens_name_x sell_token_symbol  sell_token_decimal         tokens_totalVolume_x  tokens_priceEth_x  tokens_priceUsd_x  tokens_numberOfTrades_x  tokens_totalVolumeUsd_x  tokens_totalVolumeEth_x endpoint_y                                 tokens_id_y                            tokens_address_y  tokens_firstTradeTimestamp_y tokens_name_y buy_token_symbol  buy_token_decimal       tokens_totalVolume_y  tokens_priceEth_y  tokens_priceUsd_y  tokens_numberOfTrades_y  tokens_totalVolumeUsd_y  tokens_totalVolumeEth_y endpoint
# 0  0xa6f3d0560e61e77eace4e15ff44ff0743a4a48f28de85b9e31dd8aac1160c68c0582fc81f21686541623de723448c21e1e443522640ef9d0|0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942|145        1678697171      18901538318      5.774037e+19  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942      5.960373e+18       7.500040e+22  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xa6f3d0560e61e77eace4e15ff44ff0743a4a48f28de85b9e31dd8aac1160c68c0582fc81f21686541623de723448c21e1e443522640ef9d0             5.960373                   0.0          9638.606204                   0.0        cow  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xfd0205066521550d7d7ab19da8f72bb004b4c341                    1673609795  Liquidity Incentive Token               LIT                  18  206520898804458117276021957                0.0                0.0                     2312             34695.682542                21.496144        cow  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee                    1628150700                                                18  1529142827172565356357684                1.0        1657.165221                   133765             2.950902e+09             1.529143e+06      cow
# 1   0xb4a7499f89e945dc83f203c534b5d778489e41fe4b083987f2334a5f8a585dce8cd6f461662451688e8cfc3cfdeeac55bc3b8648640ec917|0x2b3256a8254fe188bd99e661d6cf0a30b4a5d305671c017b7dd5ae00235516b4|77        1678684619      15570611508      2.558668e+19  0x2b3256a8254fe188bd99e661d6cf0a30b4a5d305671c017b7dd5ae00235516b4  0x2b3256a8254fe188bd99e661d6cf0a30b4a5d305671c017b7dd5ae00235516b4      1.200000e+17       1.511202e+21  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xb4a7499f89e945dc83f203c534b5d778489e41fe4b083987f2334a5f8a585dce8cd6f461662451688e8cfc3cfdeeac55bc3b8648640ec917             0.120000                   0.0           193.674849                   0.0        cow  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xfd0205066521550d7d7ab19da8f72bb004b4c341                    1673609795  Liquidity Incentive Token               LIT                  18  206520898804458117276021957                0.0                0.0                     2312             34695.682542                21.496144        cow  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee                    1628150700                                                18  1529142827172565356357684                1.0        1657.165221                   133765             2.950902e+09             1.529143e+06      cow
# 2  0x7cfd93136f35bb5324a2be2a99e56746f2f3e2b751d02fd09117a8da00f594524098503de63ca5c0686c1cc952138f928b7b9aab640e7cc7|0x92c4819edf00f82a4bf229204f625fcf4189e0492370f7bbcb7a99969c64fd58|212        1678665083      41018039430      1.172804e+20  0x92c4819edf00f82a4bf229204f625fcf4189e0492370f7bbcb7a99969c64fd58  0x92c4819edf00f82a4bf229204f625fcf4189e0492370f7bbcb7a99969c64fd58      2.242905e+17       3.000000e+21  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0x7cfd93136f35bb5324a2be2a99e56746f2f3e2b751d02fd09117a8da00f594524098503de63ca5c0686c1cc952138f928b7b9aab640e7cc7             0.224291                   0.0           358.399457                   0.0        cow  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xfd0205066521550d7d7ab19da8f72bb004b4c341                    1673609795  Liquidity Incentive Token               LIT                  18  206520898804458117276021957                0.0                0.0                     2312             34695.682542                21.496144        cow  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee                    1628150700                                                18  1529142827172565356357684                1.0        1657.165221                   133765             2.950902e+09             1.529143e+06      cow
# 3  0x72f1b9e2b5cfb380b6f1d4978db33a0938f3261e8e4c155f3ec8ca05fbcd1bdc0e242b564e89ff2cc2d3c25354bb923feb5c1e0d640e4aae|0x320f21701f23073cc3e0f7e3edb3cfe494a2539aa5c898c067272b517a6fe0e9|132        1678652279      25095562670      1.556697e+20  0x320f21701f23073cc3e0f7e3edb3cfe494a2539aa5c898c067272b517a6fe0e9  0x320f21701f23073cc3e0f7e3edb3cfe494a2539aa5c898c067272b517a6fe0e9      6.741116e+17       9.318566e+21  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0x72f1b9e2b5cfb380b6f1d4978db33a0938f3261e8e4c155f3ec8ca05fbcd1bdc0e242b564e89ff2cc2d3c25354bb923feb5c1e0d640e4aae             0.674112                   0.0          1070.178922                   0.0        cow  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xfd0205066521550d7d7ab19da8f72bb004b4c341                    1673609795  Liquidity Incentive Token               LIT                  18  206520898804458117276021957                0.0                0.0                     2312             34695.682542                21.496144        cow  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee                    1628150700                                                18  1529142827172565356357684                1.0        1657.165221                   133765             2.950902e+09             1.529143e+06      cow
# 4   0xe0c0fa7b9391245da2e273c24f5da80a96ff8b294951d66411762a8f11c086a427182e18bda900300e0c9d634856e0a2ce62ade3640e1f22|0x147e2712be5e496fcfdbbbdd159a1944b9a088f9d47064773460259d50a79314|94        1678641131      25375680178      5.548909e+19  0x147e2712be5e496fcfdbbbdd159a1944b9a088f9d47064773460259d50a79314  0x147e2712be5e496fcfdbbbdd159a1944b9a088f9d47064773460259d50a79314      1.500000e+18       2.172745e+22  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xe0c0fa7b9391245da2e273c24f5da80a96ff8b294951d66411762a8f11c086a427182e18bda900300e0c9d634856e0a2ce62ade3640e1f22             1.500000                   0.0          2312.974563                   0.0        cow  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xfd0205066521550d7d7ab19da8f72bb004b4c341                    1673609795  Liquidity Incentive Token               LIT                  18  206520898804458117276021957                0.0                0.0                     2312             34695.682542                21.496144        cow  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee                    1628150700                                                18  1529142827172565356357684                1.0        1657.165221                   133765             2.950902e+09             1.529143e+06      cow

# %%
df.shape
# Out:
# (331802, 42)

# %%
df.dtypes
# Out:
# trades_id                        object
# trades_timestamp                  int64
# trades_gasPrice                   int64
# trades_feeAmount                float64
# trades_txHash                    object
# trades_settlement_id             object
# trades_buyAmount                float64
# trades_sellAmount               float64
# trades_sellToken_id              object
# trades_buyToken_id               object
# trades_order_id                  object
# trades_buyAmountEth             float64
# trades_sellAmountEth            float64
# trades_buyAmountUsd             float64
# trades_sellAmountUsd            float64
# endpoint_x                       object
# tokens_id_x                      object
# tokens_address_x                 object
# tokens_firstTradeTimestamp_x      int64
# tokens_name_x                    object
# sell_token_symbol                object
# sell_token_decimal                int64
# tokens_totalVolume_x             object
# tokens_priceEth_x               float64
# tokens_priceUsd_x               float64
# tokens_numberOfTrades_x           int64
# tokens_totalVolumeUsd_x         float64
# tokens_totalVolumeEth_x         float64
# endpoint_y                       object
# tokens_id_y                      object
# tokens_address_y                 object
# tokens_firstTradeTimestamp_y      int64
# tokens_name_y                    object
# buy_token_symbol                 object
# buy_token_decimal                 int64
# tokens_totalVolume_y             object
# tokens_priceEth_y               float64
# tokens_priceUsd_y               float64
# tokens_numberOfTrades_y           int64
# tokens_totalVolumeUsd_y         float64
# tokens_totalVolumeEth_y         float64
# endpoint                         object
# dtype: object

# %%
df = df[[
    'trades_id',                        
    'trades_timestamp',                  
    'trades_gasPrice',                   
    'trades_feeAmount',                 
    'trades_txHash',                    
    'trades_buyAmount',                 
    'trades_sellAmount',                
    'trades_sellToken_id',              
    'trades_buyToken_id',               
    'trades_buyAmountUsd',             
    'trades_sellAmountUsd',            
    'sell_token_symbol',                
    'sell_token_decimal',                
    'buy_token_symbol',                 
    'buy_token_decimal'                 
    
]]

# %%
df.head(3)
# Out:
#                                                                                                                                                                                    trades_id  trades_timestamp  trades_gasPrice  trades_feeAmount                                                       trades_txHash  trades_buyAmount  trades_sellAmount                         trades_sellToken_id                          trades_buyToken_id  trades_buyAmountUsd  trades_sellAmountUsd sell_token_symbol  sell_token_decimal buy_token_symbol  buy_token_decimal
# 0  0xa6f3d0560e61e77eace4e15ff44ff0743a4a48f28de85b9e31dd8aac1160c68c0582fc81f21686541623de723448c21e1e443522640ef9d0|0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942|145        1678697171      18901538318      5.774037e+19  0x281baeb30881c0a2b8fd90345101a9b65833a761099bc77ba2696a4c99283942      5.960373e+18       7.500040e+22  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee          9638.606204                   0.0               LIT                  18                                  18
# 1   0xb4a7499f89e945dc83f203c534b5d778489e41fe4b083987f2334a5f8a585dce8cd6f461662451688e8cfc3cfdeeac55bc3b8648640ec917|0x2b3256a8254fe188bd99e661d6cf0a30b4a5d305671c017b7dd5ae00235516b4|77        1678684619      15570611508      2.558668e+19  0x2b3256a8254fe188bd99e661d6cf0a30b4a5d305671c017b7dd5ae00235516b4      1.200000e+17       1.511202e+21  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee           193.674849                   0.0               LIT                  18                                  18
# 2  0x7cfd93136f35bb5324a2be2a99e56746f2f3e2b751d02fd09117a8da00f594524098503de63ca5c0686c1cc952138f928b7b9aab640e7cc7|0x92c4819edf00f82a4bf229204f625fcf4189e0492370f7bbcb7a99969c64fd58|212        1678665083      41018039430      1.172804e+20  0x92c4819edf00f82a4bf229204f625fcf4189e0492370f7bbcb7a99969c64fd58      2.242905e+17       3.000000e+21  0xfd0205066521550d7d7ab19da8f72bb004b4c341  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee           358.399457                   0.0               LIT                  18                                  18

# %%
# calculate buy and sell amounts from the correct decimal 
df['buy_amount'] = df.apply(lambda x: x['trades_buyAmount'] / (10**x['buy_token_decimal']), axis=1)
df['sell_amount'] = df.apply(lambda x: x['trades_sellAmount'] / (10**x['sell_token_decimal']), axis=1)

# %%
# Add new empty columns needed for analysis & specify their data types 
df['cow_price'] = 0.0                  
df['pool_price'] = 0.0  # The CFMM price for a given trade. Given trade is the sell_token and its amount. 
df['surplus_volume'] = 0.0            
df['surplus_price'] = 0.0          
df['surplus_percent'] = 0.0        
df['executed'] = False     
df['k']=0.0  #23
df['k_new']=0.0 #24

df['cow_price'] = df['cow_price'].astype(float)
df['pool_price'] = df['pool_price'].astype(float)
df['surplus_volume'] = df['surplus_volume'].astype(float)
df['surplus_price'] = df['surplus_price'].astype(float)
df['surplus_percent'] = df['surplus_percent'].astype(float)
df['executed'] = df['executed'].astype(bool)
df['k'] = df['k'].astype(float)
df['k_new'] =df['k_new'].astype(float)

# %%
df.dtypes
# Out:
# trades_id                object
# trades_timestamp          int64
# trades_gasPrice           int64
# trades_feeAmount        float64
# trades_txHash            object
# trades_buyAmount        float64
# trades_sellAmount       float64
# trades_sellToken_id      object
# trades_buyToken_id       object
# trades_buyAmountUsd     float64
# trades_sellAmountUsd    float64
# sell_token_symbol        object
# sell_token_decimal        int64
# buy_token_symbol         object
# buy_token_decimal         int64
# buy_amount              float64
# sell_amount             float64
# cow_price               float64
# pool_price              float64
# surplus_volume          float64
# surplus_price           float64
# surplus_percent         float64
# executed                   bool
# k                       float64
# k_new                   float64
# dtype: object

# %% [markdown]
# ## 2. Surplus Calculation Function
#
# Detailed steps of the function:
#
# 1. Filter the dataset for token1 and token2 trades only
# 2. Calculate price for each trade based on whether token1 was the buy or token2. Price defined as Token1/Token2.
# 3. Use the price of the first trade to initialize the feedlot AMM pool with token1_starting_reserves
# 3. Loop through trades and check if `k_new > k` and if yes, execute trade by reflecting new reserves level
#
# Note about fees calculation:
# For the purpose of this study we wish to study the actual historic trades without altering the actual quantities traded by the traders, as this reflects the true prices the traders were willing to accept trading at. This means the dx and dy values do not change in the simulation and are kept as is from the COW trades dataset. This means in the presence of fees in our model, it is assumed that there happens to be a value dx' which if applied fees to results in the dx given in the dataset: So $dx' * (1+s)=dx$
#
# So in order to arrive at dx we want, we did $dx/(1+s)$ to estimate the trades that would have executed with a fee to simulate that in the presence of higher and higher fees it would reflect in worse pricing for the user.
#
#
# Note: To avoid confusion, the definitions of dx and dy at start of notebook refer to token1 and token2, in this loop, dx and dy are just used for calculation purposes. Hence, sometimes dx is token1, somtimes its token2.

# %%
from datetime import datetime
 

def surplus_analysis(token1:str, token2:str, token1_starting_reserves:int, fee_rate:float):
    
    """
    Perform surplus analysis for specific trading pair given by token1 and token2. 

    This function filters the required tokens for the simulation, initializes a feedlot AMM (CPMM) with starting 
    price corresponding to first trade in the list and a given initial reserves, loops through trade by trade and 
    checks if P_feedlot < Pmarket. If yes (k_new > k_current), it executes the trade in Feedlot using the standard 
    CPMM formula. 

    Parameters:
        token1 (str): The first token to perform the surplus analysis on.
        token2 (str): The second token to perform the surplus analysis on.
        starting_reserves (int): The starting reserves of token1. 
        fee_rate (float): The fee rate for the transactions.

    Returns:
        trades_executed_percentage : Percentage of trades executed on Feedlot AMM that met the condition P_feedlot < Pmarket
        executed_volume_percentage : volume of executed trades as percentage of total volume of swaps for token1 and token2
        total_surplus: Sum of surplus in USD terms 
    
    """
    
    
    # Filter the required tokens for the simulation 
   
    dfs = df[((df.buy_token_symbol == token1) & (df.sell_token_symbol == token2)) | ((df.sell_token_symbol == token1) & (df.buy_token_symbol == token2))]
    dfs.sort_values(by='trades_timestamp', ascending=True, inplace=True)
    dfs = dfs[dfs['trades_sellAmountUsd'] > 250]
    dfs = dfs.reset_index(drop=True)
    dfs.to_csv('raw_trades_dataset.csv', index=False)
    
    print('dfs', len(dfs), 'trades in sample')


    # Calculate price column. Only important for analysis is first price to initialize pool with it. 
    # Check if its a buy or a sell and calculate accordingly. 
    for i in range(len(dfs)):
        if dfs.loc[i,'sell_token_symbol'] == token1:
            dfs.loc[i,'cow_price'] = dfs.loc[i,'sell_amount'] / dfs.loc[i,'buy_amount']  

        if dfs.loc[i,'sell_token_symbol'] == token2:
            dfs.loc[i,'cow_price'] = dfs.loc[i,'buy_amount'] / dfs.loc[i,'sell_amount']     
    dfs = dfs[dfs['cow_price'] != 0]
    
    print('price column added')
    
    
    # initialize AMM pool 
    s = fee_rate 
    initialization_price = dfs.loc[dfs.index[0],'cow_price']  
    token2_starting_reserves = token1_starting_reserves / initialization_price
    x = token1_starting_reserves 
    y = token2_starting_reserves 
    k = x * y 
    k_new = k 
    
    print('****** Feedlot AMM Initial State **********')
    print('''AMM Initialized with the following parameters:
    initilization price = {}
    x= {}
    y= {}
    k= {}
    s= {}'''.format(initialization_price, token1_starting_reserves, token2_starting_reserves, k, s))


    # Iterating through trades and checking if the trade would have been executed through Feedlot AMM
    # The condition is k_new > k  
    # Variables to monitor (trades: total trades executed, fees: total fees collected, volume : total volume executed) 

    trades  = 0 
    fees_collected = 0 
    volume = 0 
    
    for i in range(len(dfs)):
        
        # noting the k row to row for reference and visibility
        dfs.loc[i,'k'] = k

        # if token_1 is the "buy token"
        if dfs.loc[i,'buy_token_symbol'] == token1:
            dx = dfs.loc[i,'buy_amount']
            dy = dfs.loc[i,'sell_amount']
            k_new = (x - dx) * (y + (dy/(1+s))) 
            # note the calculated value in the table for reference
            dfs.loc[i,'k_new'] = k_new
            # if token1 is the buy token, then token2 is the sell token which is dy. So given dy what is dx_f? 
            dx_f = x - (k / (y + (dy/(1+s))))
            p_feedlot = dx_f / dy
            dfs.loc[i,'pool_price'] = p_feedlot
            
            if k_new > k:
                surplus_price = abs(p_feedlot - dfs.loc[i,'cow_price'])
                dfs.loc[i,'surplus_volume'] =  surplus_price * dy  # surplus in token1 terms
                dfs.loc[i,'surplus_price'] = surplus_price
                dfs.loc[i,'surplus_percent'] = surplus_price / dfs.iloc[i,6] * 100 # surplus as % of trade volume
                dfs.loc[i,'executed'] = 1 # trade executed signal 
                volume = volume + dfs.loc[i,'trades_sellAmountUsd']
                fees_collected = fees_collected + (s * dfs.loc[i,'trades_sellAmountUsd']) 
                trades = trades + 1 
                k = k_new 
                x = x - dx
                y = y + dy/(1+s)

        # if token_2 is the "buy token"
        elif dfs.loc[i,'buy_token_symbol'] == token2:
            dx = dfs.loc[i,'sell_amount'] 
            dy = dfs.loc[i,'buy_amount']
            k_new = (x + (dx/(1+s))) * (y - dy) 
            dfs.loc[i,'k_new'] = k_new
            # if token2 is the buy token, then token1 is the sell token which is dx. So given dx what is dy? 
            dy_f = y - (k / (x + (dx/(1+s))))
            p_feedlot = dx / dy_f
            dfs.loc[i,'pool_price'] = p_feedlot

            if k_new > k: 
                surplus_price = abs(p_feedlot - dfs.loc[i,'cow_price'])
                dfs.loc[i,'surplus_volume'] =  surplus_price * dy  # surplus in token1 terms 
                dfs.loc[i,'surplus_price'] = surplus_price
                dfs.loc[i,'surplus_percent'] = surplus_price / dfs.iloc[i,6] * 100 # surplus as % of trade volume
                dfs.loc[i,'executed'] = 1 # trade executed signal 
                volume = volume + dfs.loc[i,'trades_sellAmountUsd']
                fees_collected = fees_collected + (s * dfs.loc[i,'trades_sellAmountUsd']) 
                trades = trades + 1 
                k = k_new 
                x = x + (dx/(1+s))
                y = y - dy

    dfs.to_csv('results_similation.csv', index=False)

    # Analysis results 
    
    total_trades = len(dfs)
    
    # use the sell amount USD provided in subgraph as an estimate for total trade volume
    total_volume = dfs['trades_sellAmountUsd'].sum()
    total_surplus = dfs['surplus_volume'].sum() 

    trades_executed_percentage = trades / total_trades * 100 
    executed_volume_percentage = volume / total_volume * 100 
    total_surplus_percentage = total_surplus/ total_volume *100
    
    
    # calculate return metrics 
    starting_date = datetime.utcfromtimestamp(dfs.iloc[0,1]).strftime('%Y-%m-%d')
    ending_date = datetime.utcfromtimestamp(dfs.iloc[-1,1]).strftime('%Y-%m-%d')
    # divide by 3600 because timestamp is in unix10 format which is in seconds. 
    days = (datetime.utcfromtimestamp(dfs.iloc[0,1]) - datetime.utcfromtimestamp(dfs.iloc[-1,1]))
    
    ending_reserves_1 = x 
    ending_reserves_2 = y 
    
    print('******** Results Data **********************')
    print('  Inputs:')
    print('token1', token1)
    print('token2', token2)
    print('initial Reserves', token1_starting_reserves)
    print('fee rate')
    print('  dataset timeframe:')
    print('starting date', datetime.utcfromtimestamp(dfs.iloc[0,1]).strftime('%Y-%m-%d'))
    print('ending date', datetime.utcfromtimestamp(dfs.iloc[-1,1]).strftime('%Y-%m-%d'))
    print('days', days)
    print('  Trades:')
    print('trades executed = ', trades)
    print('total_trades= ', total_trades)
    print('percentage of trades executed = ', trades_executed_percentage, '%') 
    print('  Volume:')
    print('total usd volume traded on feedlot= ', volume)
    print('total USD volume traded on COW', total_volume)
    print('volume percentage = ', volume / total_volume *100 , '%')
    print('  Surplus:')
    print('total surplus', total_surplus)
    print('surplus percentage of volume', total_surplus_percentage, '%')
    print('  LP metrics:')
    print('fees collected', fees_collected)  
    print('ending reserves token1', x)
    print('ending reserves token2', y)
    
    
    return trades_executed_percentage, executed_volume_percentage, total_surplus

# %% [markdown]
# ## 3. USDC-WETH – comparison with real UNIv2 returns

# %% [markdown]
# **Methodology**
#
# This simulation aims to compare the LP returns for an LP that provides liquidity on a proposed Feedlot AMM that executes COW trades at the COW solver UCP price with providing liquidity at UNIv2 for the same assets.
#
# Feedlot AMM is initialized with the same reserves of UNIv2 USDC-WETH pool at the start of the period.
#
# Feedlot uses same fees as UNIv2 of 0.3%
#
# Filter out trades with values < 250 USDC
#
# COW Dataset:                331,802 trades
# of which USDC-WETH trades:  13,206  trades

# %% [markdown]
# #### 3.1 Get UNI V2 returns

# %%
len(df)
# Out:
# 331802

# %%
tokena = 'USDC'
tokenb = 'WETH'

# %%
weth_usdc_df = df[((df.buy_token_symbol == tokena) & (df.sell_token_symbol == tokenb)) | ((df.sell_token_symbol == tokena) & (df.buy_token_symbol == tokenb))]

# %%
weth_usdc_df = weth_usdc_df[weth_usdc_df['trades_sellAmountUsd'] > 250]
weth_usdc_df.sort_values(by='trades_timestamp', ascending=False, inplace=True)

# %%
len(weth_usdc_df)
# Out:
# 17073

# %%
# 17,073 trades that are WETH-USDC out of 331,802

# %%
# last trade
weth_usdc_df.iloc[0,1]
# Out:
# 1678695899

# %%
weth_usdc_df.iloc[0,4]
# Out:
# '0xa0172a34527f45632cd16bfe9c70fdea373098c2b854dbcb592923f83f201243'

# %%
# Block Number last = 16817867
# https://etherscan.io/tx/0xa0172a34527f45632cd16bfe9c70fdea373098c2b854dbcb592923f83f201243

# %%
weth_usdc_df.iloc[-1,1]
# Out:
# 1646097479

# %%
weth_usdc_df.iloc[-1,4]
# Out:
# '0xab85eb2a998f6eaa54b3f10c0e3d3b2f5f55e1bb63d7042e2af7e7c679a477ec'

# %%
# Block Number first = 14298100

#https://etherscan.io/tx/0xab85eb2a998f6eaa54b3f10c0e3d3b2f5f55e1bb63d7042e2af7e7c679a477ec

# %%
days = (datetime.utcfromtimestamp(weth_usdc_df.iloc[0,1]) - datetime.utcfromtimestamp(weth_usdc_df.iloc[-1,1]))
days
# Out:
# datetime.timedelta(days=377, seconds=25620)

# %% [markdown]
# MANUAL WORK
#
# UNIv2 data obtained from Etherscan: Reserves values + LP token supply
#
# https://etherscan.io/tokencheck-tool?t=0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc

# %%
# Univ2 data at last trade:
# UNIV2 USDC_WETH Token supply @ 16760457 = 0.283752303355447465 

# UNIV2 USDC Reserves = 24,534,052.128565
# UNIV2 WETH reserves = 15,116.085248152227807536

# %%
# Univ2 data at first trade
# Block number =  4298100

# UNIV2 USDC_WETH Token supply @ 4298100 = 1.021288427515729217 


# UNIV2 USDC Reserves = 104,656,103.720135  USDC
# UNIV2 WETH reserves = 35,707.054138286841628182  WETH

# %%
# Simple TVL assuming 1.00 USDC = 1.00 USD

# %%
# Assume value of reserves of USDC = value of reserves of WETH. Hence simply multiply by 2 to obtain pool value. 

LP_token_value_end = (24534052.128565 *2) / 0.283752303355447465 
LP_token_value_end
# Out:
# 172925835.93819833

# %%
LP_token_value_start = (104656103.720135 *2) / 1.021288427515729217 
LP_token_value_start
# Out:
# 204949162.05935988

# %%
r = LP_token_value_end/LP_token_value_start
r
# Out:
# 0.8437499046134838

# %%
1-r
# Out:
# 0.15625009538651624

# %%
annual_return = 365 / 377 * (r-1) + 1
annual_return
# Out:
# 0.8487233824507203

# %%
1-annual_return
# Out:
# 0.15127661754927968

# %%
# -19.33 % annual returns. This includes all fees and capital gains.

# %%
# get total volume traded in that pool

# %%
uni_ds = Streamer('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2')

# %%
date_gt = weth_usdc_df.iloc[-1,1]
date_gt
# Out:
# 1646097479

# %%
# date_gt = weth_usdc_df.iloc[-1,1] which is 1646097479 for this simulation. Change it it accordingly below to 
# obtain the right corresponding UNIv2 volume data. 

# query COW schema: trades
uni_pool_fp = uni_ds.queryDict.get('pairDayDatas')

# trades query path that gets token a -> token b trades. Query on query_size. 
uni_pool_qp = uni_pool_fp(
    first=500,
    orderBy='date',
    orderDirection='desc',
    where = {
    'date_gt': 1646097479,
    'pairAddress': "0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc"
    }
)

# run query
uni_pool_df = uni_ds.runQuery(uni_pool_qp)
# Out:
# FIELD - pairDayDatas

# %%
len(uni_pool_df)
# Out:
# 380

# %%
uni_pool_df.dtypes
# Out:
# pairDayDatas_id                    object
# pairDayDatas_date                   int64
# pairDayDatas_pairAddress           object
# pairDayDatas_token0_id             object
# pairDayDatas_token1_id             object
# pairDayDatas_reserve0             float64
# pairDayDatas_reserve1             float64
# pairDayDatas_totalSupply          float64
# pairDayDatas_reserveUSD           float64
# pairDayDatas_dailyVolumeToken0    float64
# pairDayDatas_dailyVolumeToken1    float64
# pairDayDatas_dailyVolumeUSD       float64
# pairDayDatas_dailyTxns              int64
# endpoint                           object
# dtype: object

# %%
uni_pool_df
# Out:
#                                       pairDayDatas_id  pairDayDatas_date                    pairDayDatas_pairAddress                      pairDayDatas_token0_id                      pairDayDatas_token1_id  pairDayDatas_reserve0  pairDayDatas_reserve1  pairDayDatas_totalSupply  pairDayDatas_reserveUSD  pairDayDatas_dailyVolumeToken0  pairDayDatas_dailyVolumeToken1  pairDayDatas_dailyVolumeUSD  pairDayDatas_dailyTxns    endpoint
# 0    0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19432         1678924800  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           2.151690e+07           12976.231932                  0.245953             4.299017e+07                    6.901773e+05                      417.862913                 6.892758e+05                     550  uniswap-v2
# 1    0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19431         1678838400  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           2.149923e+07           12986.170950                  0.245958             4.294954e+07                    4.845339e+06                     2898.718629                 4.837837e+06                    2050  uniswap-v2
# 2    0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19430         1678752000  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           2.182477e+07           12788.539570                  0.246003             4.360950e+07                    6.296042e+06                     3658.722653                 6.286556e+06                    2110  uniswap-v2
# 3    0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19429         1678665600  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           2.081741e+07           12425.460230                  0.236927             4.156191e+07                    5.456099e+06                     3346.232090                 5.455180e+06                    1774  uniswap-v2
# 4    0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19428         1678579200  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           2.440243e+07           15203.795148                  0.283847             4.840944e+07                    9.856379e+06                     6293.382111                 9.695459e+06                    1869  uniswap-v2
# ..                                                ...                ...                                         ...                                         ...                                         ...                    ...                    ...                       ...                      ...                             ...                             ...                          ...                     ...         ...
# 375  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19057         1646524800  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           1.012799e+08           39714.329836                  1.057493             2.026308e+08                    1.759963e+07                     6733.305192                 1.761310e+07                    2351  uniswap-v2
# 376  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19056         1646438400  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           1.034875e+08           38853.079962                  1.057574             2.070242e+08                    2.527348e+07                     3987.569521                 1.790535e+07                    2244  uniswap-v2
# 377  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19055         1646352000  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           1.025716e+08           39168.178118                  1.057423             2.049815e+08                    2.581832e+07                     9581.754030                 2.582687e+07                    2561  uniswap-v2
# 378  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19054         1646265600  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           1.070800e+08           37693.444193                  1.060272             2.140149e+08                    1.971964e+07                     6851.645979                 1.971997e+07                    2507  uniswap-v2
# 379  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc-19053         1646179200  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2           1.091922e+08           36944.180496                  1.060275             2.184007e+08                    3.319170e+07                    11143.001344                 3.317986e+07                    2414  uniswap-v2
#
# [380 rows x 14 columns]

# %%
# Total volume of USDC 
total_uni_volume = uni_pool_df['pairDayDatas_dailyVolumeToken0'].sum()
total_uni_volume
# Out:
# 5542115304.891763

# %% [markdown]
# #### 3.2 Get Simulation Feedlot returns

# %%
# run simulation with starting USDC reserves = 104656103.720135 as per the UNIv2 pool 

surplus_analysis('USDC', 'WETH', 104656103.720135 , 0.003)
# Out:
# /tmp/ipykernel_14931/1021432584.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs.sort_values(by='trades_timestamp', ascending=True, inplace=True)
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 104656103.720135
#     y= 36667.980387553034
#     k= 3837527958647.6265
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 104656103.720135
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7369
# total_trades=  17073
# percentage of trades executed =  43.16171733145902 %
#   Volume:
# total usd volume traded on feedlot=  374070554.31786096
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  24.334932096591956 %
#   Surplus:
# total surplus 12188478.03856793
# surplus percentage of volume 0.7929140158338057 %
#   LP metrics:
# fees collected 1122211.6629535875
# ending reserves token1 81554354.07831943
# ending reserves token2 54712.24809221186
# (43.16171733145902, 24.334932096591956, 12188478.03856793)

# %%
#To calculate Value assume that value of Token1 is same as Token2 in the pool. Since Token1 is in USDC can estimate
# Value of WETH. Since fees are excluded from the returns 

# ending value  
ending_value = 81554354.07831943*2
ending_value
# Out:
# 163108708.15663886

# %%
ending_value_no_surplus = 81554354.07831943*2  - 12188478.038566954
ending_value_no_surplus
# Out:
# 150920230.1180719

# %%
starting_value = 104656103.720135 * 2 
starting_value
# Out:
# 209312207.44027

# %%
ret = ending_value / starting_value 
ret
# Out:
# 0.7792603697191626

# %%
ret -1
# Out:
# -0.22073963028083743

# %%
# number of days: 377 
annual = ((ret -1) * 365/377 )+1
annual
# Out:
# 0.7862865648474651

# %%
#normalize by total volume $1bn

feedlot_normalized = (ending_value - starting_value) / 1.5371752542109973  
feedlot_normalized
# Out:
# -30057405.072752435

# %%
univ2_normalized = (LP_token_value_end - LP_token_value_start) / 5.526736406432251
univ2_normalized
# Out:
# -5794256.097303906

# %%
# also normalize annual reurn percentage return per $1bn. FEEDLOT
(1-ret)*100 / 1.5371752542109973
# Out:
# 14.360082214187013

# %%
(1-0.8066736107929544)*100 /  5.526736406432251
# Out:
# 3.498020802693686

# %%
ret_no_surplus = ending_value_no_surplus / starting_value
ret_no_surplus
# Out:
# 0.7210292794849961

# %%
ret_no_surplus - 1
# Out:
# -0.27897072051500393

# %% [markdown]
# **Results Summary:**
#
# Time period: 377 days
# Total COW trades population: 331,802
# of which USDC-WETH : 17,073
# Total COW volume traded: 1.537bn
# Total UNI volume traded: 5.526bn
# Trades% wouldve executed feedlot: 43.32%
# Volume% wouldve executed feedlot: 24.32%
# real UNI LP return over period = -15.6%
# Feedlot LP return over period = -22.9%
# Hold strategy return over period = -22.05%
# Total Surplus captured = 12,121,421 USDC (0.788% of total volume)
#
#
# Hold Strategy calculations:
# Start:
# USDC = 104656103.720135
# WETH = 36667.98038755301 x 2854.1551133713556 = 104656103.72013
# total start value: 209,312,207.44027
#
# End:
# USDC = 104656103.720135
# WETH = 36667.98038755301 x 1487.12098143276 = 54529722.98109503
# total end value  = 159,185,826.70123005

# %%
hold_start = (35775.554356341396 * 2854.1551133713556)*2

# %%
hold_end  = (36667.98038755301 * 1487.12098143276) + 104656103.720135
hold_end
# Out:
# 159185826.70123005

# %%
hold_ret = hold_end / hold_start
hold_ret
# Out:
# 0.7794898378129795

# %%
(hold_ret-1) *100
# Out:
# -22.051016218702046

# %%
12121421/ 163108708 * 100
# Out:
# 7.431498384500721

# %% [markdown]
# **Discussion**
#
# The results show a remarkeable 24.32% of trade volume that has been traded on COW protocol over 377 days could have fetched a better price if it was executed on a simple CFMM that only traded only with the COW settlement contract. One interpretation is that not trading with arbitrageurs in the wild shields the AMM from adverse selection trades and allows it to offer better pricing. In particular 43% of the time it offered better pricing.
#
# However, the difference between the executions and what the CFMM was quoting, also knows as "surplus" in this study makes up 0.788% of the volume. Which can be interpreted as potential user price average savings of 0.788% if all the surplus was passed to users, or as better returns for LPs if passed to them.
#
# However, despite the encouraging result, the comparison with a simple hold strategy is not so encouraging. Where the feedlot returns bake in impermenant loss and ETH price depreciation (from 2854 to 1487), comparing with the hold strategy at least isolates the price effect on the holding. The hold portfolio would have lost -22.05% in comparison with a feedlot loss of -22.07% which is almost identical.
#
# The gain from the "surplus" on such an AMM contributes to 7.43% (12,121,421/ 163,108,708 * 100% )vs an AMM that would have simply executed those trades at its internal price. Which means such an AMM would have achieved returns of -28%.
#
# This is a really surprising result when compared with what UNIv2 LPs acvhieved in this period: -15.6% even though comparing with UNIv2 was done over exactly the same time period and with exactly the same starting reserves, the UNIv2 trade volume was a multiple of 3.6 to the COW trade volume which can be thought of as more fees captured in that period that allowed it to improve the returns. If we wanted to explore the effect of volume difference a little: with a fee of 0.3% applied to the difference of volume between them (5.526bn - 1.537bn = 3.989) this yields 11,967,000 in fees. Which would have made up around 7.33% of ending tvl of the feedlot pool had it gone through it. Which can be argued to explain some of the difference of 22.07 vs 15.6 = 6.47% between them. Moreover if those fees were added to Feedlot, this would make up a return of -16.3% still worse than the UniV2 return.
#
# It is worth mirroring the above, and looking at it from the user's point of view. What it means is that users were getting better pricing on COW vs UNIv2 overall, since worse pricing would yield better returns for LPs on UNIv2.

# %% [markdown]
# ## 4. USDC-WETH Study - Variable Reserves  & Variable Fees
#
#
# Since the model is based on two variable; Starting reserves and Fee level
#
# will study both seperately.
#
# a. Initial reserves variable while holding fees constant at 0.3%
#
# b. Holds reserves constant at current uni V2 pool reserves level and do variable fees

# %% [markdown]
# ### a. Initial Reserves
#
# Fee level = 0.3 %
# Variable: Initial Reserves
#
# [Study range: USD 100,000 - USD 1,000,000,000]

# %%
import matplotlib.pyplot as plt


token1 = "USDC"
token2 = "WETH"
fee_rate = 0.003 

# Study Starting reserves impact on key variables 

x = []
y1 = []
y2 = []
y3 = []


#range from 10mln to 1bn in 50mn increments for starting reserves. 
for token1_starting_reserves in range(100000, 1000100000, 50000000):
    x.append(token1_starting_reserves)
    trades_executed_percentage, executed_volume_percentage, total_surplus = surplus_analysis(token1, token2, token1_starting_reserves, fee_rate)
    y1.append(trades_executed_percentage)
    y2.append(executed_volume_percentage)
    y3.append(total_surplus)
    
    
df_results_USDC_WETH_reserves = pd.DataFrame({'starting reserves': x, '% of trades executed': y1, '% of volume executed': y2, 'total_surplus': y3})
pd.set_option('display.float_format', lambda x: '%.4f' % x)

print('**************************************')
print('*************RESULTS******************')
print(df_results_USDC_WETH_reserves)
# Out:
# /tmp/ipykernel_14931/1021432584.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs.sort_values(by='trades_timestamp', ascending=True, inplace=True)
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 100000
#     y= 35.0366381741177
#     k= 3503663.8174117696
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  1334
# total_trades=  17073
# percentage of trades executed =  7.8135067064956365 %
#   Volume:
# total usd volume traded on feedlot=  1271640.0380034081
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  0.08272576822452926 %
#   Surplus:
# total surplus 23890.217313871177
# surplus percentage of volume 0.0015541635378546065 %
#   LP metrics:
# fees collected 3814.9201140102286
# ending reserves token1 85537.22013882356
# ending reserves token2 54.659876210791516
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50100000
#     y= 17553.355725232967
#     k= 879423121834.1716
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  6888
# total_trades=  17073
# percentage of trades executed =  40.34440344403444 %
#   Volume:
# total usd volume traded on feedlot=  255899164.47540888
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  16.647364298533223 %
#   Surplus:
# total surplus 5347326.815928506
# surplus percentage of volume 0.34786708940830474 %
#   LP metrics:
# fees collected 767697.4934262253
# ending reserves token1 39639963.658236936
# ending reserves token2 25529.235782985008
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 100100000
#     y= 35071.674812291814
#     k= 3510674648710.4106
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 100100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7341
# total_trades=  17073
# percentage of trades executed =  42.99771569144263 %
#   Volume:
# total usd volume traded on feedlot=  362550523.5611277
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  23.58550351158352 %
#   Surplus:
# total surplus 11653453.047783416
# surplus percentage of volume 0.7581082908965322 %
#   LP metrics:
# fees collected 1087651.5706833869
# ending reserves token1 78159154.67876135
# ending reserves token2 52232.06736114058
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 150100000
#     y= 52589.993899350666
#     k= 7893758084292.535
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 150100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7470
# total_trades=  17073
# percentage of trades executed =  43.7532946758039 %
#   Volume:
# total usd volume traded on feedlot=  432689159.1058981
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  28.148329731471584 %
#   Surplus:
# total surplus 17340176.808898576
# surplus percentage of volume 1.1280546418761443 %
#   LP metrics:
# fees collected 1298067.4773176967
# ending reserves token1 115544853.8312391
# ending reserves token2 79271.60796198488
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 200100000
#     y= 70108.31298640951
#     k= 14028673428580.543
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 200100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7441
# total_trades=  17073
# percentage of trades executed =  43.58343583435834 %
#   Volume:
# total usd volume traded on feedlot=  461883158.59742546
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  30.04752758881103 %
#   Surplus:
# total surplus 24302400.364183903
# surplus percentage of volume 1.580977855167065 %
#   LP metrics:
# fees collected 1385649.475792273
# ending reserves token1 153994192.5868226
# ending reserves token2 106561.36503784137
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 250100000
#     y= 87626.63207346837
#     k= 21915420681574.438
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 250100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7495
# total_trades=  17073
# percentage of trades executed =  43.899724711532826 %
#   Volume:
# total usd volume traded on feedlot=  501683283.2175734
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  32.63670045710421 %
#   Surplus:
# total surplus 31348609.82719985
# surplus percentage of volume 2.0393647205367285 %
#   LP metrics:
# fees collected 1505049.8496527201
# ending reserves token1 193086999.9891499
# ending reserves token2 133546.21047343023
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 300100000
#     y= 105144.95116052721
#     k= 31553999843274.215
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 300100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7556
# total_trades=  17073
# percentage of trades executed =  44.257013998711415 %
#   Volume:
# total usd volume traded on feedlot=  532254168.8265399
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  34.62547080226944 %
#   Surplus:
# total surplus 38035061.41811111
# surplus percentage of volume 2.4743477566345407 %
#   LP metrics:
# fees collected 1596762.506479614
# ending reserves token1 232274691.61083826
# ending reserves token2 160105.43052118717
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 350100000
#     y= 122663.27024758606
#     k= 42944410913679.875
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 350100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7607
# total_trades=  17073
# percentage of trades executed =  44.55573127159843 %
#   Volume:
# total usd volume traded on feedlot=  541393486.1136216
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  35.220023522399764 %
#   Surplus:
# total surplus 43637101.58757445
# surplus percentage of volume 2.8387850681328164 %
#   LP metrics:
# fees collected 1624180.4583408607
# ending reserves token1 271883229.9641971
# ending reserves token2 185900.4802547519
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 400100000
#     y= 140181.5893346449
#     k= 56086653892791.42
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 400100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7628
# total_trades=  17073
# percentage of trades executed =  44.67873250161073 %
#   Volume:
# total usd volume traded on feedlot=  545142798.4598712
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  35.46393275369779 %
#   Surplus:
# total surplus 49563060.629685365
# surplus percentage of volume 3.2242947246197464 %
#   LP metrics:
# fees collected 1635428.3953796083
# ending reserves token1 311489070.94041324
# ending reserves token2 211707.46208482725
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 450100000
#     y= 157699.90842170376
#     k= 70980728780608.86
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 450100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7709
# total_trades=  17073
# percentage of trades executed =  45.15316581737246 %
#   Volume:
# total usd volume traded on feedlot=  566090114.5121028
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  36.82664764224728 %
#   Surplus:
# total surplus 55561633.04816125
# surplus percentage of volume 3.6145282000834693 %
#   LP metrics:
# fees collected 1698270.3435363064
# ending reserves token1 351501877.91721886
# ending reserves token2 237241.01720565808
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 500100000
#     y= 175218.22750876262
#     k= 87626635577132.19
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 500100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7650
# total_trades=  17073
# percentage of trades executed =  44.80759093305219 %
#   Volume:
# total usd volume traded on feedlot=  576740179.5476096
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  37.51948113708344 %
#   Surplus:
# total surplus 60481389.28424961
# surplus percentage of volume 3.9345799458171444 %
#   LP metrics:
# fees collected 1730220.5386428288
# ending reserves token1 391146885.7671884
# ending reserves token2 262448.8765755011
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 550100000
#     y= 192736.54659582145
#     k= 106024374282361.38
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 550100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7656
# total_trades=  17073
# percentage of trades executed =  44.84273414162713 %
#   Volume:
# total usd volume traded on feedlot=  590442771.9234707
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  38.410894939011605 %
#   Surplus:
# total surplus 65855151.19348688
# surplus percentage of volume 4.284166754121284 %
#   LP metrics:
# fees collected 1771328.3157704133
# ending reserves token1 430689768.6041043
# ending reserves token2 287884.46261665237
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 600100000
#     y= 210254.8656828803
#     k= 126173944896296.47
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 600100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7661
# total_trades=  17073
# percentage of trades executed =  44.87202014877292 %
#   Volume:
# total usd volume traded on feedlot=  594233588.9879736
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  38.65750423447861 %
#   Surplus:
# total surplus 69578211.47819197
# surplus percentage of volume 4.5263681735434345 %
#   LP metrics:
# fees collected 1782700.7669639215
# ending reserves token1 469007833.6422271
# ending reserves token2 313009.31810463447
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 650100000
#     y= 227773.18476993917
#     k= 148075347418937.44
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 650100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7672
# total_trades=  17073
# percentage of trades executed =  44.93644936449365 %
#   Volume:
# total usd volume traded on feedlot=  608582259.0917805
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  39.59094822952729 %
#   Surplus:
# total surplus 73738120.64933208
# surplus percentage of volume 4.796988531225117 %
#   LP metrics:
# fees collected 1825746.777275342
# ending reserves token1 507916642.2257625
# ending reserves token2 338060.3424379388
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 700100000
#     y= 245291.503856998
#     k= 171728581850284.28
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 700100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7720
# total_trades=  17073
# percentage of trades executed =  45.21759503309319 %
#   Volume:
# total usd volume traded on feedlot=  615836396.5120196
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  40.06286172152288 %
#   Surplus:
# total surplus 79197349.97708133
# surplus percentage of volume 5.152135370389618 %
#   LP metrics:
# fees collected 1847509.1895360579
# ending reserves token1 546899587.8569694
# ending reserves token2 363835.6092983939
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 750100000
#     y= 262809.8229440569
#     k= 197133648190337.06
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 750100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7662
# total_trades=  17073
# percentage of trades executed =  44.87787735020207 %
#   Volume:
# total usd volume traded on feedlot=  636284167.2610853
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  41.393078994605446 %
#   Surplus:
# total surplus 87606956.70067923
# surplus percentage of volume 5.699217214217139 %
#   LP metrics:
# fees collected 1908852.5017832543
# ending reserves token1 586519864.2986124
# ending reserves token2 391037.073225529
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 800100000
#     y= 280328.1420311157
#     k= 224290546439095.7
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 800100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7699
# total_trades=  17073
# percentage of trades executed =  45.09459380308089 %
#   Volume:
# total usd volume traded on feedlot=  650125445.0523367
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  42.293514891770336 %
#   Surplus:
# total surplus 96276215.3703168
# surplus percentage of volume 6.263190557262356 %
#   LP metrics:
# fees collected 1950376.3351570102
# ending reserves token1 625048408.4042997
# ending reserves token2 418945.92665027827
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 850100000
#     y= 297846.46111817454
#     k= 253199276596560.2
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 850100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7672
# total_trades=  17073
# percentage of trades executed =  44.93644936449365 %
#   Volume:
# total usd volume traded on feedlot=  663282125.007198
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  43.14941469361918 %
#   Surplus:
# total surplus 105219063.38420513
# surplus percentage of volume 6.844962088477807 %
#   LP metrics:
# fees collected 1989846.3750215948
# ending reserves token1 662091712.0028069
# ending reserves token2 448035.39482937724
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 900100000
#     y= 315364.78020523343
#     k= 283859838662730.6
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 900100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7696
# total_trades=  17073
# percentage of trades executed =  45.077022198793415 %
#   Volume:
# total usd volume traded on feedlot=  667079697.6760477
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  43.3964634708127 %
#   Surplus:
# total surplus 114491863.20746684
# surplus percentage of volume 7.448198433706462 %
#   LP metrics:
# fees collected 2001239.0930281458
# ending reserves token1 699307689.6730015
# ending reserves token2 477119.0691485544
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 950100000
#     y= 332883.09929229226
#     k= 316272232637606.9
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 950100000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7784
# total_trades=  17073
# percentage of trades executed =  45.592455924559246 %
#   Volume:
# total usd volume traded on feedlot=  678064124.6286798
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  44.11104867653604 %
#   Surplus:
# total surplus 123105465.79182883
# surplus percentage of volume 8.008551104019464 %
#   LP metrics:
# fees collected 2034192.3738860395
# ending reserves token1 736258975.385186
# ending reserves token2 505689.25358743174
# **************************************
# *************RESULTS******************
#     starting reserves  % of trades executed  % of volume executed  total_surplus
# 0              100000                7.8135                0.0827     23890.2173
# 1            50100000               40.3444               16.6474   5347326.8159
# 2           100100000               42.9977               23.5855  11653453.0478
# 3           150100000               43.7533               28.1483  17340176.8089
# 4           200100000               43.5834               30.0475  24302400.3642
# 5           250100000               43.8997               32.6367  31348609.8272
# 6           300100000               44.2570               34.6255  38035061.4181
# 7           350100000               44.5557               35.2200  43637101.5876
# 8           400100000               44.6787               35.4639  49563060.6297
# 9           450100000               45.1532               36.8266  55561633.0482
# 10          500100000               44.8076               37.5195  60481389.2842
# 11          550100000               44.8427               38.4109  65855151.1935
# 12          600100000               44.8720               38.6575  69578211.4782
# 13          650100000               44.9364               39.5909  73738120.6493
# 14          700100000               45.2176               40.0629  79197349.9771
# 15          750100000               44.8779               41.3931  87606956.7007
# 16          800100000               45.0946               42.2935  96276215.3703
# 17          850100000               44.9364               43.1494 105219063.3842
# 18          900100000               45.0770               43.3965 114491863.2075
# 19          950100000               45.5925               44.1110 123105465.7918

# %%
import matplotlib.pyplot as plt
import os

# Create the "diagrams" folder if it doesn't exist
if not os.path.exists("diagrams"):
    os.makedirs("diagrams")

# Generate the first plot1
fig, ax = plt.subplots()
ax.plot(x, y1, label='Percentage of Trades executed')
ax.plot(x, y2, label='Percentage of Volume executed')
ax.set_xlabel('Initial reserves')
ax.set_title('USDC-WETH; vs Initial reserves')
ax.legend()
fig.savefig("diagrams/plot1_exec_vs_reserves.pdf")
plt.show()


# Generate the second plot2
fig, ax = plt.subplots()
ax.plot(x, y3)
ax.set_xlabel('Initial Reserves')
ax.set_ylabel('Total Surplus')
ax.set_title('USDC-WETH; Surplus (USDC) vs Initial reserves')
ax.ticklabel_format(style='plain', axis='x')
fig.savefig("diagrams/plot2_surplus_vs_reserves.pdf")
plt.show()

# %% [markdown]
# Note:
# Uni v2 USDC-WETH current reserves TVL : USD 86,620,798
# Uni v3 USDC-ETH current reserves TVL : 390,840,000 USD (Combining 0.3% pool + 0.05% pool )

# %% [markdown]
# ### b. Fee level

# %%
import matplotlib.pyplot as plt

# starting reserves ~$100mln TVL
token1 = "USDC"
token2 = "WETH"
token1_starting_reserves = 50000000

# Study Starting reserves impact on key variables 

x_fee = []
y1_fee = []
y2_fee = []
y3_fee = []


#range from  0 - 6% increments of 0.1% for fees. 
# range method only accepts integers. 
for fee_rate_int in range(0, 60, 1):
    fee_rate = fee_rate_int/1000
    x_fee.append(fee_rate)
    trades_executed_percentage, executed_volume_percentage, total_surplus = surplus_analysis(token1, token2, token1_starting_reserves, fee_rate)
    y1_fee.append(trades_executed_percentage)
    y2_fee.append(executed_volume_percentage)
    y3_fee.append(total_surplus)
    
    
df_results_USDC_WETH_fee = pd.DataFrame({'starting reserves': x_fee, '% of trades executed': y1_fee, '% of volume executed': y2_fee, 'total_surplus': y3})
pd.set_option('display.float_format', lambda x: '%.4f' % x)

print('**************************************')
print('*************RESULTS******************')
print(df_results_USDC_WETH_fee)
# Out:
# /tmp/ipykernel_14931/1021432584.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs.sort_values(by='trades_timestamp', ascending=True, inplace=True)
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.0
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  8106
# total_trades=  17073
# percentage of trades executed =  47.478474784747846 %
#   Volume:
# total usd volume traded on feedlot=  296325142.69723034
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  19.277251691729084 %
#   Surplus:
# total surplus 6050845.502754563
# surplus percentage of volume 0.3936340691263825 %
#   LP metrics:
# fees collected 0.0
# ending reserves token1 40048118.30003584
# ending reserves token2 25612.25599216762
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.001
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7663
# total_trades=  17073
# percentage of trades executed =  44.883734551631235 %
#   Volume:
# total usd volume traded on feedlot=  279602007.44710195
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  18.189338312671207 %
#   Surplus:
# total surplus 5725559.469197548
# surplus percentage of volume 0.37247278431738534 %
#   LP metrics:
# fees collected 279602.0074471009
# ending reserves token1 39908745.36843349
# ending reserves token2 25498.769626974354
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.002
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  7277
# total_trades=  17073
# percentage of trades executed =  42.62285479997657 %
#   Volume:
# total usd volume traded on feedlot=  265573254.30188006
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  17.276706320529062 %
#   Surplus:
# total surplus 5535648.04263411
# surplus percentage of volume 0.36011821212119705 %
#   LP metrics:
# fees collected 531146.5086037583
# ending reserves token1 39783638.638150275
# ending reserves token2 25454.3288192292
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.003
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  6865
# total_trades=  17073
# percentage of trades executed =  40.209687811163825 %
#   Volume:
# total usd volume traded on feedlot=  254573036.41658428
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  16.56109384529819 %
#   Surplus:
# total surplus 5349153.441100323
# surplus percentage of volume 0.34798591939641527 %
#   LP metrics:
# fees collected 763719.109249752
# ending reserves token1 39594325.15459527
# ending reserves token2 25462.36329825541
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.004
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  6569
# total_trades=  17073
# percentage of trades executed =  38.47595618813331 %
#   Volume:
# total usd volume traded on feedlot=  240373119.4414552
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  15.637326894442763 %
#   Surplus:
# total surplus 5124856.240120875
# surplus percentage of volume 0.3333944015870438 %
#   LP metrics:
# fees collected 961492.4777658166
# ending reserves token1 39479769.967270516
# ending reserves token2 25395.53980415308
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.005
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  6291
# total_trades=  17073
# percentage of trades executed =  36.84765419082762 %
#   Volume:
# total usd volume traded on feedlot=  231178301.31267408
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  15.039163600856526 %
#   Surplus:
# total surplus 4893960.288603203
# surplus percentage of volume 0.318373606080146 %
#   LP metrics:
# fees collected 1155891.5065633692
# ending reserves token1 39373802.27636975
# ending reserves token2 25319.817938227454
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.006
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  6045
# total_trades=  17073
# percentage of trades executed =  35.40678263925496 %
#   Volume:
# total usd volume traded on feedlot=  220559842.80787835
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  14.348386249626916 %
#   Surplus:
# total surplus 4777066.754085506
# surplus percentage of volume 0.3107691683820062 %
#   LP metrics:
# fees collected 1323359.056847273
# ending reserves token1 39272198.03789504
# ending reserves token2 25296.471106038352
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.007
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  5771
# total_trades=  17073
# percentage of trades executed =  33.801909447665906 %
#   Volume:
# total usd volume traded on feedlot=  212491841.51177087
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  13.823527338841975 %
#   Surplus:
# total surplus 4494746.281560659
# surplus percentage of volume 0.29240298197928816 %
#   LP metrics:
# fees collected 1487442.8905824036
# ending reserves token1 39046377.7617067
# ending reserves token2 25273.167409307116
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.008
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  5576
# total_trades=  17073
# percentage of trades executed =  32.65975516898026 %
#   Volume:
# total usd volume traded on feedlot=  200800913.96188802
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  13.062981167033897 %
#   Surplus:
# total surplus 4488700.123551717
# surplus percentage of volume 0.29200965285221697 %
#   LP metrics:
# fees collected 1606407.3116951
# ending reserves token1 39068257.569812916
# ending reserves token2 25236.848534569905
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.009
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  5398
# total_trades=  17073
# percentage of trades executed =  31.617173314590293 %
#   Volume:
# total usd volume traded on feedlot=  196676452.6433511
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  12.794666847815044 %
#   Surplus:
# total surplus 4335807.344138885
# surplus percentage of volume 0.2820633062015022 %
#   LP metrics:
# fees collected 1770088.0737901586
# ending reserves token1 38962709.392622374
# ending reserves token2 25210.019162305223
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.01
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  5218
# total_trades=  17073
# percentage of trades executed =  30.562877057342003 %
#   Volume:
# total usd volume traded on feedlot=  190411679.87746033
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  12.387115870870236 %
#   Surplus:
# total surplus 4296472.044539724
# surplus percentage of volume 0.27950437224186386 %
#   LP metrics:
# fees collected 1904116.798774601
# ending reserves token1 38968054.43512122
# ending reserves token2 25173.19264098611
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.011
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  5026
# total_trades=  17073
# percentage of trades executed =  29.43829438294383 %
#   Volume:
# total usd volume traded on feedlot=  186074521.24711388
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  12.104964657567454 %
#   Surplus:
# total surplus 4093243.692429179
# surplus percentage of volume 0.26628347556441523 %
#   LP metrics:
# fees collected 2046819.733718254
# ending reserves token1 38768556.21929271
# ending reserves token2 25180.17858889812
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.012
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4805
# total_trades=  17073
# percentage of trades executed =  28.1438528671001 %
#   Volume:
# total usd volume traded on feedlot=  181813520.33942568
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  11.827767838531013 %
#   Surplus:
# total surplus 3966183.3147556284
# surplus percentage of volume 0.25801764007653083 %
#   LP metrics:
# fees collected 2181762.244073104
# ending reserves token1 38682340.516421445
# ending reserves token2 25145.66620091518
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.013
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4671
# total_trades=  17073
# percentage of trades executed =  27.358987875593044 %
#   Volume:
# total usd volume traded on feedlot=  174142485.49954128
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  11.328733338797162 %
#   Surplus:
# total surplus 3798552.207526083
# surplus percentage of volume 0.24711250048556158 %
#   LP metrics:
# fees collected 2263852.311494033
# ending reserves token1 38625784.36404529
# ending reserves token2 25075.95392303162
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.014
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4548
# total_trades=  17073
# percentage of trades executed =  26.638552099806713 %
#   Volume:
# total usd volume traded on feedlot=  170074662.1370058
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  11.064103567312621 %
#   Surplus:
# total surplus 3727651.717621877
# surplus percentage of volume 0.24250011229430107 %
#   LP metrics:
# fees collected 2381045.2699180776
# ending reserves token1 38605299.15135446
# ending reserves token2 25042.984986021504
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.015
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4459
# total_trades=  17073
# percentage of trades executed =  26.117261172611727 %
#   Volume:
# total usd volume traded on feedlot=  167133514.08598036
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  10.872768972056267 %
#   Surplus:
# total surplus 3685631.8591785096
# surplus percentage of volume 0.23976653599398945 %
#   LP metrics:
# fees collected 2507002.7112897066
# ending reserves token1 38544883.57563637
# ending reserves token2 25045.08234981004
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.016
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4381
# total_trades=  17073
# percentage of trades executed =  25.660399461137466 %
#   Volume:
# total usd volume traded on feedlot=  161425047.64922327
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  10.501408164554384 %
#   Surplus:
# total surplus 3566653.8896176936
# surplus percentage of volume 0.23202649664357164 %
#   LP metrics:
# fees collected 2582800.762387563
# ending reserves token1 38469459.96774372
# ending reserves token2 25016.603768381465
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.017
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4248
# total_trades=  17073
# percentage of trades executed =  24.881391671059568 %
#   Volume:
# total usd volume traded on feedlot=  156092121.83012575
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  10.154477923224496 %
#   Surplus:
# total surplus 3474460.243865308
# surplus percentage of volume 0.22602889516645788 %
#   LP metrics:
# fees collected 2653566.071112136
# ending reserves token1 38452723.09159898
# ending reserves token2 24976.708379636468
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.018
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  4106
# total_trades=  17073
# percentage of trades executed =  24.049669068119254 %
#   Volume:
# total usd volume traded on feedlot=  153281272.11218402
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.97161980667327 %
#   Surplus:
# total surplus 3342425.7387104095
# surplus percentage of volume 0.2174394708445923 %
#   LP metrics:
# fees collected 2759062.8980192947
# ending reserves token1 38384160.13379825
# ending reserves token2 24935.553976388062
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.019
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3985
# total_trades=  17073
# percentage of trades executed =  23.34094769519124 %
#   Volume:
# total usd volume traded on feedlot=  149959798.94299823
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.755543392478677 %
#   Surplus:
# total surplus 3249142.626102242
# surplus percentage of volume 0.21137099476467733 %
#   LP metrics:
# fees collected 2849236.1799169523
# ending reserves token1 38333645.79950534
# ending reserves token2 24907.316144130054
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.02
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3872
# total_trades=  17073
# percentage of trades executed =  22.679083933696482 %
#   Volume:
# total usd volume traded on feedlot=  148438512.3101903
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.656577017067642 %
#   Surplus:
# total surplus 3198325.858828316
# surplus percentage of volume 0.20806514091784253 %
#   LP metrics:
# fees collected 2968770.246203795
# ending reserves token1 38277651.17794334
# ending reserves token2 24916.52989007226
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.021
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3767
# total_trades=  17073
# percentage of trades executed =  22.064077783634982 %
#   Volume:
# total usd volume traded on feedlot=  145359777.30911863
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.45629178656854 %
#   Surplus:
# total surplus 3101252.1206904706
# surplus percentage of volume 0.2017500680026419 %
#   LP metrics:
# fees collected 3052555.3234914937
# ending reserves token1 38260190.093262166
# ending reserves token2 24860.947369357313
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.022
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3678
# total_trades=  17073
# percentage of trades executed =  21.542786856439992 %
#   Volume:
# total usd volume traded on feedlot=  142789375.667869
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.289075873210049 %
#   Surplus:
# total surplus 3143677.7398051675
# surplus percentage of volume 0.20451004081631258 %
#   LP metrics:
# fees collected 3141366.264693125
# ending reserves token1 38303864.74200558
# ending reserves token2 24867.448657661855
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.023
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3557
# total_trades=  17073
# percentage of trades executed =  20.834065483511978 %
#   Volume:
# total usd volume traded on feedlot=  139974462.74922076
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  9.105953427611412 %
#   Surplus:
# total surplus 3049927.73370635
# surplus percentage of volume 0.19841119126470844 %
#   LP metrics:
# fees collected 3219412.643232081
# ending reserves token1 38243210.43439853
# ending reserves token2 24847.151892765505
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.024
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3522
# total_trades=  17073
# percentage of trades executed =  20.629063433491478 %
#   Volume:
# total usd volume traded on feedlot=  136089487.8484495
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.853218751449496 %
#   Surplus:
# total surplus 3021257.6462194673
# surplus percentage of volume 0.1965460761837609 %
#   LP metrics:
# fees collected 3266147.7083627796
# ending reserves token1 38024432.37029772
# ending reserves token2 24967.5449552616
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.025
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3482
# total_trades=  17073
# percentage of trades executed =  20.394775376325192 %
#   Volume:
# total usd volume traded on feedlot=  134449644.93316182
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.746539769284293 %
#   Surplus:
# total surplus 3012983.981172139
# surplus percentage of volume 0.1960078379428926 %
#   LP metrics:
# fees collected 3361241.1233290504
# ending reserves token1 38037963.080693536
# ending reserves token2 24952.018573094454
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.026
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3402
# total_trades=  17073
# percentage of trades executed =  19.92619926199262 %
#   Volume:
# total usd volume traded on feedlot=  132282321.89483362
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.605545888957964 %
#   Surplus:
# total surplus 2938722.7164132996
# surplus percentage of volume 0.19117681659022606 %
#   LP metrics:
# fees collected 3439340.369265668
# ending reserves token1 38021022.01296336
# ending reserves token2 24913.68209556154
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.027
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3311
# total_trades=  17073
# percentage of trades executed =  19.39319393193932 %
#   Volume:
# total usd volume traded on feedlot=  129621511.14367908
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.432448466015108 %
#   Surplus:
# total surplus 2804768.186975233
# surplus percentage of volume 0.18246248625794245 %
#   LP metrics:
# fees collected 3499780.8008793276
# ending reserves token1 37972617.34317526
# ending reserves token2 24859.21056666675
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.028
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3282
# total_trades=  17073
# percentage of trades executed =  19.223335090493762 %
#   Volume:
# total usd volume traded on feedlot=  127891889.80375357
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.319929003111492 %
#   Surplus:
# total surplus 2777991.64444672
# surplus percentage of volume 0.18072055459106448 %
#   LP metrics:
# fees collected 3580972.914505092
# ending reserves token1 37907119.813126504
# ending reserves token2 24887.421853263142
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.029
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3198
# total_trades=  17073
# percentage of trades executed =  18.73133017044456 %
#   Volume:
# total usd volume traded on feedlot=  126174496.13572907
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  8.208205003956563 %
#   Surplus:
# total surplus 2728322.456327058
# surplus percentage of volume 0.17748935580721756 %
#   LP metrics:
# fees collected 3659060.38793613
# ending reserves token1 37880344.27448291
# ending reserves token2 24876.759402229836
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.03
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3117
# total_trades=  17073
# percentage of trades executed =  18.256896854682832 %
#   Volume:
# total usd volume traded on feedlot=  122543686.13182434
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.972004870370078 %
#   Surplus:
# total surplus 2641845.0069216928
# surplus percentage of volume 0.17186361800221026 %
#   LP metrics:
# fees collected 3676310.5839547208
# ending reserves token1 37897306.523459084
# ending reserves token2 24806.238159629112
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.031
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  3062
# total_trades=  17073
# percentage of trades executed =  17.934750776079188 %
#   Volume:
# total usd volume traded on feedlot=  121702700.4728121
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.917295060495869 %
#   Surplus:
# total surplus 2599208.2134656976
# surplus percentage of volume 0.16908990737037471 %
#   LP metrics:
# fees collected 3772783.7146571716
# ending reserves token1 37893590.50009785
# ending reserves token2 24783.387941837856
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.032
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2997
# total_trades=  17073
# percentage of trades executed =  17.554032683183976 %
#   Volume:
# total usd volume traded on feedlot=  120286517.62465912
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.825166147785789 %
#   Surplus:
# total surplus 2578513.5585345603
# surplus percentage of volume 0.16774362919718364 %
#   LP metrics:
# fees collected 3849168.563989079
# ending reserves token1 37872626.19150086
# ending reserves token2 24771.27876481515
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.033
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2948
# total_trades=  17073
# percentage of trades executed =  17.267029813155276 %
#   Volume:
# total usd volume traded on feedlot=  117713863.38951838
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.657803693303576 %
#   Surplus:
# total surplus 2540530.623274158
# surplus percentage of volume 0.16527267247599323 %
#   LP metrics:
# fees collected 3884557.4918541
# ending reserves token1 37868794.42656331
# ending reserves token2 24745.741298527555
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.034
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2883
# total_trades=  17073
# percentage of trades executed =  16.88631172026006 %
#   Volume:
# total usd volume traded on feedlot=  117505353.55078639
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.644239212730473 %
#   Surplus:
# total surplus 2521456.543638688
# surplus percentage of volume 0.1640318198417072 %
#   LP metrics:
# fees collected 3995182.0207267273
# ending reserves token1 37875325.28459119
# ending reserves token2 24731.094786451216
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.035
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2834
# total_trades=  17073
# percentage of trades executed =  16.59930885023136 %
#   Volume:
# total usd volume traded on feedlot=  115282872.88719037
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.499657086684164 %
#   Surplus:
# total surplus 2503997.556090874
# surplus percentage of volume 0.16289603603956845 %
#   LP metrics:
# fees collected 4034900.5510516516
# ending reserves token1 37884171.53701272
# ending reserves token2 24709.030969325107
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.036
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2827
# total_trades=  17073
# percentage of trades executed =  16.55830844022726 %
#   Volume:
# total usd volume traded on feedlot=  114592568.69092187
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.454749767601486 %
#   Surplus:
# total surplus 2421140.839434651
# surplus percentage of volume 0.15750584279847624 %
#   LP metrics:
# fees collected 4125332.4728731713
# ending reserves token1 37743523.25871865
# ending reserves token2 24751.355778362413
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.037
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2758
# total_trades=  17073
# percentage of trades executed =  16.154161541615416 %
#   Volume:
# total usd volume traded on feedlot=  109119178.79099087
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.0986817210377 %
#   Surplus:
# total surplus 2376970.5683585913
# surplus percentage of volume 0.1546323727139782 %
#   LP metrics:
# fees collected 4037409.615266654
# ending reserves token1 37718009.20125228
# ending reserves token2 24737.581984216213
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.038
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2740
# total_trades=  17073
# percentage of trades executed =  16.04873191589059 %
#   Volume:
# total usd volume traded on feedlot=  108875164.95782205
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.082807549728972 %
#   Surplus:
# total surplus 2391457.941119148
# surplus percentage of volume 0.15557483992588975 %
#   LP metrics:
# fees collected 4137256.268397232
# ending reserves token1 37715360.10284336
# ending reserves token2 24741.36303148667
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.039
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2688
# total_trades=  17073
# percentage of trades executed =  15.744157441574416 %
#   Volume:
# total usd volume traded on feedlot=  107603404.83680359
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  7.000073969577031 %
#   Surplus:
# total surplus 2358381.064453611
# surplus percentage of volume 0.15342304385872535 %
#   LP metrics:
# fees collected 4196532.788635328
# ending reserves token1 37714337.769675575
# ending reserves token2 24719.089156222828
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.04
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2631
# total_trades=  17073
# percentage of trades executed =  15.410296960112458 %
#   Volume:
# total usd volume traded on feedlot=  105442556.26124601
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.8595012814832 %
#   Surplus:
# total surplus 2249736.8988185385
# surplus percentage of volume 0.1463552638292558 %
#   LP metrics:
# fees collected 4217702.250449838
# ending reserves token1 37696729.06851685
# ending reserves token2 24665.82978088499
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.041
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2626
# total_trades=  17073
# percentage of trades executed =  15.381010952966673 %
#   Volume:
# total usd volume traded on feedlot=  105099194.16182607
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.837164069218085 %
#   Surplus:
# total surplus 2266222.220032188
# surplus percentage of volume 0.14742770636100286 %
#   LP metrics:
# fees collected 4309066.960634853
# ending reserves token1 37695208.48289795
# ending reserves token2 24675.86190714036
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.042
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2566
# total_trades=  17073
# percentage of trades executed =  15.029578867217245 %
#   Volume:
# total usd volume traded on feedlot=  103765925.01815665
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.7504290570575 %
#   Surplus:
# total surplus 2225450.5938316067
# surplus percentage of volume 0.14477533304905352 %
#   LP metrics:
# fees collected 4358168.850762562
# ending reserves token1 37642899.492315345
# ending reserves token2 24683.05677810996
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.043
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2517
# total_trades=  17073
# percentage of trades executed =  14.742575997188542 %
#   Volume:
# total usd volume traded on feedlot=  102579997.86829893
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.673279288570859 %
#   Surplus:
# total surplus 2205271.07375054
# surplus percentage of volume 0.14346256665980897 %
#   LP metrics:
# fees collected 4410939.908336848
# ending reserves token1 37494651.672008425
# ending reserves token2 24767.8460234075
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.044
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2502
# total_trades=  17073
# percentage of trades executed =  14.654717975751186 %
#   Volume:
# total usd volume traded on feedlot=  100834322.10549563
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.559715414964311 %
#   Surplus:
# total surplus 2150583.119054951
# surplus percentage of volume 0.1399048750728689 %
#   LP metrics:
# fees collected 4436710.172641791
# ending reserves token1 37478819.333124585
# ending reserves token2 24744.581712822335
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.045
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2487
# total_trades=  17073
# percentage of trades executed =  14.566859954313829 %
#   Volume:
# total usd volume traded on feedlot=  100248098.36861484
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.521578986780546 %
#   Surplus:
# total surplus 2118819.176594117
# surplus percentage of volume 0.1378384911407949 %
#   LP metrics:
# fees collected 4511164.426587663
# ending reserves token1 37463044.02249356
# ending reserves token2 24735.62394090009
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.046
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2407
# total_trades=  17073
# percentage of trades executed =  14.098283839981256 %
#   Volume:
# total usd volume traded on feedlot=  98984090.20017916
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.439349705182823 %
#   Surplus:
# total surplus 2088995.6420768946
# surplus percentage of volume 0.1358983392657551 %
#   LP metrics:
# fees collected 4553268.149208233
# ending reserves token1 37411225.99674878
# ending reserves token2 24744.37533972309
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.047
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2361
# total_trades=  17073
# percentage of trades executed =  13.828852574240027 %
#   Volume:
# total usd volume traded on feedlot=  97801702.55355076
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.362430196923155 %
#   Surplus:
# total surplus 2062038.8728621525
# surplus percentage of volume 0.13414468306156527 %
#   LP metrics:
# fees collected 4596680.020016873
# ending reserves token1 37389223.68779615
# ending reserves token2 24739.789873321595
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.048
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2339
# total_trades=  17073
# percentage of trades executed =  13.699994142798571 %
#   Volume:
# total usd volume traded on feedlot=  95961790.80494359
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.24273585865126 %
#   Surplus:
# total surplus 2020151.5951258414
# surplus percentage of volume 0.1314197317184075 %
#   LP metrics:
# fees collected 4606165.958637275
# ending reserves token1 37387091.90429602
# ending reserves token2 24715.002412654572
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.049
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2300
# total_trades=  17073
# percentage of trades executed =  13.471563287061441 %
#   Volume:
# total usd volume traded on feedlot=  94391998.25929329
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.140613960621093 %
#   Surplus:
# total surplus 1971941.2732603033
# surplus percentage of volume 0.12828343859025124 %
#   LP metrics:
# fees collected 4625207.914705363
# ending reserves token1 37266250.09734533
# ending reserves token2 24764.34168904837
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.05
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2306
# total_trades=  17073
# percentage of trades executed =  13.506706495636383 %
#   Volume:
# total usd volume traded on feedlot=  94331677.75073348
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.136689846672827 %
#   Surplus:
# total surplus 1970474.1913941766
# surplus percentage of volume 0.12818799847292517 %
#   LP metrics:
# fees collected 4716583.88753666
# ending reserves token1 37278644.29735515
# ending reserves token2 24756.28945614517
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.051
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2261
# total_trades=  17073
# percentage of trades executed =  13.243132431324314 %
#   Volume:
# total usd volume traded on feedlot=  93015723.23415346
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.051081227032675 %
#   Surplus:
# total surplus 1936454.0917915127
# surplus percentage of volume 0.1259748416120228 %
#   LP metrics:
# fees collected 4743801.88494182
# ending reserves token1 37273396.05057665
# ending reserves token2 24734.56469984894
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.052
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2225
# total_trades=  17073
# percentage of trades executed =  13.032273179874657 %
#   Volume:
# total usd volume traded on feedlot=  92271343.68473919
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  6.002656068783796 %
#   Surplus:
# total surplus 1908190.8323774473
# surplus percentage of volume 0.12413619248358802 %
#   LP metrics:
# fees collected 4798109.871606427
# ending reserves token1 37206531.400496386
# ending reserves token2 24760.630192962868
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.053
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2183
# total_trades=  17073
# percentage of trades executed =  12.786270719850057 %
#   Volume:
# total usd volume traded on feedlot=  91759809.79867612
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.969378543357743 %
#   Surplus:
# total surplus 1905844.1532283276
# surplus percentage of volume 0.12398353070070471 %
#   LP metrics:
# fees collected 4863269.919329826
# ending reserves token1 37281975.55574362
# ending reserves token2 24701.908144852416
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.054
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2177
# total_trades=  17073
# percentage of trades executed =  12.751127511275111 %
#   Volume:
# total usd volume traded on feedlot=  88548899.27790007
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.760494714921139 %
#   Surplus:
# total surplus 1894587.1951503153
# surplus percentage of volume 0.12325121614859527 %
#   LP metrics:
# fees collected 4781640.561006588
# ending reserves token1 37241888.212157644
# ending reserves token2 24723.7444007216
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.055
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2150
# total_trades=  17073
# percentage of trades executed =  12.592983072687868 %
#   Volume:
# total usd volume traded on feedlot=  88026652.32632971
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.726520257542925 %
#   Surplus:
# total surplus 1873509.216950785
# surplus percentage of volume 0.12188000111362847 %
#   LP metrics:
# fees collected 4841465.877948139
# ending reserves token1 37234509.99515758
# ending reserves token2 24710.088537104257
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.056
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2119
# total_trades=  17073
# percentage of trades executed =  12.411409828383999 %
#   Volume:
# total usd volume traded on feedlot=  86888465.60991248
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.652476213879118 %
#   Surplus:
# total surplus 1789526.438154164
# surplus percentage of volume 0.11641655258578136 %
#   LP metrics:
# fees collected 4865754.074155102
# ending reserves token1 37219250.11452572
# ending reserves token2 24671.001164713904
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.057
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2126
# total_trades=  17073
# percentage of trades executed =  12.452410238388097 %
#   Volume:
# total usd volume traded on feedlot=  87758140.3333377
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.709052373366644 %
#   Surplus:
# total surplus 1817008.620287839
# surplus percentage of volume 0.11820438920742805 %
#   LP metrics:
# fees collected 5002213.999000244
# ending reserves token1 37233184.73328458
# ending reserves token2 24681.600604936946
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.058
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2078
# total_trades=  17073
# percentage of trades executed =  12.171264569788555 %
#   Volume:
# total usd volume traded on feedlot=  86789985.97376832
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.646069681125329 %
#   Surplus:
# total surplus 1759432.5329231413
# surplus percentage of volume 0.1144588119086151 %
#   LP metrics:
# fees collected 5033819.186478559
# ending reserves token1 37235950.77341682
# ending reserves token2 24643.19930857255
# dfs 17073 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 2854.1551133713538
#     x= 50000000
#     y= 17518.319087058848
#     k= 875915954352.9424
#     s= 0.059
# ******** Results Data **********************
#   Inputs:
# token1 USDC
# token2 WETH
# initial Reserves 50000000
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -378 days, 16:53:00
#   Trades:
# trades executed =  2069
# total_trades=  17073
# percentage of trades executed =  12.118549756926141 %
#   Volume:
# total usd volume traded on feedlot=  86229394.87059404
# total USD volume traded on COW 1537175254.2109973
# volume percentage =  5.6096007683166835 %
#   Surplus:
# total surplus 1753505.7217299296
# surplus percentage of volume 0.11407324681595728 %
#   LP metrics:
# fees collected 5087534.2973650545
# ending reserves token1 37251678.387611
# ending reserves token2 24627.398033187234
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14931/683128336.py in <cell line: 27>()
#      25
#      26
# ---> 27 df_results_USDC_WETH_fee = pd.DataFrame({'starting reserves': x_fee, '% of trades executed': y1_fee, '% of volume executed': y2_fee, 'total_surplus': y3})
#      28 pd.set_option('display.float_format', lambda x: '%.4f' % x)
#      29
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     661         elif isinstance(data, dict):
#     662             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664         elif isinstance(data, ma.MaskedArray):
#     665             import numpy.ma.mrecords as mrecords
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# --> 493     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     494
#     495
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         # figure out the index, if necessary
#     117         if index is None:
# --> 118             index = _extract_index(arrays)
#     119         else:
#     120             index = ensure_index(index)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py in _extract_index(data)
#     664             lengths = list(set(raw_lengths))
#     665             if len(lengths) > 1:
# --> 666                 raise ValueError("All arrays must be of the same length")
#     667
#     668             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
import matplotlib.pyplot as plt
import os

# Create a directory to store the diagrams
if not os.path.exists("diagrams"):
    os.makedirs("diagrams")

# Plot3 : Percentage of Trades/Volume vs. Fee level
fig, ax = plt.subplots()
ax.plot(x_fee, y1_fee, label='Percentage of Trades')
ax.plot(x_fee, y2_fee, label='Percentage of Volume')
ax.set_xlabel('Fee level')
ax.set_title('USDC-WETH; Executions vs fees')
ax.legend()
# Save the plot as a PDF file
plt.savefig("diagrams/plot3_executions_vs_fees.pdf", bbox_inches='tight')
# Display the plot
plt.show()

# Plot 4: Total Surplus vs. Fee level
fig, ax = plt.subplots()
ax.plot(x_fee, y3_fee)
ax.set_xlabel('Fee level')
ax.set_ylabel('Total Surplus')
ax.set_title('USDC-WETH; variable fees; % surplus($)')
ax.ticklabel_format(style='plain', axis='x')
# Save the plot as a PDF file
plt.savefig("diagrams/plot4_surplus_vs_fees.pdf", bbox_inches='tight')
# Display the plot
plt.show()

# %% [markdown]
# ## 5. DAI-USDC – comparison with real UNIv2 returns
#
# Where studying a stable pool might not make too much sense on UNIv2 especially since there are more efficient pools on UNIv3 and on Curve for stable swaps, the study below still highlights the surplus numbers for a popular stable swap pair such as DAI-USDC.
#
# Fee level was chosen as 0.0% for this run to isolate the effects of better pricing since stables as sensitive to fees.

# %% [markdown]
# **5.1 get UNI returns**

# %%
len(df)
# Out:
# 331802

# %%
tokena = 'DAI'
tokenb = 'USDC'

# %%
dai_usdc_df = df[((df.buy_token_symbol == tokena) & (df.sell_token_symbol == tokenb)) | ((df.sell_token_symbol == tokena) & (df.buy_token_symbol == tokenb))]

# %%
dai_usdc_df = dai_usdc_df[dai_usdc_df['trades_sellAmountUsd'] > 250]
dai_usdc_df.sort_values(by='trades_timestamp', ascending=False, inplace=True)

# %%
len(dai_usdc_df)
# Out:
# 6358

# %%
# last trade
dai_usdc_df.iloc[0,1]
# Out:
# 1678696091

# %%
dai_usdc_df.iloc[0,4]
# Out:
# '0xa3fc82535841fe7980e3a29aa8ab641f5c41effd6a21c20ea764f45c49ce9790'

# %%
#Block number last trade = 16817883
#https://etherscan.io/tx/0xa3fc82535841fe7980e3a29aa8ab641f5c41effd6a21c20ea764f45c49ce9790

# %%
# first trade
dai_usdc_df.iloc[-1,1]
# Out:
# 1646123362

# %%
dai_usdc_df.iloc[-1,4]
# Out:
# '0xe9d15d88a336fcd32cf6ac9fa6da6f726e8f3a953bd00e4b208181e74e74830c'

# %%
# Block number first trade  = 14300014
#https://etherscan.io/tx/0xe9d15d88a336fcd32cf6ac9fa6da6f726e8f3a953bd00e4b208181e74e74830c

# %%
days = (datetime.utcfromtimestamp(dai_usdc_df.iloc[0,1]) - datetime.utcfromtimestamp(dai_usdc_df.iloc[-1,1]))
days
# Out:
# datetime.timedelta(days=376, seconds=86329)

# %% [markdown]
# MANUAL WORK
#
# UNIv2 data obtained from Etherscan: Reserves values + LP token supply
#
# DAI-USDC pool address: 0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5
# DAI Address: 0x6b175474e89094c44da98b954eedeac495271d0f
# USDC Address: 0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
#
# https://etherscan.io/tokencheck-tool?t=0xB4e16d0168e52d35CaCD2c6185b44281Ec28C9Dc

# %%
# Univ2 data at COW data last trade:
# UNIV2 USDC_WETH Token supply @ 16817883 = 11.510319181795390492  

# UNIV2 DAI Reserves = 12,977,224.344432413558677259
# UNIV2 USDC reserves = 12,982,573.818835

# %%
# Univ2 data at COW data first trade
# Block number =  14300014

# UNIV2 USDC_WETH Token supply @14300014 = 31.151563625852901815 

# UNIV2 DAI Reserves = 34,989,337.70919416559373272 DAI
# UNIV2 USDC reserves = 35,057,275.278217 USDC

# %%
# LP value at period end. TVL/ LP token supply
LP_token_value_end_DU = (12977224.344432413558677259+12982573.818835) / 11.510319181795390492 
LP_token_value_end_DU
# Out:
# 2255349.98232935

# %%
LP_token_value_start_DU = (34989337.70919416559373272+35057275.278217 ) / 31.151563625852901815 
LP_token_value_start_DU
# Out:
# 2248574.54440197

# %%
# total return for period 
r_DU = LP_token_value_end_DU/LP_token_value_start_DU
r_DU
# Out:
# 1.0030132147249677

# %%
# number of days: 
annual_DU = ((r_DU -1) * 365/376 )+1
annual_DU
# Out:
# 1.0029250621665244

# %%
# get volume 

uni_ds = Streamer('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2')

# %%
date_gt = dai_usdc_df.iloc[-1,1]
date_gt
# Out:
# 1646123362

# %%
# date_gt = weth_usdc_df.iloc[-1,1] which is 1646097479 for this simulation. Change it it accordingly below to 
# obtain the right corresponding UNIv2 volume data. 

# query COW schema: trades
uni_pool_fp = uni_ds.queryDict.get('pairDayDatas')

# trades query path that gets token a -> token b trades. Query on query_size. 
uni_pool_qp = uni_pool_fp(
    first=2000,
    orderBy='date',
    orderDirection='desc',
    where = {
    'date_gt': 1646123362,
    'pairAddress': "0xae461ca67b15dc8dc81ce7615e0320da1a9ab8d5"
    }
)

# run query
uni_pool_df_DU = uni_ds.runQuery(uni_pool_qp)
# Out:
# FIELD - pairDayDatas

# %%
len(uni_pool_df_DU)
# Out:
# 380

# %%
# Total trade volume on UNI pool - USDC
total_uni_volume_DU = uni_pool_df_DU['pairDayDatas_dailyVolumeUSD'].sum()
total_uni_volume_DU
# Out:
# 75050707.42513612

# %% [markdown]
# **5.2 get Feedlot returns**

# %%
# run simulation with starting DAI reserves = 34989337.70919416559373272  as per the UNIv2 pool 

surplus_analysis('DAI','USDC', 34989337.70919416559373272 , 0.00)
# Out:
# /tmp/ipykernel_14931/1021432584.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfs.sort_values(by='trades_timestamp', ascending=True, inplace=True)
# dfs 6358 trades in sample
# price column added
# ****** Feedlot AMM Initial State **********
# AMM Initialized with the following parameters:
#     initilization price = 1.0019219305802831
#     x= 34989337.70919417
#     y= 34922219.62736098
#     k= 1221905336096382.2
#     s= 0.0
# ******** Results Data **********************
#   Inputs:
# token1 DAI
# token2 USDC
# initial Reserves 34989337.70919417
# fee rate
#   dataset timeframe:
# starting date 2022-03-01
# ending date 2023-03-13
# days -377 days, 0:01:11
#   Trades:
# trades executed =  1469
# total_trades=  6358
# percentage of trades executed =  23.10474992135892 %
#   Volume:
# total usd volume traded on feedlot=  9812381.096017778
# total USD volume traded on COW 1032273040.3586895
# volume percentage =  0.9505606280881089 %
#   Surplus:
# total surplus 17648.94019421747
# surplus percentage of volume 0.0017097162770118356 %
#   LP metrics:
# fees collected 0.0
# ending reserves token1 34972588.90326044
# ending reserves token2 34956610.23096194
# (23.10474992135892, 0.9505606280881089, 17648.94019421747)

# %%
# ending value + the fees 
ending_value_DU = 34972588.90326044 + 34956610.23096194
ending_value_DU
# Out:
# 69929199.13422239

# %%
starting_value_DU = 34989337.70919417 + 34922219.62736098 
starting_value_DU
# Out:
# 69911557.33655515

# %%
r_feedlot_DU = ending_value_DU / starting_value_DU
r_feedlot_DU
# Out:
# 1.0002523445098255

# %%
(r_feedlot_DU-1)*100
# Out:
# 0.025234450982547507

# %% [markdown]
# **Results Summary**
# Time period: 377 days
# Total COW trade population: 331,802
# of which DAI-USDC : 6,358
# Total COW volume trades: 1,032,273,040
# Total UNI volume trades: 74,940,235
# trades % wouldve executed feedlot: 23.1%
# volume % would executed feedlot: 0.95%
# real UNI LP return over period: 0.30%
# Feedlot LP return over period: 0.025%
# Total surplus: 5,672 (~0.000%)

# %% [markdown]
# **Discussion**
#
# The results show that for a stable swap pair, there is no surplus to be captured by running a surplus capturing pool for stable swaps using a CPMM. Where the model might be improved by using a CFMM that has a flatter curve similar to how Curve uses,and would make an excellent follow up study. However, preliminary results rules out the benefit of running a surplus capturing CPMM pool for stable swaps.
