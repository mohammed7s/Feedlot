# %% [markdown]
# # Cow + Univ3 DataPipeline

# %% [markdown]
# ### Setup Jupyter Environment

# %%
from datastreams.datastream import Streamer

# import concurrent.futures
import os
import pandas as pd
import polars as pl

# These commands enlarge the column size of the dataframe so things like 0x... are not truncated
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %% [markdown]
# ### Cowswap Trades

# %%
# instantiate Streamer class. Note that we need two separate streamer classes, otherwise the queries will be overwritten. 
cow_ds1 = Streamer('https://api.thegraph.com/subgraphs/name/cowprotocol/cow')
cow_ds2 = Streamer('https://api.thegraph.com/subgraphs/name/cowprotocol/cow')

# %%
# DEFINE TIMESTAMP HERE. Timstamp is used for replication quality assurance purposes.
timestamp = 1677891498 # current block timestamp is around 1677891498 on March 3rd, 2023 8:06PM

# define ethereum token addresses here to be used in cowswap trades query filter
weth_addr = "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"
usdc_addr = "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"

# we set a fixed query size number. The Cow settlements and Uniswap swaps query are multiples larger than this initial query size.
query_size = 10000000

#Filter size - We filter trades out that are smaller than $1000 USD size
filter_usd = 1000

# %%
token_addr_list = [weth_addr, usdc_addr]

# %%
# We need to make two queries to the cow schema to get all the trades that match weth/usdc and usdc/weth.
trades_weth_usdc_fp = cow_ds1.queryDict.get('trades')
trades_usdc_weth_fp = cow_ds2.queryDict.get('trades')

# trades query path that gets token a -> token b trades
trades_weth_usdc_qp = trades_weth_usdc_fp(
    first=query_size,
    orderBy='timestamp',
    orderDirection='desc',
    where = {
    'timestamp_lt': timestamp, 
    'buyAmountUsd_gt': filter_usd, 
    'sellAmountUsd_gt': filter_usd, 
    "sellToken_in": token_addr_list, 
    "buyToken_in": token_addr_list
    }
)

# trades query path that gets token b -> token a trades
trades_usdc_weth_qp = trades_usdc_weth_fp(
    first=query_size,
    orderBy='timestamp',
    orderDirection='desc',
    where = {
    'timestamp_lt': timestamp, 
    'buyAmountUsd_gt': filter_usd, 
    'sellAmountUsd_gt': filter_usd, 
    "sellToken_in": token_addr_list, 
    "buyToken_in": token_addr_list
    }
)

# run query
trades_weth_usdc_df = cow_ds1.runQuery(trades_weth_usdc_qp)
trades_usdc_weth_df = cow_ds2.runQuery(trades_usdc_weth_qp)
# Out:
# FIELD - trades
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb Cell 8 in <cell line: 34>()
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a> trades_usdc_weth_qp = trades_usdc_weth_fp(
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=20'>21</a>     first=query_size,
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a>     orderBy='timestamp',
#    (...)
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=29'>30</a>     }
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=30'>31</a> )
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a> # run query
# ---> <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=33'>34</a> trades_weth_usdc_df = cow_ds1.runQuery(trades_weth_usdc_qp)
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X10sZmlsZQ%3D%3D?line=34'>35</a> trades_usdc_weth_df = cow_ds2.runQuery(trades_usdc_weth_qp)
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:209, in Streamer.runQuery(self, query_field)
#     200 """
#     201 runQuery() executes the Subgrounds query_df() function to query the Subgraph and return a DataFrame.
#     202
#    (...)
#     205 :return: DataFrame object
#     206 """
#     207 print(f'FIELD - {query_field}')
# --> 209 df = self.sub.query_df(query_field)
#     210 # add endpoint column to df
#     211 # get the values to the right of the last / in the self.endpoint
#     212 endpoint = self.endpoint.split('/')[-1]
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:380, in Subgrounds.query_df(self, fpaths, columns, concat, pagination_strategy)
#     309 """Same as :func:`Subgrounds.query` but formats the response data into a
#     310 Pandas DataFrame. If the response data cannot be flattened to a single query
#     311 (e.g.: when querying multiple list fields that return different entities),
#    (...)
#     372     9       1643213196  2610.686563
#     373 """
#     374 fpaths = list(
#     375   [fpaths]
#     376   | traverse
#     377   | map(FieldPath._auto_select)
#     378   | traverse
#     379 )
# --> 380 json_data = self.query_json(fpaths, pagination_strategy=pagination_strategy)
#     381 return df_of_json(json_data, fpaths, columns, concat)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:274, in Subgrounds.query_json(self, fpaths, pagination_strategy)
#     267 fpaths = list(
#     268   [fpaths]
#     269   | traverse
#     270   | map(FieldPath._auto_select)
#     271   | traverse
#     272 )
#     273 req = self.mk_request(fpaths)
# --> 274 return self.execute(req, pagination_strategy=pagination_strategy)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:199, in Subgrounds.execute(self, req, pagination_strategy)
#     189   match transforms:
#     190     case []:
#     191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#    (...)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False  # Suppress mypy missing return statement warning
# --> 199 return transform_req(self.global_transforms, req)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req(transforms, req)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req.<locals>.<lambda>(doc)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:180, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
# --> 180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
#     183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:172, in Subgrounds.execute.<locals>.execute_document(doc)
#     167 subgraph: Subgraph = next(
#     168   self.subgraphs.values()
#     169   | where(lambda sg: sg._url == doc.url)
#     170 )
#     171 if pagination_strategy is not None and subgraph._is_subgraph:
# --> 172   return paginate(subgraph._schema, doc, pagination_strategy=pagination_strategy)
#     173 else:
#     174   return client.query(doc.url, doc.graphql, variables=doc.variables)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:79, in paginate(schema, doc, pagination_strategy)
#      77 while True:
#      78   try:
# ---> 79     page_data = client.query(
#      80       url=doc.url,
#      81       query_str=doc.graphql,
#      82       variables=doc.variables | args
#      83     )
#      84     data = merge(data, page_data)
#      85     doc, args = strategy.step(page_data)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/client.py:154, in query(url, query_str, variables)
#     134 """ Executes the GraphQL query :attr:`query_str` with variables
#     135 :attr:`variables` against the API served at :attr:`url` and returns the
#     136 response data. In case of errors, an exception containing the error message is
#    (...)
#     149   dict[str, Any]: Response data
#     150 """
#     151 logger.info(
#     152   f'client.query: url = {url}, variables = {variables}\n{query_str}'
#     153 )
# --> 154 resp = requests.post(
#     155   url,
#     156   json=(
#     157     {'query': query_str}
#     158     if variables == {}
#     159     else {'query': query_str, 'variables': variables}
#     160   ),
#     161   headers={'Content-Type': 'application/json'}
#     162 ).json()
#     164 try:
#     165   return resp['data']
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# combine the trades queries together
trades_df = pd.concat([trades_weth_usdc_df, trades_usdc_weth_df])

# %%
print(f'query returned {len(trades_df)} rows')
# Out:
# query returned 43696 rows

# %%
# verify the query results to ensure that only two tokens were queried.
trades_df['trades_buyToken_id'].unique()
# Out:
# array(['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#        '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'], dtype=object)

# %%
# replace addresses with symbols
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].replace(weth_addr, 'WETH')
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].replace(usdc_addr, 'USDC')

trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].replace(weth_addr, 'WETH')
trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].replace(usdc_addr, 'USDC')

# %%
trades_df.columns
# Out:
# Index(['trades_id', 'trades_timestamp', 'trades_gasPrice', 'trades_feeAmount',
#        'trades_txHash', 'trades_settlement_id', 'trades_buyAmount',
#        'trades_sellAmount', 'trades_sellToken_id', 'trades_buyToken_id',
#        'trades_order_id', 'trades_buyAmountEth', 'trades_sellAmountEth',
#        'trades_buyAmountUsd', 'trades_sellAmountUsd', 'endpoint'],
#       dtype='object')

# %% [markdown]
# ### Cowswap Trades-Settlement Merge

# %%
# do same query methood but instead of timestamps, use trades_settlement_id

# get unique trades_settlement_id list
trades_settlement_id_list = trades_df['trades_settlement_id'].unique()

# define field path
settlements_fp = cow_ds1.queryDict.get('settlements')

# %%
settlement_df_list = []

# %%
for i in range(0, len(trades_settlement_id_list)): # inner loop through cowswap timestamps
    print(f'round {i} of {len(trades_settlement_id_list)}')
    # define the query path
    settlements_qp = settlements_fp(
        first=query_size * 3,
        orderBy='firstTradeTimestamp',
        orderDirection='desc',
        where = {'txHash': trades_settlement_id_list[i]} 
        )
    
    # run query
    df = cow_ds1.runQuery(settlements_qp)

    if df.empty:
        print('empty')
        continue
    else:
        settlement_df_list.append(df)
# Out:
# round 0 of 20628
# FIELD - settlements
# round 1 of 20628
# FIELD - settlements
# round 2 of 20628
# FIELD - settlements
# round 3 of 20628
# FIELD - settlements
# round 4 of 20628
# FIELD - settlements
# round 5 of 20628
# FIELD - settlements
# round 6 of 20628
# FIELD - settlements
# round 7 of 20628
# FIELD - settlements
# round 8 of 20628
# FIELD - settlements
# round 9 of 20628
# FIELD - settlements
# round 10 of 20628
# FIELD - settlements
# round 11 of 20628
# FIELD - settlements
# round 12 of 20628
# FIELD - settlements
# round 13 of 20628
# FIELD - settlements
# round 14 of 20628
# FIELD - settlements
# round 15 of 20628
# FIELD - settlements
# round 16 of 20628
# FIELD - settlements
# round 17 of 20628
# FIELD - settlements
# round 18 of 20628
# FIELD - settlements
# round 19 of 20628
# FIELD - settlements
# round 20 of 20628
# FIELD - settlements
# round 21 of 20628
# FIELD - settlements
# round 22 of 20628
# FIELD - settlements
# round 23 of 20628
# FIELD - settlements
# round 24 of 20628
# FIELD - settlements
# round 25 of 20628
# FIELD - settlements
# round 26 of 20628
# FIELD - settlements
# round 27 of 20628
# FIELD - settlements
# round 28 of 20628
# FIELD - settlements
# round 29 of 20628
# FIELD - settlements
# round 30 of 20628
# FIELD - settlements
# round 31 of 20628
# FIELD - settlements
# round 32 of 20628
# FIELD - settlements
# round 33 of 20628
# FIELD - settlements
# round 34 of 20628
# FIELD - settlements
# round 35 of 20628
# FIELD - settlements
# round 36 of 20628
# FIELD - settlements
# round 37 of 20628
# FIELD - settlements
# round 38 of 20628
# FIELD - settlements
# round 39 of 20628
# FIELD - settlements
# round 40 of 20628
# FIELD - settlements
# round 41 of 20628
# FIELD - settlements
# round 42 of 20628
# FIELD - settlements
# round 43 of 20628
# FIELD - settlements
# round 44 of 20628
# FIELD - settlements
# round 45 of 20628
# FIELD - settlements
# round 46 of 20628
# FIELD - settlements
# round 47 of 20628
# FIELD - settlements
# round 48 of 20628
# FIELD - settlements
# round 49 of 20628
# FIELD - settlements
# round 50 of 20628
# FIELD - settlements
# round 51 of 20628
# FIELD - settlements
# round 52 of 20628
# FIELD - settlements
# round 53 of 20628
# FIELD - settlements
# round 54 of 20628
# FIELD - settlements
# round 55 of 20628
# FIELD - settlements
# round 56 of 20628
# FIELD - settlements
# round 57 of 20628
# FIELD - settlements
# round 58 of 20628
# FIELD - settlements
# round 59 of 20628
# FIELD - settlements
# round 60 of 20628
# FIELD - settlements
# round 61 of 20628
# FIELD - settlements
# round 62 of 20628
# FIELD - settlements
# round 63 of 20628
# FIELD - settlements
# round 64 of 20628
# FIELD - settlements
# round 65 of 20628
# FIELD - settlements
# round 66 of 20628
# FIELD - settlements
# round 67 of 20628
# FIELD - settlements
# round 68 of 20628
# FIELD - settlements
# round 69 of 20628
# FIELD - settlements
# round 70 of 20628
# FIELD - settlements
# round 71 of 20628
# FIELD - settlements
# round 72 of 20628
# FIELD - settlements
# round 73 of 20628
# FIELD - settlements
# round 74 of 20628
# FIELD - settlements
# round 75 of 20628
# FIELD - settlements
# round 76 of 20628
# FIELD - settlements
# round 77 of 20628
# FIELD - settlements
# round 78 of 20628
# FIELD - settlements
# round 79 of 20628
# FIELD - settlements
# round 80 of 20628
# FIELD - settlements
# round 81 of 20628
# FIELD - settlements
# round 82 of 20628
# FIELD - settlements
# round 83 of 20628
# FIELD - settlements
# round 84 of 20628
# FIELD - settlements
# round 85 of 20628
# FIELD - settlements
# round 86 of 20628
# FIELD - settlements
# round 87 of 20628
# FIELD - settlements
# round 88 of 20628
# FIELD - settlements
# round 89 of 20628
# FIELD - settlements
# round 90 of 20628
# FIELD - settlements
# round 91 of 20628
# FIELD - settlements
# round 92 of 20628
# FIELD - settlements
# round 93 of 20628
# FIELD - settlements
# round 94 of 20628
# FIELD - settlements
# round 95 of 20628
# FIELD - settlements
# round 96 of 20628
# FIELD - settlements
# round 97 of 20628
# FIELD - settlements
# round 98 of 20628
# FIELD - settlements
# round 99 of 20628
# FIELD - settlements
# round 100 of 20628
# FIELD - settlements
# round 101 of 20628
# FIELD - settlements
# round 102 of 20628
# FIELD - settlements
# round 103 of 20628
# FIELD - settlements
# round 104 of 20628
# FIELD - settlements
# round 105 of 20628
# FIELD - settlements
# round 106 of 20628
# FIELD - settlements
# round 107 of 20628
# FIELD - settlements
# round 108 of 20628
# FIELD - settlements
# round 109 of 20628
# FIELD - settlements
# round 110 of 20628
# FIELD - settlements
# round 111 of 20628
# FIELD - settlements
# round 112 of 20628
# FIELD - settlements
# round 113 of 20628
# FIELD - settlements
# round 114 of 20628
# FIELD - settlements
# round 115 of 20628
# FIELD - settlements
# round 116 of 20628
# FIELD - settlements
# round 117 of 20628
# FIELD - settlements
# round 118 of 20628
# FIELD - settlements
# round 119 of 20628
# FIELD - settlements
# round 120 of 20628
# FIELD - settlements
# round 121 of 20628
# FIELD - settlements
# round 122 of 20628
# FIELD - settlements
# round 123 of 20628
# FIELD - settlements
# round 124 of 20628
# FIELD - settlements
# round 125 of 20628
# FIELD - settlements
# round 126 of 20628
# FIELD - settlements
# round 127 of 20628
# FIELD - settlements
# round 128 of 20628
# FIELD - settlements
# round 129 of 20628
# FIELD - settlements
# round 130 of 20628
# FIELD - settlements
# round 131 of 20628
# FIELD - settlements
# round 132 of 20628
# FIELD - settlements
# round 133 of 20628
# FIELD - settlements
# round 134 of 20628
# FIELD - settlements
# round 135 of 20628
# FIELD - settlements
# round 136 of 20628
# FIELD - settlements
# round 137 of 20628
# FIELD - settlements
# round 138 of 20628
# FIELD - settlements
# round 139 of 20628
# FIELD - settlements
# round 140 of 20628
# FIELD - settlements
# round 141 of 20628
# FIELD - settlements
# round 142 of 20628
# FIELD - settlements
# round 143 of 20628
# FIELD - settlements
# round 144 of 20628
# FIELD - settlements
# round 145 of 20628
# FIELD - settlements
# round 146 of 20628
# FIELD - settlements
# round 147 of 20628
# FIELD - settlements
# round 148 of 20628
# FIELD - settlements
# round 149 of 20628
# FIELD - settlements
# round 150 of 20628
# FIELD - settlements
# round 151 of 20628
# FIELD - settlements
# round 152 of 20628
# FIELD - settlements
# round 153 of 20628
# FIELD - settlements
# round 154 of 20628
# FIELD - settlements
# round 155 of 20628
# FIELD - settlements
# round 156 of 20628
# FIELD - settlements
# round 157 of 20628
# FIELD - settlements
# round 158 of 20628
# FIELD - settlements
# round 159 of 20628
# FIELD - settlements
# round 160 of 20628
# FIELD - settlements
# round 161 of 20628
# FIELD - settlements
# round 162 of 20628
# FIELD - settlements
# round 163 of 20628
# FIELD - settlements
# round 164 of 20628
# FIELD - settlements
# round 165 of 20628
# FIELD - settlements
# round 166 of 20628
# FIELD - settlements
# round 167 of 20628
# FIELD - settlements
# round 168 of 20628
# FIELD - settlements
# round 169 of 20628
# FIELD - settlements
# round 170 of 20628
# FIELD - settlements
# round 171 of 20628
# FIELD - settlements
# round 172 of 20628
# FIELD - settlements
# round 173 of 20628
# FIELD - settlements
# round 174 of 20628
# FIELD - settlements
# round 175 of 20628
# FIELD - settlements
# round 176 of 20628
# FIELD - settlements
# round 177 of 20628
# FIELD - settlements
# round 178 of 20628
# FIELD - settlements
# round 179 of 20628
# FIELD - settlements
# round 180 of 20628
# FIELD - settlements
# round 181 of 20628
# FIELD - settlements
# round 182 of 20628
# FIELD - settlements
# round 183 of 20628
# FIELD - settlements
# round 184 of 20628
# FIELD - settlements
# round 185 of 20628
# FIELD - settlements
# round 186 of 20628
# FIELD - settlements
# round 187 of 20628
# FIELD - settlements
# round 188 of 20628
# FIELD - settlements
# round 189 of 20628
# FIELD - settlements
# round 190 of 20628
# FIELD - settlements
# round 191 of 20628
# FIELD - settlements
# round 192 of 20628
# FIELD - settlements
# round 193 of 20628
# FIELD - settlements
# round 194 of 20628
# FIELD - settlements
# round 195 of 20628
# FIELD - settlements
# round 196 of 20628
# FIELD - settlements
# round 197 of 20628
# FIELD - settlements
# round 198 of 20628
# FIELD - settlements
# round 199 of 20628
# FIELD - settlements
# round 200 of 20628
# FIELD - settlements
# round 201 of 20628
# FIELD - settlements
# round 202 of 20628
# FIELD - settlements
# round 203 of 20628
# FIELD - settlements
# round 204 of 20628
# FIELD - settlements
# round 205 of 20628
# FIELD - settlements
# round 206 of 20628
# FIELD - settlements
# round 207 of 20628
# FIELD - settlements
# round 208 of 20628
# FIELD - settlements
# round 209 of 20628
# FIELD - settlements
# round 210 of 20628
# FIELD - settlements
# round 211 of 20628
# FIELD - settlements
# round 212 of 20628
# FIELD - settlements
# round 213 of 20628
# FIELD - settlements
# round 214 of 20628
# FIELD - settlements
# round 215 of 20628
# FIELD - settlements
# round 216 of 20628
# FIELD - settlements
# round 217 of 20628
# FIELD - settlements
# round 218 of 20628
# FIELD - settlements
# round 219 of 20628
# FIELD - settlements
# round 220 of 20628
# FIELD - settlements
# round 221 of 20628
# FIELD - settlements
# round 222 of 20628
# FIELD - settlements
# round 223 of 20628
# FIELD - settlements
# round 224 of 20628
# FIELD - settlements
# round 225 of 20628
# FIELD - settlements
# round 226 of 20628
# FIELD - settlements
# round 227 of 20628
# FIELD - settlements
# round 228 of 20628
# FIELD - settlements
# round 229 of 20628
# FIELD - settlements
# round 230 of 20628
# FIELD - settlements
# round 231 of 20628
# FIELD - settlements
# round 232 of 20628
# FIELD - settlements
# round 233 of 20628
# FIELD - settlements
# round 234 of 20628
# FIELD - settlements
# round 235 of 20628
# FIELD - settlements
# round 236 of 20628
# FIELD - settlements
# round 237 of 20628
# FIELD - settlements
# round 238 of 20628
# FIELD - settlements
# round 239 of 20628
# FIELD - settlements
# round 240 of 20628
# FIELD - settlements
# round 241 of 20628
# FIELD - settlements
# round 242 of 20628
# FIELD - settlements
# round 243 of 20628
# FIELD - settlements
# round 244 of 20628
# FIELD - settlements
# round 245 of 20628
# FIELD - settlements
# round 246 of 20628
# FIELD - settlements
# round 247 of 20628
# FIELD - settlements
# round 248 of 20628
# FIELD - settlements
# round 249 of 20628
# FIELD - settlements
# round 250 of 20628
# FIELD - settlements
# round 251 of 20628
# FIELD - settlements
# round 252 of 20628
# FIELD - settlements
# round 253 of 20628
# FIELD - settlements
# round 254 of 20628
# FIELD - settlements
# round 255 of 20628
# FIELD - settlements
# round 256 of 20628
# FIELD - settlements
# round 257 of 20628
# FIELD - settlements
# round 258 of 20628
# FIELD - settlements
# round 259 of 20628
# FIELD - settlements
# round 260 of 20628
# FIELD - settlements
# round 261 of 20628
# FIELD - settlements
# round 262 of 20628
# FIELD - settlements
# round 263 of 20628
# FIELD - settlements
# round 264 of 20628
# FIELD - settlements
# round 265 of 20628
# FIELD - settlements
# round 266 of 20628
# FIELD - settlements
# round 267 of 20628
# FIELD - settlements
# round 268 of 20628
# FIELD - settlements
# round 269 of 20628
# FIELD - settlements
# round 270 of 20628
# FIELD - settlements
# round 271 of 20628
# FIELD - settlements
# round 272 of 20628
# FIELD - settlements
# round 273 of 20628
# FIELD - settlements
# round 274 of 20628
# FIELD - settlements
# round 275 of 20628
# FIELD - settlements
# round 276 of 20628
# FIELD - settlements
# round 277 of 20628
# FIELD - settlements
# round 278 of 20628
# FIELD - settlements
# round 279 of 20628
# FIELD - settlements
# round 280 of 20628
# FIELD - settlements
# round 281 of 20628
# FIELD - settlements
# round 282 of 20628
# FIELD - settlements
# round 283 of 20628
# FIELD - settlements
# round 284 of 20628
# FIELD - settlements
# round 285 of 20628
# FIELD - settlements
# round 286 of 20628
# FIELD - settlements
# round 287 of 20628
# FIELD - settlements
# round 288 of 20628
# FIELD - settlements
# round 289 of 20628
# FIELD - settlements
# round 290 of 20628
# FIELD - settlements
# round 291 of 20628
# FIELD - settlements
# round 292 of 20628
# FIELD - settlements
# round 293 of 20628
# FIELD - settlements
# round 294 of 20628
# FIELD - settlements
# round 295 of 20628
# FIELD - settlements
# round 296 of 20628
# FIELD - settlements
# round 297 of 20628
# FIELD - settlements
# round 298 of 20628
# FIELD - settlements
# round 299 of 20628
# FIELD - settlements
# round 300 of 20628
# FIELD - settlements
# round 301 of 20628
# FIELD - settlements
# round 302 of 20628
# FIELD - settlements
# round 303 of 20628
# FIELD - settlements
# round 304 of 20628
# FIELD - settlements
# round 305 of 20628
# FIELD - settlements
# round 306 of 20628
# FIELD - settlements
# round 307 of 20628
# FIELD - settlements
# round 308 of 20628
# FIELD - settlements
# round 309 of 20628
# FIELD - settlements
# round 310 of 20628
# FIELD - settlements
# round 311 of 20628
# FIELD - settlements
# round 312 of 20628
# FIELD - settlements
# round 313 of 20628
# FIELD - settlements
# round 314 of 20628
# FIELD - settlements
# round 315 of 20628
# FIELD - settlements
# round 316 of 20628
# FIELD - settlements
# round 317 of 20628
# FIELD - settlements
# round 318 of 20628
# FIELD - settlements
# round 319 of 20628
# FIELD - settlements
# round 320 of 20628
# FIELD - settlements
# round 321 of 20628
# FIELD - settlements
# round 322 of 20628
# FIELD - settlements
# round 323 of 20628
# FIELD - settlements
# round 324 of 20628
# FIELD - settlements
# round 325 of 20628
# FIELD - settlements
# round 326 of 20628
# FIELD - settlements
# round 327 of 20628
# FIELD - settlements
# round 328 of 20628
# FIELD - settlements
# round 329 of 20628
# FIELD - settlements
# round 330 of 20628
# FIELD - settlements
# round 331 of 20628
# FIELD - settlements
# round 332 of 20628
# FIELD - settlements
# round 333 of 20628
# FIELD - settlements
# round 334 of 20628
# FIELD - settlements
# round 335 of 20628
# FIELD - settlements
# round 336 of 20628
# FIELD - settlements
# round 337 of 20628
# FIELD - settlements
# round 338 of 20628
# FIELD - settlements
# round 339 of 20628
# FIELD - settlements
# round 340 of 20628
# FIELD - settlements
# round 341 of 20628
# FIELD - settlements
# round 342 of 20628
# FIELD - settlements
# round 343 of 20628
# FIELD - settlements
# round 344 of 20628
# FIELD - settlements
# round 345 of 20628
# FIELD - settlements
# round 346 of 20628
# FIELD - settlements
# round 347 of 20628
# FIELD - settlements
# round 348 of 20628
# FIELD - settlements
# round 349 of 20628
# FIELD - settlements
# round 350 of 20628
# FIELD - settlements
# round 351 of 20628
# FIELD - settlements
# round 352 of 20628
# FIELD - settlements
# round 353 of 20628
# FIELD - settlements
# round 354 of 20628
# FIELD - settlements
# round 355 of 20628
# FIELD - settlements
# round 356 of 20628
# FIELD - settlements
# round 357 of 20628
# FIELD - settlements
# round 358 of 20628
# FIELD - settlements
# round 359 of 20628
# FIELD - settlements
# round 360 of 20628
# FIELD - settlements
# round 361 of 20628
# FIELD - settlements
# round 362 of 20628
# FIELD - settlements
# round 363 of 20628
# FIELD - settlements
# round 364 of 20628
# FIELD - settlements
# round 365 of 20628
# FIELD - settlements
# round 366 of 20628
# FIELD - settlements
# round 367 of 20628
# FIELD - settlements
# round 368 of 20628
# FIELD - settlements
# round 369 of 20628
# FIELD - settlements
# round 370 of 20628
# FIELD - settlements
# round 371 of 20628
# FIELD - settlements
# round 372 of 20628
# FIELD - settlements
# round 373 of 20628
# FIELD - settlements
# round 374 of 20628
# FIELD - settlements
# round 375 of 20628
# FIELD - settlements
# round 376 of 20628
# FIELD - settlements
# round 377 of 20628
# FIELD - settlements
# round 378 of 20628
# FIELD - settlements
# round 379 of 20628
# FIELD - settlements
# round 380 of 20628
# FIELD - settlements
# round 381 of 20628
# FIELD - settlements
# round 382 of 20628
# FIELD - settlements
# round 383 of 20628
# FIELD - settlements
# round 384 of 20628
# FIELD - settlements
# round 385 of 20628
# FIELD - settlements
# round 386 of 20628
# FIELD - settlements
# round 387 of 20628
# FIELD - settlements
# round 388 of 20628
# FIELD - settlements
# round 389 of 20628
# FIELD - settlements
# round 390 of 20628
# FIELD - settlements
# round 391 of 20628
# FIELD - settlements
# round 392 of 20628
# FIELD - settlements
# round 393 of 20628
# FIELD - settlements
# round 394 of 20628
# FIELD - settlements
# round 395 of 20628
# FIELD - settlements
# round 396 of 20628
# FIELD - settlements
# round 397 of 20628
# FIELD - settlements
# round 398 of 20628
# FIELD - settlements
# round 399 of 20628
# FIELD - settlements
# round 400 of 20628
# FIELD - settlements
# round 401 of 20628
# FIELD - settlements
# round 402 of 20628
# FIELD - settlements
# round 403 of 20628
# FIELD - settlements
# round 404 of 20628
# FIELD - settlements
# round 405 of 20628
# FIELD - settlements
# round 406 of 20628
# FIELD - settlements
# round 407 of 20628
# FIELD - settlements
# round 408 of 20628
# FIELD - settlements
# round 409 of 20628
# FIELD - settlements
# round 410 of 20628
# FIELD - settlements
# round 411 of 20628
# FIELD - settlements
# round 412 of 20628
# FIELD - settlements
# round 413 of 20628
# FIELD - settlements
# round 414 of 20628
# FIELD - settlements
# round 415 of 20628
# FIELD - settlements
# round 416 of 20628
# FIELD - settlements
# round 417 of 20628
# FIELD - settlements
# round 418 of 20628
# FIELD - settlements
# round 419 of 20628
# FIELD - settlements
# round 420 of 20628
# FIELD - settlements
# round 421 of 20628
# FIELD - settlements
# round 422 of 20628
# FIELD - settlements
# round 423 of 20628
# FIELD - settlements
# round 424 of 20628
# FIELD - settlements
# round 425 of 20628
# FIELD - settlements
# round 426 of 20628
# FIELD - settlements
# round 427 of 20628
# FIELD - settlements
# round 428 of 20628
# FIELD - settlements
# round 429 of 20628
# FIELD - settlements
# round 430 of 20628
# FIELD - settlements
# round 431 of 20628
# FIELD - settlements
# round 432 of 20628
# FIELD - settlements
# round 433 of 20628
# FIELD - settlements
# round 434 of 20628
# FIELD - settlements
# round 435 of 20628
# FIELD - settlements
# round 436 of 20628
# FIELD - settlements
# round 437 of 20628
# FIELD - settlements
# round 438 of 20628
# FIELD - settlements
# round 439 of 20628
# FIELD - settlements
# round 440 of 20628
# FIELD - settlements
# round 441 of 20628
# FIELD - settlements
# round 442 of 20628
# FIELD - settlements
# round 443 of 20628
# FIELD - settlements
# round 444 of 20628
# FIELD - settlements
# round 445 of 20628
# FIELD - settlements
# round 446 of 20628
# FIELD - settlements
# round 447 of 20628
# FIELD - settlements
# round 448 of 20628
# FIELD - settlements
# round 449 of 20628
# FIELD - settlements
# round 450 of 20628
# FIELD - settlements
# round 451 of 20628
# FIELD - settlements
# round 452 of 20628
# FIELD - settlements
# round 453 of 20628
# FIELD - settlements
# round 454 of 20628
# FIELD - settlements
# round 455 of 20628
# FIELD - settlements
# round 456 of 20628
# FIELD - settlements
# round 457 of 20628
# FIELD - settlements
# round 458 of 20628
# FIELD - settlements
# round 459 of 20628
# FIELD - settlements
# round 460 of 20628
# FIELD - settlements
# round 461 of 20628
# FIELD - settlements
# round 462 of 20628
# FIELD - settlements
# round 463 of 20628
# FIELD - settlements
# round 464 of 20628
# FIELD - settlements
# round 465 of 20628
# FIELD - settlements
# round 466 of 20628
# FIELD - settlements
# round 467 of 20628
# FIELD - settlements
# round 468 of 20628
# FIELD - settlements
# round 469 of 20628
# FIELD - settlements
# round 470 of 20628
# FIELD - settlements
# round 471 of 20628
# FIELD - settlements
# round 472 of 20628
# FIELD - settlements
# round 473 of 20628
# FIELD - settlements
# round 474 of 20628
# FIELD - settlements
# round 475 of 20628
# FIELD - settlements
# round 476 of 20628
# FIELD - settlements
# round 477 of 20628
# FIELD - settlements
# round 478 of 20628
# FIELD - settlements
# round 479 of 20628
# FIELD - settlements
# round 480 of 20628
# FIELD - settlements
# round 481 of 20628
# FIELD - settlements
# round 482 of 20628
# FIELD - settlements
# round 483 of 20628
# FIELD - settlements
# round 484 of 20628
# FIELD - settlements
# round 485 of 20628
# FIELD - settlements
# round 486 of 20628
# FIELD - settlements
# round 487 of 20628
# FIELD - settlements
# round 488 of 20628
# FIELD - settlements
# round 489 of 20628
# FIELD - settlements
# round 490 of 20628
# FIELD - settlements
# round 491 of 20628
# FIELD - settlements
# round 492 of 20628
# FIELD - settlements
# round 493 of 20628
# FIELD - settlements
# round 494 of 20628
# FIELD - settlements
# round 495 of 20628
# FIELD - settlements
# round 496 of 20628
# FIELD - settlements
# round 497 of 20628
# FIELD - settlements
# round 498 of 20628
# FIELD - settlements
# round 499 of 20628
# FIELD - settlements
# round 500 of 20628
# FIELD - settlements
# round 501 of 20628
# FIELD - settlements
# round 502 of 20628
# FIELD - settlements
# round 503 of 20628
# FIELD - settlements
# round 504 of 20628
# FIELD - settlements
# round 505 of 20628
# FIELD - settlements
# round 506 of 20628
# FIELD - settlements
# round 507 of 20628
# FIELD - settlements
# round 508 of 20628
# FIELD - settlements
# round 509 of 20628
# FIELD - settlements
# round 510 of 20628
# FIELD - settlements
# round 511 of 20628
# FIELD - settlements
# round 512 of 20628
# FIELD - settlements
# round 513 of 20628
# FIELD - settlements
# round 514 of 20628
# FIELD - settlements
# round 515 of 20628
# FIELD - settlements
# round 516 of 20628
# FIELD - settlements
# round 517 of 20628
# FIELD - settlements
# round 518 of 20628
# FIELD - settlements
# round 519 of 20628
# FIELD - settlements
# round 520 of 20628
# FIELD - settlements
# round 521 of 20628
# FIELD - settlements
# round 522 of 20628
# FIELD - settlements
# round 523 of 20628
# FIELD - settlements
# round 524 of 20628
# FIELD - settlements
# round 525 of 20628
# FIELD - settlements
# round 526 of 20628
# FIELD - settlements
# round 527 of 20628
# FIELD - settlements
# round 528 of 20628
# FIELD - settlements
# round 529 of 20628
# FIELD - settlements
# round 530 of 20628
# FIELD - settlements
# round 531 of 20628
# FIELD - settlements
# round 532 of 20628
# FIELD - settlements
# round 533 of 20628
# FIELD - settlements
# round 534 of 20628
# FIELD - settlements
# round 535 of 20628
# FIELD - settlements
# round 536 of 20628
# FIELD - settlements
# round 537 of 20628
# FIELD - settlements
# round 538 of 20628
# FIELD - settlements
# round 539 of 20628
# FIELD - settlements
# round 540 of 20628
# FIELD - settlements
# round 541 of 20628
# FIELD - settlements
# round 542 of 20628
# FIELD - settlements
# round 543 of 20628
# FIELD - settlements
# round 544 of 20628
# FIELD - settlements
# round 545 of 20628
# FIELD - settlements
# round 546 of 20628
# FIELD - settlements
# round 547 of 20628
# FIELD - settlements
# round 548 of 20628
# FIELD - settlements
# round 549 of 20628
# FIELD - settlements
# round 550 of 20628
# FIELD - settlements
# round 551 of 20628
# FIELD - settlements
# round 552 of 20628
# FIELD - settlements
# round 553 of 20628
# FIELD - settlements
# round 554 of 20628
# FIELD - settlements
# round 555 of 20628
# FIELD - settlements
# round 556 of 20628
# FIELD - settlements
# round 557 of 20628
# FIELD - settlements
# round 558 of 20628
# FIELD - settlements
# round 559 of 20628
# FIELD - settlements
# round 560 of 20628
# FIELD - settlements
# round 561 of 20628
# FIELD - settlements
# round 562 of 20628
# FIELD - settlements
# round 563 of 20628
# FIELD - settlements
# round 564 of 20628
# FIELD - settlements
# round 565 of 20628
# FIELD - settlements
# round 566 of 20628
# FIELD - settlements
# round 567 of 20628
# FIELD - settlements
# round 568 of 20628
# FIELD - settlements
# round 569 of 20628
# FIELD - settlements
# round 570 of 20628
# FIELD - settlements
# round 571 of 20628
# FIELD - settlements
# round 572 of 20628
# FIELD - settlements
# round 573 of 20628
# FIELD - settlements
# round 574 of 20628
# FIELD - settlements
# round 575 of 20628
# FIELD - settlements
# round 576 of 20628
# FIELD - settlements
# round 577 of 20628
# FIELD - settlements
# round 578 of 20628
# FIELD - settlements
# round 579 of 20628
# FIELD - settlements
# round 580 of 20628
# FIELD - settlements
# round 581 of 20628
# FIELD - settlements
# round 582 of 20628
# FIELD - settlements
# round 583 of 20628
# FIELD - settlements
# round 584 of 20628
# FIELD - settlements
# round 585 of 20628
# FIELD - settlements
# round 586 of 20628
# FIELD - settlements
# round 587 of 20628
# FIELD - settlements
# round 588 of 20628
# FIELD - settlements
# round 589 of 20628
# FIELD - settlements
# round 590 of 20628
# FIELD - settlements
# round 591 of 20628
# FIELD - settlements
# round 592 of 20628
# FIELD - settlements
# round 593 of 20628
# FIELD - settlements
# round 594 of 20628
# FIELD - settlements
# round 595 of 20628
# FIELD - settlements
# round 596 of 20628
# FIELD - settlements
# round 597 of 20628
# FIELD - settlements
# round 598 of 20628
# FIELD - settlements
# round 599 of 20628
# FIELD - settlements
# round 600 of 20628
# FIELD - settlements
# round 601 of 20628
# FIELD - settlements
# round 602 of 20628
# FIELD - settlements
# round 603 of 20628
# FIELD - settlements
# round 604 of 20628
# FIELD - settlements
# round 605 of 20628
# FIELD - settlements
# round 606 of 20628
# FIELD - settlements
# round 607 of 20628
# FIELD - settlements
# round 608 of 20628
# FIELD - settlements
# round 609 of 20628
# FIELD - settlements
# round 610 of 20628
# FIELD - settlements
# round 611 of 20628
# FIELD - settlements
# round 612 of 20628
# FIELD - settlements
# round 613 of 20628
# FIELD - settlements
# round 614 of 20628
# FIELD - settlements
# round 615 of 20628
# FIELD - settlements
# round 616 of 20628
# FIELD - settlements
# round 617 of 20628
# FIELD - settlements
# round 618 of 20628
# FIELD - settlements
# round 619 of 20628
# FIELD - settlements
# round 620 of 20628
# FIELD - settlements
# round 621 of 20628
# FIELD - settlements
# round 622 of 20628
# FIELD - settlements
# round 623 of 20628
# FIELD - settlements
# round 624 of 20628
# FIELD - settlements
# round 625 of 20628
# FIELD - settlements
# round 626 of 20628
# FIELD - settlements
# round 627 of 20628
# FIELD - settlements
# round 628 of 20628
# FIELD - settlements
# round 629 of 20628
# FIELD - settlements
# round 630 of 20628
# FIELD - settlements
# round 631 of 20628
# FIELD - settlements
# round 632 of 20628
# FIELD - settlements
# round 633 of 20628
# FIELD - settlements
# round 634 of 20628
# FIELD - settlements
# round 635 of 20628
# FIELD - settlements
# round 636 of 20628
# FIELD - settlements
# round 637 of 20628
# FIELD - settlements
# round 638 of 20628
# FIELD - settlements
# round 639 of 20628
# FIELD - settlements
# round 640 of 20628
# FIELD - settlements
# round 641 of 20628
# FIELD - settlements
# round 642 of 20628
# FIELD - settlements
# round 643 of 20628
# FIELD - settlements
# round 644 of 20628
# FIELD - settlements
# round 645 of 20628
# FIELD - settlements
# round 646 of 20628
# FIELD - settlements
# round 647 of 20628
# FIELD - settlements
# round 648 of 20628
# FIELD - settlements
# round 649 of 20628
# FIELD - settlements
# round 650 of 20628
# FIELD - settlements
# round 651 of 20628
# FIELD - settlements
# round 652 of 20628
# FIELD - settlements
# round 653 of 20628
# FIELD - settlements
# round 654 of 20628
# FIELD - settlements
# round 655 of 20628
# FIELD - settlements
# round 656 of 20628
# FIELD - settlements
# round 657 of 20628
# FIELD - settlements
# round 658 of 20628
# FIELD - settlements
# round 659 of 20628
# FIELD - settlements
# round 660 of 20628
# FIELD - settlements
# round 661 of 20628
# FIELD - settlements
# round 662 of 20628
# FIELD - settlements
# round 663 of 20628
# FIELD - settlements
# round 664 of 20628
# FIELD - settlements
# round 665 of 20628
# FIELD - settlements
# round 666 of 20628
# FIELD - settlements
# round 667 of 20628
# FIELD - settlements
# round 668 of 20628
# FIELD - settlements
# round 669 of 20628
# FIELD - settlements
# round 670 of 20628
# FIELD - settlements
# round 671 of 20628
# FIELD - settlements
# round 672 of 20628
# FIELD - settlements
# round 673 of 20628
# FIELD - settlements
# round 674 of 20628
# FIELD - settlements
# round 675 of 20628
# FIELD - settlements
# round 676 of 20628
# FIELD - settlements
# round 677 of 20628
# FIELD - settlements
# round 678 of 20628
# FIELD - settlements
# round 679 of 20628
# FIELD - settlements
# round 680 of 20628
# FIELD - settlements
# round 681 of 20628
# FIELD - settlements
# round 682 of 20628
# FIELD - settlements
# round 683 of 20628
# FIELD - settlements
# round 684 of 20628
# FIELD - settlements
# round 685 of 20628
# FIELD - settlements
# round 686 of 20628
# FIELD - settlements
# round 687 of 20628
# FIELD - settlements
# round 688 of 20628
# FIELD - settlements
# round 689 of 20628
# FIELD - settlements
# round 690 of 20628
# FIELD - settlements
# round 691 of 20628
# FIELD - settlements
# round 692 of 20628
# FIELD - settlements
# round 693 of 20628
# FIELD - settlements
# round 694 of 20628
# FIELD - settlements
# round 695 of 20628
# FIELD - settlements
# round 696 of 20628
# FIELD - settlements
# round 697 of 20628
# FIELD - settlements
# round 698 of 20628
# FIELD - settlements
# round 699 of 20628
# FIELD - settlements
# round 700 of 20628
# FIELD - settlements
# round 701 of 20628
# FIELD - settlements
# round 702 of 20628
# FIELD - settlements
# round 703 of 20628
# FIELD - settlements
# round 704 of 20628
# FIELD - settlements
# round 705 of 20628
# FIELD - settlements
# round 706 of 20628
# FIELD - settlements
# round 707 of 20628
# FIELD - settlements
# round 708 of 20628
# FIELD - settlements
# round 709 of 20628
# FIELD - settlements
# round 710 of 20628
# FIELD - settlements
# round 711 of 20628
# FIELD - settlements
# round 712 of 20628
# FIELD - settlements
# round 713 of 20628
# FIELD - settlements
# round 714 of 20628
# FIELD - settlements
# round 715 of 20628
# FIELD - settlements
# round 716 of 20628
# FIELD - settlements
# round 717 of 20628
# FIELD - settlements
# round 718 of 20628
# FIELD - settlements
# round 719 of 20628
# FIELD - settlements
# round 720 of 20628
# FIELD - settlements
# round 721 of 20628
# FIELD - settlements
# round 722 of 20628
# FIELD - settlements
# round 723 of 20628
# FIELD - settlements
# round 724 of 20628
# FIELD - settlements
# round 725 of 20628
# FIELD - settlements
# round 726 of 20628
# FIELD - settlements
# round 727 of 20628
# FIELD - settlements
# round 728 of 20628
# FIELD - settlements
# round 729 of 20628
# FIELD - settlements
# round 730 of 20628
# FIELD - settlements
# round 731 of 20628
# FIELD - settlements
# round 732 of 20628
# FIELD - settlements
# round 733 of 20628
# FIELD - settlements
# round 734 of 20628
# FIELD - settlements
# round 735 of 20628
# FIELD - settlements
# round 736 of 20628
# FIELD - settlements
# round 737 of 20628
# FIELD - settlements
# round 738 of 20628
# FIELD - settlements
# round 739 of 20628
# FIELD - settlements
# round 740 of 20628
# FIELD - settlements
# round 741 of 20628
# FIELD - settlements
# round 742 of 20628
# FIELD - settlements
# round 743 of 20628
# FIELD - settlements
# round 744 of 20628
# FIELD - settlements
# round 745 of 20628
# FIELD - settlements
# round 746 of 20628
# FIELD - settlements
# round 747 of 20628
# FIELD - settlements
# round 748 of 20628
# FIELD - settlements
# round 749 of 20628
# FIELD - settlements
# round 750 of 20628
# FIELD - settlements
# round 751 of 20628
# FIELD - settlements
# round 752 of 20628
# FIELD - settlements
# round 753 of 20628
# FIELD - settlements
# round 754 of 20628
# FIELD - settlements
# round 755 of 20628
# FIELD - settlements
# round 756 of 20628
# FIELD - settlements
# round 757 of 20628
# FIELD - settlements
# round 758 of 20628
# FIELD - settlements
# round 759 of 20628
# FIELD - settlements
# round 760 of 20628
# FIELD - settlements
# round 761 of 20628
# FIELD - settlements
# round 762 of 20628
# FIELD - settlements
# round 763 of 20628
# FIELD - settlements
# round 764 of 20628
# FIELD - settlements
# round 765 of 20628
# FIELD - settlements
# round 766 of 20628
# FIELD - settlements
# round 767 of 20628
# FIELD - settlements
# round 768 of 20628
# FIELD - settlements
# round 769 of 20628
# FIELD - settlements
# round 770 of 20628
# FIELD - settlements
# round 771 of 20628
# FIELD - settlements
# round 772 of 20628
# FIELD - settlements
# round 773 of 20628
# FIELD - settlements
# round 774 of 20628
# FIELD - settlements
# round 775 of 20628
# FIELD - settlements
# round 776 of 20628
# FIELD - settlements
# round 777 of 20628
# FIELD - settlements
# round 778 of 20628
# FIELD - settlements
# round 779 of 20628
# FIELD - settlements
# round 780 of 20628
# FIELD - settlements
# round 781 of 20628
# FIELD - settlements
# round 782 of 20628
# FIELD - settlements
# round 783 of 20628
# FIELD - settlements
# round 784 of 20628
# FIELD - settlements
# round 785 of 20628
# FIELD - settlements
# round 786 of 20628
# FIELD - settlements
# round 787 of 20628
# FIELD - settlements
# round 788 of 20628
# FIELD - settlements
# round 789 of 20628
# FIELD - settlements
# round 790 of 20628
# FIELD - settlements
# round 791 of 20628
# FIELD - settlements
# round 792 of 20628
# FIELD - settlements
# round 793 of 20628
# FIELD - settlements
# round 794 of 20628
# FIELD - settlements
# round 795 of 20628
# FIELD - settlements
# round 796 of 20628
# FIELD - settlements
# round 797 of 20628
# FIELD - settlements
# round 798 of 20628
# FIELD - settlements
# round 799 of 20628
# FIELD - settlements
# round 800 of 20628
# FIELD - settlements
# round 801 of 20628
# FIELD - settlements
# round 802 of 20628
# FIELD - settlements
# round 803 of 20628
# FIELD - settlements
# round 804 of 20628
# FIELD - settlements
# round 805 of 20628
# FIELD - settlements
# round 806 of 20628
# FIELD - settlements
# round 807 of 20628
# FIELD - settlements
# round 808 of 20628
# FIELD - settlements
# round 809 of 20628
# FIELD - settlements
# round 810 of 20628
# FIELD - settlements
# round 811 of 20628
# FIELD - settlements
# round 812 of 20628
# FIELD - settlements
# round 813 of 20628
# FIELD - settlements
# round 814 of 20628
# FIELD - settlements
# round 815 of 20628
# FIELD - settlements
# round 816 of 20628
# FIELD - settlements
# round 817 of 20628
# FIELD - settlements
# round 818 of 20628
# FIELD - settlements
# round 819 of 20628
# FIELD - settlements
# round 820 of 20628
# FIELD - settlements
# round 821 of 20628
# FIELD - settlements
# round 822 of 20628
# FIELD - settlements
# round 823 of 20628
# FIELD - settlements
# round 824 of 20628
# FIELD - settlements
# round 825 of 20628
# FIELD - settlements
# round 826 of 20628
# FIELD - settlements
# round 827 of 20628
# FIELD - settlements
# round 828 of 20628
# FIELD - settlements
# round 829 of 20628
# FIELD - settlements
# round 830 of 20628
# FIELD - settlements
# round 831 of 20628
# FIELD - settlements
# round 832 of 20628
# FIELD - settlements
# round 833 of 20628
# FIELD - settlements
# round 834 of 20628
# FIELD - settlements
# round 835 of 20628
# FIELD - settlements
# round 836 of 20628
# FIELD - settlements
# round 837 of 20628
# FIELD - settlements
# round 838 of 20628
# FIELD - settlements
# round 839 of 20628
# FIELD - settlements
# round 840 of 20628
# FIELD - settlements
# round 841 of 20628
# FIELD - settlements
# round 842 of 20628
# FIELD - settlements
# round 843 of 20628
# FIELD - settlements
# round 844 of 20628
# FIELD - settlements
# round 845 of 20628
# FIELD - settlements
# round 846 of 20628
# FIELD - settlements
# round 847 of 20628
# FIELD - settlements
# round 848 of 20628
# FIELD - settlements
# round 849 of 20628
# FIELD - settlements
# round 850 of 20628
# FIELD - settlements
# round 851 of 20628
# FIELD - settlements
# round 852 of 20628
# FIELD - settlements
# round 853 of 20628
# FIELD - settlements
# round 854 of 20628
# FIELD - settlements
# round 855 of 20628
# FIELD - settlements
# round 856 of 20628
# FIELD - settlements
# round 857 of 20628
# FIELD - settlements
# round 858 of 20628
# FIELD - settlements
# round 859 of 20628
# FIELD - settlements
# round 860 of 20628
# FIELD - settlements
# round 861 of 20628
# FIELD - settlements
# round 862 of 20628
# FIELD - settlements
# round 863 of 20628
# FIELD - settlements
# round 864 of 20628
# FIELD - settlements
# round 865 of 20628
# FIELD - settlements
# round 866 of 20628
# FIELD - settlements
# round 867 of 20628
# FIELD - settlements
# round 868 of 20628
# FIELD - settlements
# round 869 of 20628
# FIELD - settlements
# round 870 of 20628
# FIELD - settlements
# round 871 of 20628
# FIELD - settlements
# round 872 of 20628
# FIELD - settlements
# round 873 of 20628
# FIELD - settlements
# round 874 of 20628
# FIELD - settlements
# round 875 of 20628
# FIELD - settlements
# round 876 of 20628
# FIELD - settlements
# round 877 of 20628
# FIELD - settlements
# round 878 of 20628
# FIELD - settlements
# round 879 of 20628
# FIELD - settlements
# round 880 of 20628
# FIELD - settlements
# round 881 of 20628
# FIELD - settlements
# round 882 of 20628
# FIELD - settlements
# round 883 of 20628
# FIELD - settlements
# round 884 of 20628
# FIELD - settlements
# round 885 of 20628
# FIELD - settlements
# round 886 of 20628
# FIELD - settlements
# round 887 of 20628
# FIELD - settlements
# round 888 of 20628
# FIELD - settlements
# round 889 of 20628
# FIELD - settlements
# round 890 of 20628
# FIELD - settlements
# round 891 of 20628
# FIELD - settlements
# round 892 of 20628
# FIELD - settlements
# round 893 of 20628
# FIELD - settlements
# round 894 of 20628
# FIELD - settlements
# round 895 of 20628
# FIELD - settlements
# round 896 of 20628
# FIELD - settlements
# round 897 of 20628
# FIELD - settlements
# round 898 of 20628
# FIELD - settlements
# round 899 of 20628
# FIELD - settlements
# round 900 of 20628
# FIELD - settlements
# round 901 of 20628
# FIELD - settlements
# round 902 of 20628
# FIELD - settlements
# round 903 of 20628
# FIELD - settlements
# round 904 of 20628
# FIELD - settlements
# round 905 of 20628
# FIELD - settlements
# round 906 of 20628
# FIELD - settlements
# round 907 of 20628
# FIELD - settlements
# round 908 of 20628
# FIELD - settlements
# round 909 of 20628
# FIELD - settlements
# round 910 of 20628
# FIELD - settlements
# round 911 of 20628
# FIELD - settlements
# round 912 of 20628
# FIELD - settlements
# round 913 of 20628
# FIELD - settlements
# round 914 of 20628
# FIELD - settlements
# round 915 of 20628
# FIELD - settlements
# round 916 of 20628
# FIELD - settlements
# round 917 of 20628
# FIELD - settlements
# round 918 of 20628
# FIELD - settlements
# round 919 of 20628
# FIELD - settlements
# round 920 of 20628
# FIELD - settlements
# round 921 of 20628
# FIELD - settlements
# round 922 of 20628
# FIELD - settlements
# round 923 of 20628
# FIELD - settlements
# round 924 of 20628
# FIELD - settlements
# round 925 of 20628
# FIELD - settlements
# round 926 of 20628
# FIELD - settlements
# round 927 of 20628
# FIELD - settlements
# round 928 of 20628
# FIELD - settlements
# round 929 of 20628
# FIELD - settlements
# round 930 of 20628
# FIELD - settlements
# round 931 of 20628
# FIELD - settlements
# round 932 of 20628
# FIELD - settlements
# round 933 of 20628
# FIELD - settlements
# round 934 of 20628
# FIELD - settlements
# round 935 of 20628
# FIELD - settlements
# round 936 of 20628
# FIELD - settlements
# round 937 of 20628
# FIELD - settlements
# round 938 of 20628
# FIELD - settlements
# round 939 of 20628
# FIELD - settlements
# round 940 of 20628
# FIELD - settlements
# round 941 of 20628
# FIELD - settlements
# round 942 of 20628
# FIELD - settlements
# round 943 of 20628
# FIELD - settlements
# round 944 of 20628
# FIELD - settlements
# round 945 of 20628
# FIELD - settlements
# round 946 of 20628
# FIELD - settlements
# round 947 of 20628
# FIELD - settlements
# round 948 of 20628
# FIELD - settlements
# round 949 of 20628
# FIELD - settlements
# round 950 of 20628
# FIELD - settlements
# round 951 of 20628
# FIELD - settlements
# round 952 of 20628
# FIELD - settlements
# round 953 of 20628
# FIELD - settlements
# round 954 of 20628
# FIELD - settlements
# round 955 of 20628
# FIELD - settlements
# round 956 of 20628
# FIELD - settlements
# round 957 of 20628
# FIELD - settlements
# round 958 of 20628
# FIELD - settlements
# round 959 of 20628
# FIELD - settlements
# round 960 of 20628
# FIELD - settlements
# round 961 of 20628
# FIELD - settlements
# round 962 of 20628
# FIELD - settlements
# round 963 of 20628
# FIELD - settlements
# round 964 of 20628
# FIELD - settlements
# round 965 of 20628
# FIELD - settlements
# round 966 of 20628
# FIELD - settlements
# round 967 of 20628
# FIELD - settlements
# round 968 of 20628
# FIELD - settlements
# round 969 of 20628
# FIELD - settlements
# round 970 of 20628
# FIELD - settlements
# round 971 of 20628
# FIELD - settlements
# round 972 of 20628
# FIELD - settlements
# round 973 of 20628
# FIELD - settlements
# round 974 of 20628
# FIELD - settlements
# round 975 of 20628
# FIELD - settlements
# round 976 of 20628
# FIELD - settlements
# round 977 of 20628
# FIELD - settlements
# round 978 of 20628
# FIELD - settlements
# round 979 of 20628
# FIELD - settlements
# round 980 of 20628
# FIELD - settlements
# round 981 of 20628
# FIELD - settlements
# round 982 of 20628
# FIELD - settlements
# round 983 of 20628
# FIELD - settlements
# round 984 of 20628
# FIELD - settlements
# round 985 of 20628
# FIELD - settlements
# round 986 of 20628
# FIELD - settlements
# round 987 of 20628
# FIELD - settlements
# round 988 of 20628
# FIELD - settlements
# round 989 of 20628
# FIELD - settlements
# round 990 of 20628
# FIELD - settlements
# round 991 of 20628
# FIELD - settlements
# round 992 of 20628
# FIELD - settlements
# round 993 of 20628
# FIELD - settlements
# round 994 of 20628
# FIELD - settlements
# round 995 of 20628
# FIELD - settlements
# round 996 of 20628
# FIELD - settlements
# round 997 of 20628
# FIELD - settlements
# round 998 of 20628
# FIELD - settlements
# round 999 of 20628
# FIELD - settlements
# round 1000 of 20628
# FIELD - settlements
# round 1001 of 20628
# FIELD - settlements
# round 1002 of 20628
# FIELD - settlements
# round 1003 of 20628
# FIELD - settlements
# round 1004 of 20628
# FIELD - settlements
# round 1005 of 20628
# FIELD - settlements
# round 1006 of 20628
# FIELD - settlements
# round 1007 of 20628
# FIELD - settlements
# round 1008 of 20628
# FIELD - settlements
# round 1009 of 20628
# FIELD - settlements
# round 1010 of 20628
# FIELD - settlements
# round 1011 of 20628
# FIELD - settlements
# round 1012 of 20628
# FIELD - settlements
# round 1013 of 20628
# FIELD - settlements
# round 1014 of 20628
# FIELD - settlements
# round 1015 of 20628
# FIELD - settlements
# round 1016 of 20628
# FIELD - settlements
# round 1017 of 20628
# FIELD - settlements
# round 1018 of 20628
# FIELD - settlements
# round 1019 of 20628
# FIELD - settlements
# round 1020 of 20628
# FIELD - settlements
# round 1021 of 20628
# FIELD - settlements
# round 1022 of 20628
# FIELD - settlements
# round 1023 of 20628
# FIELD - settlements
# round 1024 of 20628
# FIELD - settlements
# round 1025 of 20628
# FIELD - settlements
# round 1026 of 20628
# FIELD - settlements
# round 1027 of 20628
# FIELD - settlements
# round 1028 of 20628
# FIELD - settlements
# round 1029 of 20628
# FIELD - settlements
# round 1030 of 20628
# FIELD - settlements
# round 1031 of 20628
# FIELD - settlements
# round 1032 of 20628
# FIELD - settlements
# round 1033 of 20628
# FIELD - settlements
# round 1034 of 20628
# FIELD - settlements
# round 1035 of 20628
# FIELD - settlements
# round 1036 of 20628
# FIELD - settlements
# round 1037 of 20628
# FIELD - settlements
# round 1038 of 20628
# FIELD - settlements
# round 1039 of 20628
# FIELD - settlements
# round 1040 of 20628
# FIELD - settlements
# round 1041 of 20628
# FIELD - settlements
# round 1042 of 20628
# FIELD - settlements
# round 1043 of 20628
# FIELD - settlements
# round 1044 of 20628
# FIELD - settlements
# round 1045 of 20628
# FIELD - settlements
# round 1046 of 20628
# FIELD - settlements
# round 1047 of 20628
# FIELD - settlements
# round 1048 of 20628
# FIELD - settlements
# round 1049 of 20628
# FIELD - settlements
# round 1050 of 20628
# FIELD - settlements
# round 1051 of 20628
# FIELD - settlements
# round 1052 of 20628
# FIELD - settlements
# round 1053 of 20628
# FIELD - settlements
# round 1054 of 20628
# FIELD - settlements
# round 1055 of 20628
# FIELD - settlements
# round 1056 of 20628
# FIELD - settlements
# round 1057 of 20628
# FIELD - settlements
# round 1058 of 20628
# FIELD - settlements
# round 1059 of 20628
# FIELD - settlements
# round 1060 of 20628
# FIELD - settlements
# round 1061 of 20628
# FIELD - settlements
# round 1062 of 20628
# FIELD - settlements
# round 1063 of 20628
# FIELD - settlements
# round 1064 of 20628
# FIELD - settlements
# round 1065 of 20628
# FIELD - settlements
# round 1066 of 20628
# FIELD - settlements
# round 1067 of 20628
# FIELD - settlements
# round 1068 of 20628
# FIELD - settlements
# round 1069 of 20628
# FIELD - settlements
# round 1070 of 20628
# FIELD - settlements
# round 1071 of 20628
# FIELD - settlements
# round 1072 of 20628
# FIELD - settlements
# round 1073 of 20628
# FIELD - settlements
# round 1074 of 20628
# FIELD - settlements
# round 1075 of 20628
# FIELD - settlements
# round 1076 of 20628
# FIELD - settlements
# round 1077 of 20628
# FIELD - settlements
# round 1078 of 20628
# FIELD - settlements
# round 1079 of 20628
# FIELD - settlements
# round 1080 of 20628
# FIELD - settlements
# round 1081 of 20628
# FIELD - settlements
# round 1082 of 20628
# FIELD - settlements
# round 1083 of 20628
# FIELD - settlements
# round 1084 of 20628
# FIELD - settlements
# round 1085 of 20628
# FIELD - settlements
# round 1086 of 20628
# FIELD - settlements
# round 1087 of 20628
# FIELD - settlements
# round 1088 of 20628
# FIELD - settlements
# round 1089 of 20628
# FIELD - settlements
# round 1090 of 20628
# FIELD - settlements
# round 1091 of 20628
# FIELD - settlements
# round 1092 of 20628
# FIELD - settlements
# round 1093 of 20628
# FIELD - settlements
# round 1094 of 20628
# FIELD - settlements
# round 1095 of 20628
# FIELD - settlements
# round 1096 of 20628
# FIELD - settlements
# round 1097 of 20628
# FIELD - settlements
# round 1098 of 20628
# FIELD - settlements
# round 1099 of 20628
# FIELD - settlements
# round 1100 of 20628
# FIELD - settlements
# round 1101 of 20628
# FIELD - settlements
# round 1102 of 20628
# FIELD - settlements
# round 1103 of 20628
# FIELD - settlements
# round 1104 of 20628
# FIELD - settlements
# round 1105 of 20628
# FIELD - settlements
# round 1106 of 20628
# FIELD - settlements
# round 1107 of 20628
# FIELD - settlements
# round 1108 of 20628
# FIELD - settlements
# round 1109 of 20628
# FIELD - settlements
# round 1110 of 20628
# FIELD - settlements
# round 1111 of 20628
# FIELD - settlements
# round 1112 of 20628
# FIELD - settlements
# round 1113 of 20628
# FIELD - settlements
# round 1114 of 20628
# FIELD - settlements
# round 1115 of 20628
# FIELD - settlements
# round 1116 of 20628
# FIELD - settlements
# round 1117 of 20628
# FIELD - settlements
# round 1118 of 20628
# FIELD - settlements
# round 1119 of 20628
# FIELD - settlements
# round 1120 of 20628
# FIELD - settlements
# round 1121 of 20628
# FIELD - settlements
# round 1122 of 20628
# FIELD - settlements
# round 1123 of 20628
# FIELD - settlements
# round 1124 of 20628
# FIELD - settlements
# round 1125 of 20628
# FIELD - settlements
# round 1126 of 20628
# FIELD - settlements
# round 1127 of 20628
# FIELD - settlements
# round 1128 of 20628
# FIELD - settlements
# round 1129 of 20628
# FIELD - settlements
# round 1130 of 20628
# FIELD - settlements
# round 1131 of 20628
# FIELD - settlements
# round 1132 of 20628
# FIELD - settlements
# round 1133 of 20628
# FIELD - settlements
# round 1134 of 20628
# FIELD - settlements
# round 1135 of 20628
# FIELD - settlements
# round 1136 of 20628
# FIELD - settlements
# round 1137 of 20628
# FIELD - settlements
# round 1138 of 20628
# FIELD - settlements
# round 1139 of 20628
# FIELD - settlements
# round 1140 of 20628
# FIELD - settlements
# round 1141 of 20628
# FIELD - settlements
# round 1142 of 20628
# FIELD - settlements
# round 1143 of 20628
# FIELD - settlements
# round 1144 of 20628
# FIELD - settlements
# round 1145 of 20628
# FIELD - settlements
# round 1146 of 20628
# FIELD - settlements
# round 1147 of 20628
# FIELD - settlements
# round 1148 of 20628
# FIELD - settlements
# round 1149 of 20628
# FIELD - settlements
# round 1150 of 20628
# FIELD - settlements
# round 1151 of 20628
# FIELD - settlements
# round 1152 of 20628
# FIELD - settlements
# round 1153 of 20628
# FIELD - settlements
# round 1154 of 20628
# FIELD - settlements
# round 1155 of 20628
# FIELD - settlements
# round 1156 of 20628
# FIELD - settlements
# round 1157 of 20628
# FIELD - settlements
# round 1158 of 20628
# FIELD - settlements
# round 1159 of 20628
# FIELD - settlements
# round 1160 of 20628
# FIELD - settlements
# round 1161 of 20628
# FIELD - settlements
# round 1162 of 20628
# FIELD - settlements
# round 1163 of 20628
# FIELD - settlements
# round 1164 of 20628
# FIELD - settlements
# round 1165 of 20628
# FIELD - settlements
# round 1166 of 20628
# FIELD - settlements
# round 1167 of 20628
# FIELD - settlements
# round 1168 of 20628
# FIELD - settlements
# round 1169 of 20628
# FIELD - settlements
# round 1170 of 20628
# FIELD - settlements
# round 1171 of 20628
# FIELD - settlements
# round 1172 of 20628
# FIELD - settlements
# round 1173 of 20628
# FIELD - settlements
# round 1174 of 20628
# FIELD - settlements
# round 1175 of 20628
# FIELD - settlements
# round 1176 of 20628
# FIELD - settlements
# round 1177 of 20628
# FIELD - settlements
# round 1178 of 20628
# FIELD - settlements
# round 1179 of 20628
# FIELD - settlements
# round 1180 of 20628
# FIELD - settlements
# round 1181 of 20628
# FIELD - settlements
# round 1182 of 20628
# FIELD - settlements
# round 1183 of 20628
# FIELD - settlements
# round 1184 of 20628
# FIELD - settlements
# round 1185 of 20628
# FIELD - settlements
# round 1186 of 20628
# FIELD - settlements
# round 1187 of 20628
# FIELD - settlements
# round 1188 of 20628
# FIELD - settlements
# round 1189 of 20628
# FIELD - settlements
# round 1190 of 20628
# FIELD - settlements
# round 1191 of 20628
# FIELD - settlements
# round 1192 of 20628
# FIELD - settlements
# round 1193 of 20628
# FIELD - settlements
# round 1194 of 20628
# FIELD - settlements
# round 1195 of 20628
# FIELD - settlements
# round 1196 of 20628
# FIELD - settlements
# round 1197 of 20628
# FIELD - settlements
# round 1198 of 20628
# FIELD - settlements
# round 1199 of 20628
# FIELD - settlements
# round 1200 of 20628
# FIELD - settlements
# round 1201 of 20628
# FIELD - settlements
# round 1202 of 20628
# FIELD - settlements
# round 1203 of 20628
# FIELD - settlements
# round 1204 of 20628
# FIELD - settlements
# round 1205 of 20628
# FIELD - settlements
# round 1206 of 20628
# FIELD - settlements
# round 1207 of 20628
# FIELD - settlements
# round 1208 of 20628
# FIELD - settlements
# round 1209 of 20628
# FIELD - settlements
# round 1210 of 20628
# FIELD - settlements
# round 1211 of 20628
# FIELD - settlements
# round 1212 of 20628
# FIELD - settlements
# round 1213 of 20628
# FIELD - settlements
# round 1214 of 20628
# FIELD - settlements
# round 1215 of 20628
# FIELD - settlements
# round 1216 of 20628
# FIELD - settlements
# round 1217 of 20628
# FIELD - settlements
# round 1218 of 20628
# FIELD - settlements
# round 1219 of 20628
# FIELD - settlements
# round 1220 of 20628
# FIELD - settlements
# round 1221 of 20628
# FIELD - settlements
# round 1222 of 20628
# FIELD - settlements
# round 1223 of 20628
# FIELD - settlements
# round 1224 of 20628
# FIELD - settlements
# round 1225 of 20628
# FIELD - settlements
# round 1226 of 20628
# FIELD - settlements
# round 1227 of 20628
# ...
# round 20238 of 20628
# FIELD - settlements
# round 20239 of 20628
# FIELD - settlements
# round 20240 of 20628
# FIELD - settlements
# round 20241 of 20628
# FIELD - settlements
# round 20242 of 20628
# FIELD - settlements
# round 20243 of 20628
# FIELD - settlements
# round 20244 of 20628
# FIELD - settlements
# round 20245 of 20628
# FIELD - settlements
# round 20246 of 20628
# FIELD - settlements
# round 20247 of 20628
# FIELD - settlements
# round 20248 of 20628
# FIELD - settlements
# round 20249 of 20628
# FIELD - settlements
# round 20250 of 20628
# FIELD - settlements
# round 20251 of 20628
# FIELD - settlements
# round 20252 of 20628
# FIELD - settlements
# round 20253 of 20628
# FIELD - settlements
# round 20254 of 20628
# FIELD - settlements
# round 20255 of 20628
# FIELD - settlements
# round 20256 of 20628
# FIELD - settlements
# round 20257 of 20628
# FIELD - settlements
# round 20258 of 20628
# FIELD - settlements
# round 20259 of 20628
# FIELD - settlements
# round 20260 of 20628
# FIELD - settlements
# round 20261 of 20628
# FIELD - settlements
# round 20262 of 20628
# FIELD - settlements
# round 20263 of 20628
# FIELD - settlements
# round 20264 of 20628
# FIELD - settlements
# round 20265 of 20628
# FIELD - settlements
# round 20266 of 20628
# FIELD - settlements
# round 20267 of 20628
# FIELD - settlements
# round 20268 of 20628
# FIELD - settlements
# round 20269 of 20628
# FIELD - settlements
# round 20270 of 20628
# FIELD - settlements
# round 20271 of 20628
# FIELD - settlements
# round 20272 of 20628
# FIELD - settlements
# round 20273 of 20628
# FIELD - settlements
# round 20274 of 20628
# FIELD - settlements
# round 20275 of 20628
# FIELD - settlements
# round 20276 of 20628
# FIELD - settlements
# round 20277 of 20628
# FIELD - settlements
# round 20278 of 20628
# FIELD - settlements
# round 20279 of 20628
# FIELD - settlements
# round 20280 of 20628
# FIELD - settlements
# round 20281 of 20628
# FIELD - settlements
# round 20282 of 20628
# FIELD - settlements
# round 20283 of 20628
# FIELD - settlements
# round 20284 of 20628
# FIELD - settlements
# round 20285 of 20628
# FIELD - settlements
# round 20286 of 20628
# FIELD - settlements
# round 20287 of 20628
# FIELD - settlements
# round 20288 of 20628
# FIELD - settlements
# round 20289 of 20628
# FIELD - settlements
# round 20290 of 20628
# FIELD - settlements
# round 20291 of 20628
# FIELD - settlements
# round 20292 of 20628
# FIELD - settlements
# round 20293 of 20628
# FIELD - settlements
# round 20294 of 20628
# FIELD - settlements
# round 20295 of 20628
# FIELD - settlements
# round 20296 of 20628
# FIELD - settlements
# round 20297 of 20628
# FIELD - settlements
# round 20298 of 20628
# FIELD - settlements
# round 20299 of 20628
# FIELD - settlements
# round 20300 of 20628
# FIELD - settlements
# round 20301 of 20628
# FIELD - settlements
# round 20302 of 20628
# FIELD - settlements
# round 20303 of 20628
# FIELD - settlements
# round 20304 of 20628
# FIELD - settlements
# round 20305 of 20628
# FIELD - settlements
# round 20306 of 20628
# FIELD - settlements
# round 20307 of 20628
# FIELD - settlements
# round 20308 of 20628
# FIELD - settlements
# round 20309 of 20628
# FIELD - settlements
# round 20310 of 20628
# FIELD - settlements
# round 20311 of 20628
# FIELD - settlements
# round 20312 of 20628
# FIELD - settlements
# round 20313 of 20628
# FIELD - settlements
# round 20314 of 20628
# FIELD - settlements
# round 20315 of 20628
# FIELD - settlements
# round 20316 of 20628
# FIELD - settlements
# round 20317 of 20628
# FIELD - settlements
# round 20318 of 20628
# FIELD - settlements
# round 20319 of 20628
# FIELD - settlements
# round 20320 of 20628
# FIELD - settlements
# round 20321 of 20628
# FIELD - settlements
# round 20322 of 20628
# FIELD - settlements
# round 20323 of 20628
# FIELD - settlements
# round 20324 of 20628
# FIELD - settlements
# round 20325 of 20628
# FIELD - settlements
# round 20326 of 20628
# FIELD - settlements
# round 20327 of 20628
# FIELD - settlements
# round 20328 of 20628
# FIELD - settlements
# round 20329 of 20628
# FIELD - settlements
# round 20330 of 20628
# FIELD - settlements
# round 20331 of 20628
# FIELD - settlements
# round 20332 of 20628
# FIELD - settlements
# round 20333 of 20628
# FIELD - settlements
# round 20334 of 20628
# FIELD - settlements
# round 20335 of 20628
# FIELD - settlements
# round 20336 of 20628
# FIELD - settlements
# round 20337 of 20628
# FIELD - settlements
# round 20338 of 20628
# FIELD - settlements
# round 20339 of 20628
# FIELD - settlements
# round 20340 of 20628
# FIELD - settlements
# round 20341 of 20628
# FIELD - settlements
# round 20342 of 20628
# FIELD - settlements
# round 20343 of 20628
# FIELD - settlements
# round 20344 of 20628
# FIELD - settlements
# round 20345 of 20628
# FIELD - settlements
# round 20346 of 20628
# FIELD - settlements
# round 20347 of 20628
# FIELD - settlements
# round 20348 of 20628
# FIELD - settlements
# round 20349 of 20628
# FIELD - settlements
# round 20350 of 20628
# FIELD - settlements
# round 20351 of 20628
# FIELD - settlements
# round 20352 of 20628
# FIELD - settlements
# round 20353 of 20628
# FIELD - settlements
# round 20354 of 20628
# FIELD - settlements
# round 20355 of 20628
# FIELD - settlements
# round 20356 of 20628
# FIELD - settlements
# round 20357 of 20628
# FIELD - settlements
# round 20358 of 20628
# FIELD - settlements
# round 20359 of 20628
# FIELD - settlements
# round 20360 of 20628
# FIELD - settlements
# round 20361 of 20628
# FIELD - settlements
# round 20362 of 20628
# FIELD - settlements
# round 20363 of 20628
# FIELD - settlements
# round 20364 of 20628
# FIELD - settlements
# round 20365 of 20628
# FIELD - settlements
# round 20366 of 20628
# FIELD - settlements
# round 20367 of 20628
# FIELD - settlements
# round 20368 of 20628
# FIELD - settlements
# round 20369 of 20628
# FIELD - settlements
# round 20370 of 20628
# FIELD - settlements
# round 20371 of 20628
# FIELD - settlements
# round 20372 of 20628
# FIELD - settlements
# round 20373 of 20628
# FIELD - settlements
# round 20374 of 20628
# FIELD - settlements
# round 20375 of 20628
# FIELD - settlements
# round 20376 of 20628
# FIELD - settlements
# round 20377 of 20628
# FIELD - settlements
# round 20378 of 20628
# FIELD - settlements
# round 20379 of 20628
# FIELD - settlements
# round 20380 of 20628
# FIELD - settlements
# round 20381 of 20628
# FIELD - settlements
# round 20382 of 20628
# FIELD - settlements
# round 20383 of 20628
# FIELD - settlements
# round 20384 of 20628
# FIELD - settlements
# round 20385 of 20628
# FIELD - settlements
# round 20386 of 20628
# FIELD - settlements
# round 20387 of 20628
# FIELD - settlements
# round 20388 of 20628
# FIELD - settlements
# round 20389 of 20628
# FIELD - settlements
# round 20390 of 20628
# FIELD - settlements
# round 20391 of 20628
# FIELD - settlements
# round 20392 of 20628
# FIELD - settlements
# round 20393 of 20628
# FIELD - settlements
# round 20394 of 20628
# FIELD - settlements
# round 20395 of 20628
# FIELD - settlements
# round 20396 of 20628
# FIELD - settlements
# round 20397 of 20628
# FIELD - settlements
# round 20398 of 20628
# FIELD - settlements
# round 20399 of 20628
# FIELD - settlements
# round 20400 of 20628
# FIELD - settlements
# round 20401 of 20628
# FIELD - settlements
# round 20402 of 20628
# FIELD - settlements
# round 20403 of 20628
# FIELD - settlements
# round 20404 of 20628
# FIELD - settlements
# round 20405 of 20628
# FIELD - settlements
# round 20406 of 20628
# FIELD - settlements
# round 20407 of 20628
# FIELD - settlements
# round 20408 of 20628
# FIELD - settlements
# round 20409 of 20628
# FIELD - settlements
# round 20410 of 20628
# FIELD - settlements
# round 20411 of 20628
# FIELD - settlements
# round 20412 of 20628
# FIELD - settlements
# round 20413 of 20628
# FIELD - settlements
# round 20414 of 20628
# FIELD - settlements
# round 20415 of 20628
# FIELD - settlements
# round 20416 of 20628
# FIELD - settlements
# round 20417 of 20628
# FIELD - settlements
# round 20418 of 20628
# FIELD - settlements
# round 20419 of 20628
# FIELD - settlements
# round 20420 of 20628
# FIELD - settlements
# round 20421 of 20628
# FIELD - settlements
# round 20422 of 20628
# FIELD - settlements
# round 20423 of 20628
# FIELD - settlements
# round 20424 of 20628
# FIELD - settlements
# round 20425 of 20628
# FIELD - settlements
# round 20426 of 20628
# FIELD - settlements
# round 20427 of 20628
# FIELD - settlements
# round 20428 of 20628
# FIELD - settlements
# round 20429 of 20628
# FIELD - settlements
# round 20430 of 20628
# FIELD - settlements
# round 20431 of 20628
# FIELD - settlements
# round 20432 of 20628
# FIELD - settlements
# round 20433 of 20628
# FIELD - settlements
# round 20434 of 20628
# FIELD - settlements
# round 20435 of 20628
# FIELD - settlements
# round 20436 of 20628
# FIELD - settlements
# round 20437 of 20628
# FIELD - settlements
# round 20438 of 20628
# FIELD - settlements
# round 20439 of 20628
# FIELD - settlements
# round 20440 of 20628
# FIELD - settlements
# round 20441 of 20628
# FIELD - settlements
# round 20442 of 20628
# FIELD - settlements
# round 20443 of 20628
# FIELD - settlements
# round 20444 of 20628
# FIELD - settlements
# round 20445 of 20628
# FIELD - settlements
# round 20446 of 20628
# FIELD - settlements
# round 20447 of 20628
# FIELD - settlements
# round 20448 of 20628
# FIELD - settlements
# round 20449 of 20628
# FIELD - settlements
# round 20450 of 20628
# FIELD - settlements
# round 20451 of 20628
# FIELD - settlements
# round 20452 of 20628
# FIELD - settlements
# round 20453 of 20628
# FIELD - settlements
# round 20454 of 20628
# FIELD - settlements
# round 20455 of 20628
# FIELD - settlements
# round 20456 of 20628
# FIELD - settlements
# round 20457 of 20628
# FIELD - settlements
# round 20458 of 20628
# FIELD - settlements
# round 20459 of 20628
# FIELD - settlements
# round 20460 of 20628
# FIELD - settlements
# round 20461 of 20628
# FIELD - settlements
# round 20462 of 20628
# FIELD - settlements
# round 20463 of 20628
# FIELD - settlements
# round 20464 of 20628
# FIELD - settlements
# round 20465 of 20628
# FIELD - settlements
# round 20466 of 20628
# FIELD - settlements
# round 20467 of 20628
# FIELD - settlements
# round 20468 of 20628
# FIELD - settlements
# round 20469 of 20628
# FIELD - settlements
# round 20470 of 20628
# FIELD - settlements
# round 20471 of 20628
# FIELD - settlements
# round 20472 of 20628
# FIELD - settlements
# round 20473 of 20628
# FIELD - settlements
# round 20474 of 20628
# FIELD - settlements
# round 20475 of 20628
# FIELD - settlements
# round 20476 of 20628
# FIELD - settlements
# round 20477 of 20628
# FIELD - settlements
# round 20478 of 20628
# FIELD - settlements
# round 20479 of 20628
# FIELD - settlements
# round 20480 of 20628
# FIELD - settlements
# round 20481 of 20628
# FIELD - settlements
# round 20482 of 20628
# FIELD - settlements
# round 20483 of 20628
# FIELD - settlements
# round 20484 of 20628
# FIELD - settlements
# round 20485 of 20628
# FIELD - settlements
# round 20486 of 20628
# FIELD - settlements
# round 20487 of 20628
# FIELD - settlements
# round 20488 of 20628
# FIELD - settlements
# round 20489 of 20628
# FIELD - settlements
# round 20490 of 20628
# FIELD - settlements
# round 20491 of 20628
# FIELD - settlements
# round 20492 of 20628
# FIELD - settlements
# round 20493 of 20628
# FIELD - settlements
# round 20494 of 20628
# FIELD - settlements
# round 20495 of 20628
# FIELD - settlements
# round 20496 of 20628
# FIELD - settlements
# round 20497 of 20628
# FIELD - settlements
# round 20498 of 20628
# FIELD - settlements
# round 20499 of 20628
# FIELD - settlements
# round 20500 of 20628
# FIELD - settlements
# round 20501 of 20628
# FIELD - settlements
# round 20502 of 20628
# FIELD - settlements
# round 20503 of 20628
# FIELD - settlements
# round 20504 of 20628
# FIELD - settlements
# round 20505 of 20628
# FIELD - settlements
# round 20506 of 20628
# FIELD - settlements
# round 20507 of 20628
# FIELD - settlements
# round 20508 of 20628
# FIELD - settlements
# round 20509 of 20628
# FIELD - settlements
# round 20510 of 20628
# FIELD - settlements
# round 20511 of 20628
# FIELD - settlements
# round 20512 of 20628
# FIELD - settlements
# round 20513 of 20628
# FIELD - settlements
# round 20514 of 20628
# FIELD - settlements
# round 20515 of 20628
# FIELD - settlements
# round 20516 of 20628
# FIELD - settlements
# round 20517 of 20628
# FIELD - settlements
# round 20518 of 20628
# FIELD - settlements
# round 20519 of 20628
# FIELD - settlements
# round 20520 of 20628
# FIELD - settlements
# round 20521 of 20628
# FIELD - settlements
# round 20522 of 20628
# FIELD - settlements
# round 20523 of 20628
# FIELD - settlements
# round 20524 of 20628
# FIELD - settlements
# round 20525 of 20628
# FIELD - settlements
# round 20526 of 20628
# FIELD - settlements
# round 20527 of 20628
# FIELD - settlements
# round 20528 of 20628
# FIELD - settlements
# round 20529 of 20628
# FIELD - settlements
# round 20530 of 20628
# FIELD - settlements
# round 20531 of 20628
# FIELD - settlements
# round 20532 of 20628
# FIELD - settlements
# round 20533 of 20628
# FIELD - settlements
# round 20534 of 20628
# FIELD - settlements
# round 20535 of 20628
# FIELD - settlements
# round 20536 of 20628
# FIELD - settlements
# round 20537 of 20628
# FIELD - settlements
# round 20538 of 20628
# FIELD - settlements
# round 20539 of 20628
# FIELD - settlements
# round 20540 of 20628
# FIELD - settlements
# round 20541 of 20628
# FIELD - settlements
# round 20542 of 20628
# FIELD - settlements
# round 20543 of 20628
# FIELD - settlements
# round 20544 of 20628
# FIELD - settlements
# round 20545 of 20628
# FIELD - settlements
# round 20546 of 20628
# FIELD - settlements
# round 20547 of 20628
# FIELD - settlements
# round 20548 of 20628
# FIELD - settlements
# round 20549 of 20628
# FIELD - settlements
# round 20550 of 20628
# FIELD - settlements
# round 20551 of 20628
# FIELD - settlements
# round 20552 of 20628
# FIELD - settlements
# round 20553 of 20628
# FIELD - settlements
# round 20554 of 20628
# FIELD - settlements
# round 20555 of 20628
# FIELD - settlements
# round 20556 of 20628
# FIELD - settlements
# round 20557 of 20628
# FIELD - settlements
# round 20558 of 20628
# FIELD - settlements
# round 20559 of 20628
# FIELD - settlements
# round 20560 of 20628
# FIELD - settlements
# round 20561 of 20628
# FIELD - settlements
# round 20562 of 20628
# FIELD - settlements
# round 20563 of 20628
# FIELD - settlements
# round 20564 of 20628
# FIELD - settlements
# round 20565 of 20628
# FIELD - settlements
# round 20566 of 20628
# FIELD - settlements
# round 20567 of 20628
# FIELD - settlements
# round 20568 of 20628
# FIELD - settlements
# round 20569 of 20628
# FIELD - settlements
# round 20570 of 20628
# FIELD - settlements
# round 20571 of 20628
# FIELD - settlements
# round 20572 of 20628
# FIELD - settlements
# round 20573 of 20628
# FIELD - settlements
# round 20574 of 20628
# FIELD - settlements
# round 20575 of 20628
# FIELD - settlements
# round 20576 of 20628
# FIELD - settlements
# round 20577 of 20628
# FIELD - settlements
# round 20578 of 20628
# FIELD - settlements
# round 20579 of 20628
# FIELD - settlements
# round 20580 of 20628
# FIELD - settlements
# round 20581 of 20628
# FIELD - settlements
# round 20582 of 20628
# FIELD - settlements
# round 20583 of 20628
# FIELD - settlements
# round 20584 of 20628
# FIELD - settlements
# round 20585 of 20628
# FIELD - settlements
# round 20586 of 20628
# FIELD - settlements
# round 20587 of 20628
# FIELD - settlements
# round 20588 of 20628
# FIELD - settlements
# round 20589 of 20628
# FIELD - settlements
# round 20590 of 20628
# FIELD - settlements
# round 20591 of 20628
# FIELD - settlements
# round 20592 of 20628
# FIELD - settlements
# round 20593 of 20628
# FIELD - settlements
# round 20594 of 20628
# FIELD - settlements
# round 20595 of 20628
# FIELD - settlements
# round 20596 of 20628
# FIELD - settlements
# round 20597 of 20628
# FIELD - settlements
# round 20598 of 20628
# FIELD - settlements
# round 20599 of 20628
# FIELD - settlements
# round 20600 of 20628
# FIELD - settlements
# round 20601 of 20628
# FIELD - settlements
# round 20602 of 20628
# FIELD - settlements
# round 20603 of 20628
# FIELD - settlements
# round 20604 of 20628
# FIELD - settlements
# round 20605 of 20628
# FIELD - settlements
# round 20606 of 20628
# FIELD - settlements
# round 20607 of 20628
# FIELD - settlements
# round 20608 of 20628
# FIELD - settlements
# round 20609 of 20628
# FIELD - settlements
# round 20610 of 20628
# FIELD - settlements
# round 20611 of 20628
# FIELD - settlements
# round 20612 of 20628
# FIELD - settlements
# round 20613 of 20628
# FIELD - settlements
# round 20614 of 20628
# FIELD - settlements
# round 20615 of 20628
# FIELD - settlements
# round 20616 of 20628
# FIELD - settlements
# round 20617 of 20628
# FIELD - settlements
# round 20618 of 20628
# FIELD - settlements
# round 20619 of 20628
# FIELD - settlements
# round 20620 of 20628
# FIELD - settlements
# round 20621 of 20628
# FIELD - settlements
# round 20622 of 20628
# FIELD - settlements
# round 20623 of 20628
# FIELD - settlements
# round 20624 of 20628
# FIELD - settlements
# round 20625 of 20628
# FIELD - settlements
# round 20626 of 20628
# FIELD - settlements
# round 20627 of 20628
# FIELD - settlements

# %%
# concatenate
settlements_df = pd.concat(settlement_df_list)

# %%
# enforce trades_df column types. This is necessary because the data types are not enforced by pandas dataframes. We need to enforce the types as a preprocessing step to converting to Polars
trades_df['trades_buyAmount'] = trades_df['trades_buyAmount'].astype('float64')
trades_df['trades_sellAmount'] = trades_df['trades_sellAmount'].astype('float64')
trades_df['trades_buyAmountUsd'] = trades_df['trades_buyAmountUsd'].astype('float64')
trades_df['trades_sellAmountUsd'] = trades_df['trades_sellAmountUsd'].astype('float64')
trades_df['trades_timestamp'] = trades_df['trades_timestamp'].astype('int64')
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].astype('str')
trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].astype('str')

# %%
# convert dictionaries into polars dataframes
settlement_pl = pl.from_pandas(settlements_df)
trades_pl = pl.from_pandas(trades_df)

# %%
# merge trades and settlement dataframes on the settlement transaction hash
cow_trades_pl = trades_pl.join(other=settlement_pl, left_on='trades_settlement_id', right_on='settlements_txHash', how='inner')

# %%
cow_trades_pl.shape
# Out:
# (43696, 20)

# %%
cow_trades_pl.head(5)
# Out:
# shape: (5, 20)
# ┌─────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ trades_ ┆ trades_tim ┆ trades_gas ┆ trades_fee ┆ ... ┆ settlement ┆ settlement ┆ settlement ┆ endpoint_r │
# │ id      ┆ estamp     ┆ Price      ┆ Amount     ┆     ┆ s_id       ┆ s_firstTra ┆ s_solver_i ┆ ight       │
# │ ---     ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ deTimestam ┆ d          ┆ ---        │
# │ str     ┆ i64        ┆ i64        ┆ i64        ┆     ┆ str        ┆ p          ┆ ---        ┆ str        │
# │         ┆            ┆            ┆            ┆     ┆            ┆ ---        ┆ str        ┆            │
# │         ┆            ┆            ┆            ┆     ┆            ┆ i64        ┆            ┆            │
# ╞═════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 0x2d177 ┆ 1677890687 ┆ 3403193858 ┆ 11504283   ┆ ... ┆ 0xdbeb3db4 ┆ 1677890687 ┆ 0x149d0f92 ┆ cow        │
# │ cbcc3e2 ┆            ┆ 1          ┆            ┆     ┆ bf019dac72 ┆            ┆ 82333681ee ┆            │
# │ 66aa322 ┆            ┆            ┆            ┆     ┆ 1970e0eed1 ┆            ┆ 41d3058982 ┆            │
# │ fff7f41 ┆            ┆            ┆            ┆     ┆ 75...      ┆            ┆ 4b...      ┆            │
# │ 2305... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x47ece ┆ 1677887663 ┆ 3009611088 ┆ 39337855   ┆ ... ┆ 0x8810dcd2 ┆ 1677887663 ┆ 0x149d0f92 ┆ cow        │
# │ 80491bf ┆            ┆ 4          ┆            ┆     ┆ 471391d3c6 ┆            ┆ 82333681ee ┆            │
# │ 75fd702 ┆            ┆            ┆            ┆     ┆ cc430a8080 ┆            ┆ 41d3058982 ┆            │
# │ 5549f9e ┆            ┆            ┆            ┆     ┆ a1...      ┆            ┆ 4b...      ┆            │
# │ 88c7... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x8c129 ┆ 1677885323 ┆ 1968935519 ┆ 27018672   ┆ ... ┆ 0xf8e2a0e1 ┆ 1677885323 ┆ 0xb20b86c4 ┆ cow        │
# │ 381cf3e ┆            ┆ 8          ┆            ┆     ┆ ae139b4b4a ┆            ┆ e6deeb432a ┆            │
# │ a5e26a1 ┆            ┆            ┆            ┆     ┆ f587b97058 ┆            ┆ 22d773a221 ┆            │
# │ ccdec20 ┆            ┆            ┆            ┆     ┆ 95...      ┆            ┆ 89...      ┆            │
# │ b070... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0xc07f4 ┆ 1677882191 ┆ 2122076543 ┆ 4843587156 ┆ ... ┆ 0x4eadf538 ┆ 1677882191 ┆ 0xc9ec550b ┆ cow        │
# │ 5a19d95 ┆            ┆ 2          ┆ 540876     ┆     ┆ 41770fb1ba ┆            ┆ ea1c64d779 ┆            │
# │ d27214a ┆            ┆            ┆            ┆     ┆ 903817d7e3 ┆            ┆ 124b23a262 ┆            │
# │ 7be024c ┆            ┆            ┆            ┆     ┆ 7d...      ┆            ┆ 92...      ┆            │
# │ f2e4... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x7159b ┆ 1677882011 ┆ 2151573490 ┆ 3250564090 ┆ ... ┆ 0xfb4569f8 ┆ 1677882011 ┆ 0x149d0f92 ┆ cow        │
# │ 0217959 ┆            ┆ 6          ┆ 489318     ┆     ┆ 5710f1ba09 ┆            ┆ 82333681ee ┆            │
# │ de58857 ┆            ┆            ┆            ┆     ┆ 3f1001277b ┆            ┆ 41d3058982 ┆            │
# │ 8921983 ┆            ┆            ┆            ┆     ┆ db...      ┆            ┆ 4b...      ┆            │
# │ bd06... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# └─────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
# get unique values in cow_trades_pl trades_sellToken_id column
cow_trades_pl['trades_sellToken_id'].unique()
# Out:
# shape: (2,)
# Series: 'trades_sellToken_id' [str]
# [
# 	"USDC"
# 	"WETH"
# ]

# %% [markdown]
# ### Cowswap Trades-Solver Merge

# %%
solvers = pd.read_csv('data/cowv2_solvers.csv') # load in pandas instead of polars. Having trouble replacing \ symbol in polars

# %%
# rename address to settlements_solver_id in pandas
solvers = solvers.rename(columns={"address": "settlements_solver_id"})

# %%
# NOTE - dune formats addresses as /x... need to convert '/' to '0'
solvers['settlements_solver_id'] = solvers['settlements_solver_id'].str.replace('\\', '0', regex=False)

# %%
# turn solvers into a dictionary
solvers_dict = solvers.to_dict('records')

# convert dict to polars
solvers_pl = pl.from_dicts(solvers_dict)

# %%
# inner join solvers_pl on total_settlement_tokens_pl
cow_complete_pl = cow_trades_pl.join(solvers_pl, on="settlements_solver_id", how="inner")

# %%
# drop endpoint_right column from total_settlement_tokens_solvers
cow_complete_pl = cow_complete_pl.drop('endpoint_right')

# %%
cow_complete_pl.shape
# Out:
# (43514, 22)

# %%
# save polars to parquet
cow_complete_pl.write_parquet('data/cow_complete_pl.parquet')

# %% [markdown]
# #### Basic Agg

# %%
# filter by "prod" environments
filter_df = cow_complete_pl.filter(pl.col("environment") == "prod")

# %%
# filter by "prod" environments
filter_df = cow_complete_pl.filter(pl.col("environment") == "prod")

# %%
filter_df.shape
# Out:
# (42310, 22)

# %%
# group filter_df by solver name. Check solver count
grouped_df = filter_df.groupby("name").agg(
    pl.count("trades_id").alias("total_trades")).sort("total_trades", reverse=True)

# %%
grouped_df
# Out:
# shape: (16, 2)
# ┌────────────────────┬──────────────┐
# │ name               ┆ total_trades │
# │ ---                ┆ ---          │
# │ str                ┆ u32          │
# ╞════════════════════╪══════════════╡
# │ Otex               ┆ 6510         │
# │ PLM                ┆ 6020         │
# │ Gnosis_0x          ┆ 5866         │
# │ Gnosis_1inch       ┆ 4568         │
# │ ...                ┆ ...          │
# │ Quasilabs          ┆ 956          │
# │ Atlas              ┆ 210          │
# │ Gnosis_BalancerSOR ┆ 200          │
# │ Seasolver          ┆ 164          │
# └────────────────────┴──────────────┘

# %% [markdown]
# ### Uniswap V3 Swaps

# %%
# load parquet
cow_complete_pl = pl.read_parquet('data/cow_complete_pl.parquet')

# %%
# instantiate Streamer object. 
# Note - unlike the cow queries, univ3 does not require multiple streamer instantations because the swaps field path is reset each iteration. 
# If the Cow queries were updated to use the same method, we could use the same streamer object for all queries.
univ3_ds = Streamer('https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-ethereum')

# %%
# get a query field path from the query dictionary which is automatically populated in the Streamer object
swaps_fp = univ3_ds.queryDict.get('swaps')

# %%
weth_usdc_list = [
    "0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640", # usdc/weth .05%
    "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8" #usdc/weth .3%
]

# %%
timestamps_list = cow_complete_pl['trades_timestamp'].to_list()
# get unique values in cow_timestamps
cow_timestamps = list(set(timestamps_list))

swaps_df_list = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb Cell 45 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> timestamps_list = cow_trades_pl['trades_timestamp'].to_list()
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X61sZmlsZQ%3D%3D?line=1'>2</a> # get unique values in cow_timestamps
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X61sZmlsZQ%3D%3D?line=2'>3</a> cow_timestamps = list(set(timestamps_list))
#
# NameError: name 'cow_trades_pl' is not defined

# %%
for lp in weth_usdc_list: # outer loop loops through liquidity pools
    for i in range(0, len(cow_timestamps)): # inner loop through cowswap timestamps
        print(f'round {i} of {len(cow_timestamps)}, timestamp: {cow_timestamps[i]}')
        # define the query path
        swaps_qp = swaps_fp(
            first=10,
            orderBy='timestamp',
            orderDirection='desc',
            where = {'timestamp_lt': cow_timestamps[i], 'amountInUSD_gt': filter_usd, 'amountOutUSD_gt': filter_usd, 'pool': lp} 
            )

        # run query
        df = univ3_ds.runQuery(swaps_qp)

        if df.empty:
            print('empty')
            continue
        else:
            swaps_df_list.append(df)
# Out:
# round 0 of 20603, timestamp: 1648623621
# FIELD - swaps
# round 1 of 20603, timestamp: 1652555791
# FIELD - swaps
# round 2 of 20603, timestamp: 1634992143
# FIELD - swaps
# round 3 of 20603, timestamp: 1674575891
# FIELD - swaps
# round 4 of 20603, timestamp: 1664221211
# FIELD - swaps
# round 5 of 20603, timestamp: 1636565026
# FIELD - swaps
# round 6 of 20603, timestamp: 1633681442
# FIELD - swaps
# round 7 of 20603, timestamp: 1673658407
# FIELD - swaps
# round 8 of 20603, timestamp: 1661468720
# FIELD - swaps
# round 9 of 20603, timestamp: 1638006837
# FIELD - swaps
# round 10 of 20603, timestamp: 1636696118
# FIELD - swaps
# round 11 of 20603, timestamp: 1636565047
# FIELD - swaps
# round 12 of 20603, timestamp: 1636433974
# FIELD - swaps
# round 13 of 20603, timestamp: 1640366138
# FIELD - swaps
# round 14 of 20603, timestamp: 1661993031
# FIELD - swaps
# round 15 of 20603, timestamp: 1669988435
# FIELD - swaps
# round 16 of 20603, timestamp: 1639317593
# FIELD - swaps
# round 17 of 20603, timestamp: 1669070951
# FIELD - swaps
# round 18 of 20603, timestamp: 1668022391
# FIELD - swaps
# round 19 of 20603, timestamp: 1639448695
# FIELD - swaps
# round 20 of 20603, timestamp: 1646919801
# FIELD - swaps
# round 21 of 20603, timestamp: 1643249788
# FIELD - swaps
# round 22 of 20603, timestamp: 1673658503
# FIELD - swaps
# round 23 of 20603, timestamp: 1663565963
# FIELD - swaps
# round 24 of 20603, timestamp: 1656357013
# FIELD - swaps
# round 25 of 20603, timestamp: 1654259861
# FIELD - swaps
# round 26 of 20603, timestamp: 1634992290
# FIELD - swaps
# round 27 of 20603, timestamp: 1675100327
# FIELD - swaps
# round 28 of 20603, timestamp: 1668415655
# FIELD - swaps
# round 29 of 20603, timestamp: 1665663143
# FIELD - swaps
# round 30 of 20603, timestamp: 1673658539
# FIELD - swaps
# round 31 of 20603, timestamp: 1677066419
# FIELD - swaps
# round 32 of 20603, timestamp: 1631715512
# FIELD - swaps
# round 33 of 20603, timestamp: 1657405649
# FIELD - swaps
# round 34 of 20603, timestamp: 1677459671
# FIELD - swaps
# round 35 of 20603, timestamp: 1634992346
# FIELD - swaps
# round 36 of 20603, timestamp: 1673789663
# FIELD - swaps
# round 37 of 20603, timestamp: 1637482719
# FIELD - swaps
# round 38 of 20603, timestamp: 1637089506
# FIELD - swaps
# round 39 of 20603, timestamp: 1647182062
# FIELD - swaps
# round 40 of 20603, timestamp: 1640104176
# FIELD - swaps
# round 41 of 20603, timestamp: 1642201335
# FIELD - swaps
# round 42 of 20603, timestamp: 1658716430
# FIELD - swaps
# round 43 of 20603, timestamp: 1634468110
# FIELD - swaps
# round 44 of 20603, timestamp: 1654915344
# FIELD - swaps
# round 45 of 20603, timestamp: 1642725657
# FIELD - swaps
# round 46 of 20603, timestamp: 1677197603
# FIELD - swaps
# round 47 of 20603, timestamp: 1670250791
# FIELD - swaps
# round 48 of 20603, timestamp: 1649672488
# FIELD - swaps
# round 49 of 20603, timestamp: 1664876843
# FIELD - swaps
# round 50 of 20603, timestamp: 1638531373
# FIELD - swaps
# round 51 of 20603, timestamp: 1634992437
# FIELD - swaps
# round 52 of 20603, timestamp: 1676280119
# FIELD - swaps
# round 53 of 20603, timestamp: 1638138167
# FIELD - swaps
# round 54 of 20603, timestamp: 1668940091
# FIELD - swaps
# round 55 of 20603, timestamp: 1631453500
# FIELD - swaps
# round 56 of 20603, timestamp: 1634468172
# FIELD - swaps
# round 57 of 20603, timestamp: 1650458959
# FIELD - swaps
# round 58 of 20603, timestamp: 1658323289
# FIELD - swaps
# round 59 of 20603, timestamp: 1640890724
# FIELD - swaps
# round 60 of 20603, timestamp: 1631453543
# FIELD - swaps
# round 61 of 20603, timestamp: 1668677999
# FIELD - swaps
# round 62 of 20603, timestamp: 1641021810
# FIELD - swaps
# round 63 of 20603, timestamp: 1662910840
# FIELD - swaps
# round 64 of 20603, timestamp: 1660944764
# FIELD - swaps
# round 65 of 20603, timestamp: 1631977857
# FIELD - swaps
# round 66 of 20603, timestamp: 1648230794
# FIELD - swaps
# round 67 of 20603, timestamp: 1677853067
# FIELD - swaps
# round 68 of 20603, timestamp: 1669071251
# FIELD - swaps
# round 69 of 20603, timestamp: 1660420502
# FIELD - swaps
# round 70 of 20603, timestamp: 1651638692
# FIELD - swaps
# round 71 of 20603, timestamp: 1639317926
# FIELD - swaps
# round 72 of 20603, timestamp: 1674838439
# FIELD - swaps
# round 73 of 20603, timestamp: 1641415087
# FIELD - swaps
# round 74 of 20603, timestamp: 1636696506
# FIELD - swaps
# round 75 of 20603, timestamp: 1668022715
# FIELD - swaps
# round 76 of 20603, timestamp: 1656881595
# FIELD - swaps
# round 77 of 20603, timestamp: 1653604802
# FIELD - swaps
# round 78 of 20603, timestamp: 1677722051
# FIELD - swaps
# round 79 of 20603, timestamp: 1651245522
# FIELD - swaps
# round 80 of 20603, timestamp: 1642201565
# FIELD - swaps
# round 81 of 20603, timestamp: 1662779872
# FIELD - swaps
# round 82 of 20603, timestamp: 1629618664
# FIELD - swaps
# round 83 of 20603, timestamp: 1673134571
# FIELD - swaps
# round 84 of 20603, timestamp: 1654784495
# FIELD - swaps
# round 85 of 20603, timestamp: 1631453682
# FIELD - swaps
# round 86 of 20603, timestamp: 1634992633
# FIELD - swaps
# round 87 of 20603, timestamp: 1645347327
# FIELD - swaps
# round 88 of 20603, timestamp: 1659634177
# FIELD - swaps
# round 89 of 20603, timestamp: 1639055874
# FIELD - swaps
# round 90 of 20603, timestamp: 1659109904
# FIELD - swaps
# round 91 of 20603, timestamp: 1677197855
# FIELD - swaps
# round 92 of 20603, timestamp: 1630143014
# FIELD - swaps
# round 93 of 20603, timestamp: 1667105327
# FIELD - swaps
# round 94 of 20603, timestamp: 1666056755
# FIELD - swaps
# round 95 of 20603, timestamp: 1642857016
# FIELD - swaps
# round 96 of 20603, timestamp: 1661731400
# FIELD - swaps
# round 97 of 20603, timestamp: 1673658959
# FIELD - swaps
# round 98 of 20603, timestamp: 1646002771
# FIELD - swaps
# round 99 of 20603, timestamp: 1658585685
# FIELD - swaps
# round 100 of 20603, timestamp: 1644298844
# FIELD - swaps
# round 101 of 20603, timestamp: 1630536284
# FIELD - swaps
# round 102 of 20603, timestamp: 1676280419
# FIELD - swaps
# round 103 of 20603, timestamp: 1675362923
# FIELD - swaps
# round 104 of 20603, timestamp: 1649148534
# FIELD - swaps
# round 105 of 20603, timestamp: 1633288827
# FIELD - swaps
# round 106 of 20603, timestamp: 1668940415
# FIELD - swaps
# round 107 of 20603, timestamp: 1634730624
# FIELD - swaps
# round 108 of 20603, timestamp: 1634861699
# FIELD - swaps
# round 109 of 20603, timestamp: 1631453827
# FIELD - swaps
# round 110 of 20603, timestamp: 1660551814
# FIELD - swaps
# round 111 of 20603, timestamp: 1675362959
# FIELD - swaps
# round 112 of 20603, timestamp: 1669857935
# FIELD - swaps
# round 113 of 20603, timestamp: 1668547223
# FIELD - swaps
# round 114 of 20603, timestamp: 1661993623
# FIELD - swaps
# round 115 of 20603, timestamp: 1655046809
# FIELD - swaps
# round 116 of 20603, timestamp: 1646527128
# FIELD - swaps
# round 117 of 20603, timestamp: 1666187939
# FIELD - swaps
# round 118 of 20603, timestamp: 1667498663
# FIELD - swaps
# round 119 of 20603, timestamp: 1637745334
# FIELD - swaps
# round 120 of 20603, timestamp: 1632371402
# FIELD - swaps
# round 121 of 20603, timestamp: 1653867214
# FIELD - swaps
# round 122 of 20603, timestamp: 1636958926
# FIELD - swaps
# round 123 of 20603, timestamp: 1636303567
# FIELD - swaps
# round 124 of 20603, timestamp: 1658716881
# FIELD - swaps
# round 125 of 20603, timestamp: 1664746199
# FIELD - swaps
# round 126 of 20603, timestamp: 1646396126
# FIELD - swaps
# round 127 of 20603, timestamp: 1663435499
# FIELD - swaps
# round 128 of 20603, timestamp: 1634992885
# FIELD - swaps
# round 129 of 20603, timestamp: 1673659127
# FIELD - swaps
# round 130 of 20603, timestamp: 1654784765
# FIELD - swaps
# round 131 of 20603, timestamp: 1658847999
# FIELD - swaps
# round 132 of 20603, timestamp: 1650852614
# FIELD - swaps
# round 133 of 20603, timestamp: 1675625231
# FIELD - swaps
# round 134 of 20603, timestamp: 1658323727
# FIELD - swaps
# round 135 of 20603, timestamp: 1641677590
# FIELD - swaps
# round 136 of 20603, timestamp: 1665270551
# FIELD - swaps
# round 137 of 20603, timestamp: 1639187225
# FIELD - swaps
# round 138 of 20603, timestamp: 1670382383
# FIELD - swaps
# round 139 of 20603, timestamp: 1669595951
# FIELD - swaps
# round 140 of 20603, timestamp: 1659110191
# FIELD - swaps
# round 141 of 20603, timestamp: 1636565809
# FIELD - swaps
# round 142 of 20603, timestamp: 1668023099
# FIELD - swaps
# round 143 of 20603, timestamp: 1676936003
# FIELD - swaps
# round 144 of 20603, timestamp: 1667629895
# FIELD - swaps
# round 145 of 20603, timestamp: 1671037775
# FIELD - swaps
# round 146 of 20603, timestamp: 1634468688
# FIELD - swaps
# round 147 of 20603, timestamp: 1642333016
# FIELD - swaps
# round 148 of 20603, timestamp: 1651901275
# FIELD - swaps
# round 149 of 20603, timestamp: 1644823392
# FIELD - swaps
# round 150 of 20603, timestamp: 1673659235
# FIELD - swaps
# round 151 of 20603, timestamp: 1655440228
# FIELD - swaps
# round 152 of 20603, timestamp: 1642857326
# FIELD - swaps
# round 153 of 20603, timestamp: 1659634543
# FIELD - swaps
# round 154 of 20603, timestamp: 1633158002
# FIELD - swaps
# round 155 of 20603, timestamp: 1641939832
# FIELD - swaps
# round 156 of 20603, timestamp: 1633944445
# FIELD - swaps
# round 157 of 20603, timestamp: 1639318403
# FIELD - swaps
# round 158 of 20603, timestamp: 1650852743
# FIELD - swaps
# round 159 of 20603, timestamp: 1658192777
# FIELD - swaps
# round 160 of 20603, timestamp: 1641677707
# FIELD - swaps
# round 161 of 20603, timestamp: 1629225868
# FIELD - swaps
# round 162 of 20603, timestamp: 1662780307
# FIELD - swaps
# round 163 of 20603, timestamp: 1634861974
# FIELD - swaps
# round 164 of 20603, timestamp: 1648493465
# FIELD - swaps
# round 165 of 20603, timestamp: 1671562151
# FIELD - swaps
# round 166 of 20603, timestamp: 1636959146
# FIELD - swaps
# round 167 of 20603, timestamp: 1673266091
# FIELD - swaps
# round 168 of 20603, timestamp: 1633026994
# FIELD - swaps
# round 169 of 20603, timestamp: 1649279928
# FIELD - swaps
# round 170 of 20603, timestamp: 1659765692
# FIELD - swaps
# round 171 of 20603, timestamp: 1677198275
# FIELD - swaps
# round 172 of 20603, timestamp: 1673528267
# FIELD - swaps
# round 173 of 20603, timestamp: 1665270731
# FIELD - swaps
# round 174 of 20603, timestamp: 1670382551
# FIELD - swaps
# round 175 of 20603, timestamp: 1636959199
# FIELD - swaps
# round 176 of 20603, timestamp: 1675101155
# FIELD - swaps
# round 177 of 20603, timestamp: 1664484323
# FIELD - swaps
# round 178 of 20603, timestamp: 1634993125
# FIELD - swaps
# round 179 of 20603, timestamp: 1637352425
# FIELD - swaps
# round 180 of 20603, timestamp: 1635910644
# FIELD - swaps
# round 181 of 20603, timestamp: 1673528315
# FIELD - swaps
# round 182 of 20603, timestamp: 1654522876
# FIELD - swaps
# round 183 of 20603, timestamp: 1631454205
# FIELD - swaps
# round 184 of 20603, timestamp: 1642726424
# FIELD - swaps
# round 185 of 20603, timestamp: 1655178280
# FIELD - swaps
# round 186 of 20603, timestamp: 1638925353
# FIELD - swaps
# round 187 of 20603, timestamp: 1671169079
# FIELD - swaps
# round 188 of 20603, timestamp: 1666712639
# FIELD - swaps
# round 189 of 20603, timestamp: 1653605439
# FIELD - swaps
# round 190 of 20603, timestamp: 1666974791
# FIELD - swaps
# round 191 of 20603, timestamp: 1649280074
# FIELD - swaps
# round 192 of 20603, timestamp: 1644168278
# FIELD - swaps
# round 193 of 20603, timestamp: 1636566118
# FIELD - swaps
# round 194 of 20603, timestamp: 1650984041
# FIELD - swaps
# round 195 of 20603, timestamp: 1655309422
# FIELD - swaps
# round 196 of 20603, timestamp: 1634600050
# FIELD - swaps
# round 197 of 20603, timestamp: 1633027187
# FIELD - swaps
# round 198 of 20603, timestamp: 1651639415
# FIELD - swaps
# round 199 of 20603, timestamp: 1660552323
# FIELD - swaps
# round 200 of 20603, timestamp: 1670251655
# FIELD - swaps
# round 201 of 20603, timestamp: 1651901580
# FIELD - swaps
# round 202 of 20603, timestamp: 1675625615
# FIELD - swaps
# round 203 of 20603, timestamp: 1646920851
# FIELD - swaps
# round 204 of 20603, timestamp: 1634993305
# FIELD - swaps
# round 205 of 20603, timestamp: 1641153694
# FIELD - swaps
# round 206 of 20603, timestamp: 1638532262
# FIELD - swaps
# round 207 of 20603, timestamp: 1631454374
# FIELD - swaps
# round 208 of 20603, timestamp: 1650328750
# FIELD - swaps
# round 209 of 20603, timestamp: 1655178416
# FIELD - swaps
# round 210 of 20603, timestamp: 1636566193
# FIELD - swaps
# round 211 of 20603, timestamp: 1637483707
# FIELD - swaps
# round 212 of 20603, timestamp: 1633027259
# FIELD - swaps
# round 213 of 20603, timestamp: 1674577091
# FIELD - swaps
# round 214 of 20603, timestamp: 1642726601
# FIELD - swaps
# round 215 of 20603, timestamp: 1675494611
# FIELD - swaps
# round 216 of 20603, timestamp: 1639187674
# FIELD - swaps
# round 217 of 20603, timestamp: 1667892443
# FIELD - swaps
# round 218 of 20603, timestamp: 1667499227
# FIELD - swaps
# round 219 of 20603, timestamp: 1661207791
# FIELD - swaps
# round 220 of 20603, timestamp: 1638532344
# FIELD - swaps
# round 221 of 20603, timestamp: 1672479995
# FIELD - swaps
# round 222 of 20603, timestamp: 1668547835
# FIELD - swaps
# round 223 of 20603, timestamp: 1634469146
# FIELD - swaps
# round 224 of 20603, timestamp: 1660552482
# FIELD - swaps
# round 225 of 20603, timestamp: 1643250978
# FIELD - swaps
# round 226 of 20603, timestamp: 1632240936
# FIELD - swaps
# round 227 of 20603, timestamp: 1638925613
# FIELD - swaps
# round 228 of 20603, timestamp: 1639187759
# FIELD - swaps
# round 229 of 20603, timestamp: 1654785337
# FIELD - swaps
# round 230 of 20603, timestamp: 1675363643
# FIELD - swaps
# round 231 of 20603, timestamp: 1673659715
# FIELD - swaps
# round 232 of 20603, timestamp: 1651901769
# FIELD - swaps
# round 233 of 20603, timestamp: 1671169355
# FIELD - swaps
# round 234 of 20603, timestamp: 1652294992
# FIELD - swaps
# round 235 of 20603, timestamp: 1649149269
# FIELD - swaps
# round 236 of 20603, timestamp: 1653081434
# FIELD - swaps
# round 237 of 20603, timestamp: 1654654299
# FIELD - swaps
# round 238 of 20603, timestamp: 1660159325
# FIELD - swaps
# round 239 of 20603, timestamp: 1657800035
# FIELD - swaps
# round 240 of 20603, timestamp: 1633289577
# FIELD - swaps
# round 241 of 20603, timestamp: 1673004395
# FIELD - swaps
# round 242 of 20603, timestamp: 1653474675
# FIELD - swaps
# round 243 of 20603, timestamp: 1668547967
# FIELD - swaps
# round 244 of 20603, timestamp: 1658193287
# FIELD - swaps
# round 245 of 20603, timestamp: 1629881744
# FIELD - swaps
# round 246 of 20603, timestamp: 1648493979
# FIELD - swaps
# round 247 of 20603, timestamp: 1637090717
# FIELD - swaps
# round 248 of 20603, timestamp: 1636566431
# FIELD - swaps
# round 249 of 20603, timestamp: 1652819371
# FIELD - swaps
# round 250 of 20603, timestamp: 1629226418
# FIELD - swaps
# round 251 of 20603, timestamp: 1674708407
# FIELD - swaps
# round 252 of 20603, timestamp: 1658717625
# FIELD - swaps
# round 253 of 20603, timestamp: 1652295097
# FIELD - swaps
# round 254 of 20603, timestamp: 1640498623
# FIELD - swaps
# round 255 of 20603, timestamp: 1636828607
# FIELD - swaps
# round 256 of 20603, timestamp: 1645741514
# FIELD - swaps
# round 257 of 20603, timestamp: 1655965133
# FIELD - swaps
# round 258 of 20603, timestamp: 1633027540
# FIELD - swaps
# round 259 of 20603, timestamp: 1661470169
# FIELD - swaps
# round 260 of 20603, timestamp: 1663305191
# FIELD - swaps
# round 261 of 20603, timestamp: 1637352936
# FIELD - swaps
# round 262 of 20603, timestamp: 1667761643
# FIELD - swaps
# round 263 of 20603, timestamp: 1639056876
# FIELD - swaps
# round 264 of 20603, timestamp: 1673922035
# FIELD - swaps
# round 265 of 20603, timestamp: 1660159495
# FIELD - swaps
# round 266 of 20603, timestamp: 1656489492
# FIELD - swaps
# round 267 of 20603, timestamp: 1652688405
# FIELD - swaps
# round 268 of 20603, timestamp: 1677067811
# FIELD - swaps
# round 269 of 20603, timestamp: 1663305251
# FIELD - swaps
# round 270 of 20603, timestamp: 1668154919
# FIELD - swaps
# round 271 of 20603, timestamp: 1641547335
# FIELD - swaps
# round 272 of 20603, timestamp: 1649149527
# FIELD - swaps
# round 273 of 20603, timestamp: 1657275992
# FIELD - swaps
# round 274 of 20603, timestamp: 1658717794
# FIELD - swaps
# round 275 of 20603, timestamp: 1674577523
# FIELD - swaps
# round 276 of 20603, timestamp: 1651771002
# FIELD - swaps
# round 277 of 20603, timestamp: 1638794892
# FIELD - swaps
# round 278 of 20603, timestamp: 1663698575
# FIELD - swaps
# round 279 of 20603, timestamp: 1647576725
# FIELD - swaps
# round 280 of 20603, timestamp: 1671038615
# FIELD - swaps
# round 281 of 20603, timestamp: 1673922203
# FIELD - swaps
# round 282 of 20603, timestamp: 1652819615
# FIELD - swaps
# round 283 of 20603, timestamp: 1630537383
# FIELD - swaps
# round 284 of 20603, timestamp: 1636173486
# FIELD - swaps
# round 285 of 20603, timestamp: 1674577583
# FIELD - swaps
# round 286 of 20603, timestamp: 1669465775
# FIELD - swaps
# round 287 of 20603, timestamp: 1659635376
# FIELD - swaps
# round 288 of 20603, timestamp: 1638401713
# FIELD - swaps
# round 289 of 20603, timestamp: 1675101875
# FIELD - swaps
# round 290 of 20603, timestamp: 1669727927
# FIELD - swaps
# round 291 of 20603, timestamp: 1668023999
# FIELD - swaps
# round 292 of 20603, timestamp: 1634207428
# FIELD - swaps
# round 293 of 20603, timestamp: 1653606091
# FIELD - swaps
# round 294 of 20603, timestamp: 1637091021
# FIELD - swaps
# round 295 of 20603, timestamp: 1665402575
# FIELD - swaps
# round 296 of 20603, timestamp: 1639057109
# FIELD - swaps
# round 297 of 20603, timestamp: 1642071770
# FIELD - swaps
# round 298 of 20603, timestamp: 1637353180
# FIELD - swaps
# round 299 of 20603, timestamp: 1631454943
# FIELD - swaps
# round 300 of 20603, timestamp: 1650853606
# FIELD - swaps
# round 301 of 20603, timestamp: 1670907623
# FIELD - swaps
# round 302 of 20603, timestamp: 1651246827
# FIELD - swaps
# round 303 of 20603, timestamp: 1672742639
# FIELD - swaps
# round 304 of 20603, timestamp: 1636173554
# FIELD - swaps
# round 305 of 20603, timestamp: 1651640056
# FIELD - swaps
# round 306 of 20603, timestamp: 1656620794
# FIELD - swaps
# round 307 of 20603, timestamp: 1652426493
# FIELD - swaps
# round 308 of 20603, timestamp: 1641416454
# FIELD - swaps
# round 309 of 20603, timestamp: 1637484298
# FIELD - swaps
# round 310 of 20603, timestamp: 1659111181
# FIELD - swaps
# round 311 of 20603, timestamp: 1669596947
# FIELD - swaps
# round 312 of 20603, timestamp: 1629095699
# FIELD - swaps
# round 313 of 20603, timestamp: 1650591509
# FIELD - swaps
# round 314 of 20603, timestamp: 1662781210
# FIELD - swaps
# round 315 of 20603, timestamp: 1675364135
# FIELD - swaps
# round 316 of 20603, timestamp: 1641678632
# FIELD - swaps
# round 317 of 20603, timestamp: 1634469673
# FIELD - swaps
# round 318 of 20603, timestamp: 1673660207
# FIELD - swaps
# round 319 of 20603, timestamp: 1636960048
# FIELD - swaps
# round 320 of 20603, timestamp: 1669203767
# FIELD - swaps
# round 321 of 20603, timestamp: 1668810551
# FIELD - swaps
# round 322 of 20603, timestamp: 1651902264
# FIELD - swaps
# round 323 of 20603, timestamp: 1657931580
# FIELD - swaps
# round 324 of 20603, timestamp: 1672349507
# FIELD - swaps
# round 325 of 20603, timestamp: 1633683267
# FIELD - swaps
# round 326 of 20603, timestamp: 1654261584
# FIELD - swaps
# round 327 of 20603, timestamp: 1661732691
# FIELD - swaps
# round 328 of 20603, timestamp: 1636173653
# FIELD - swaps
# round 329 of 20603, timestamp: 1662519133
# FIELD - swaps
# round 330 of 20603, timestamp: 1634600798
# FIELD - swaps
# round 331 of 20603, timestamp: 1646266213
# FIELD - swaps
# round 332 of 20603, timestamp: 1639974757
# FIELD - swaps
# round 333 of 20603, timestamp: 1646135153
# FIELD - swaps
# round 334 of 20603, timestamp: 1665402743
# FIELD - swaps
# round 335 of 20603, timestamp: 1659111293
# FIELD - swaps
# round 336 of 20603, timestamp: 1639188350
# FIELD - swaps
# round 337 of 20603, timestamp: 1674053507
# FIELD - swaps
# round 338 of 20603, timestamp: 1670383511
# FIELD - swaps
# round 339 of 20603, timestamp: 1676412827
# FIELD - swaps
# round 340 of 20603, timestamp: 1660290971
# FIELD - swaps
# round 341 of 20603, timestamp: 1639188381
# FIELD - swaps
# round 342 of 20603, timestamp: 1669597091
# FIELD - swaps
# round 343 of 20603, timestamp: 1658718115
# FIELD - swaps
# round 344 of 20603, timestamp: 1652033446
# FIELD - swaps
# round 345 of 20603, timestamp: 1660159911
# FIELD - swaps
# round 346 of 20603, timestamp: 1629489069
# FIELD - swaps
# round 347 of 20603, timestamp: 1644038063
# FIELD - swaps
# round 348 of 20603, timestamp: 1673267123
# FIELD - swaps
# round 349 of 20603, timestamp: 1677068219
# FIELD - swaps
# round 350 of 20603, timestamp: 1665664955
# FIELD - swaps
# round 351 of 20603, timestamp: 1651771327
# FIELD - swaps
# round 352 of 20603, timestamp: 1673398211
# FIELD - swaps
# round 353 of 20603, timestamp: 1643120586
# FIELD - swaps
# round 354 of 20603, timestamp: 1639057361
# FIELD - swaps
# round 355 of 20603, timestamp: 1650591708
# FIELD - swaps
# round 356 of 20603, timestamp: 1637746652
# FIELD - swaps
# round 357 of 20603, timestamp: 1674840035
# FIELD - swaps
# round 358 of 20603, timestamp: 1670907875
# FIELD - swaps
# round 359 of 20603, timestamp: 1668155375
# FIELD - swaps
# round 360 of 20603, timestamp: 1670776823
# FIELD - swaps
# round 361 of 20603, timestamp: 1648494602
# FIELD - swaps
# round 362 of 20603, timestamp: 1663830035
# FIELD - swaps
# round 363 of 20603, timestamp: 1642596376
# FIELD - swaps
# round 364 of 20603, timestamp: 1657538591
# FIELD - swaps
# round 365 of 20603, timestamp: 1649805349
# FIELD - swaps
# round 366 of 20603, timestamp: 1669597235
# FIELD - swaps
# round 367 of 20603, timestamp: 1634994235
# FIELD - swaps
# round 368 of 20603, timestamp: 1629882438
# FIELD - swaps
# round 369 of 20603, timestamp: 1650985034
# FIELD - swaps
# round 370 of 20603, timestamp: 1659111508
# FIELD - swaps
# round 371 of 20603, timestamp: 1658456148
# FIELD - swaps
# round 372 of 20603, timestamp: 1649150040
# FIELD - swaps
# round 373 of 20603, timestamp: 1629882462
# FIELD - swaps
# round 374 of 20603, timestamp: 1636960353
# FIELD - swaps
# round 375 of 20603, timestamp: 1674840167
# FIELD - swaps
# round 376 of 20603, timestamp: 1640237166
# FIELD - swaps
# round 377 of 20603, timestamp: 1674315887
# FIELD - swaps
# round 378 of 20603, timestamp: 1660946548
# FIELD - swaps
# round 379 of 20603, timestamp: 1639319681
# FIELD - swaps
# round 380 of 20603, timestamp: 1636042890
# FIELD - swaps
# round 381 of 20603, timestamp: 1653737612
# FIELD - swaps
# round 382 of 20603, timestamp: 1662257296
# FIELD - swaps
# round 383 of 20603, timestamp: 1638533266
# FIELD - swaps
# round 384 of 20603, timestamp: 1668941975
# FIELD - swaps
# round 385 of 20603, timestamp: 1655572632
# FIELD - swaps
# round 386 of 20603, timestamp: 1649936539
# FIELD - swaps
# round 387 of 20603, timestamp: 1665665183
# FIELD - swaps
# round 388 of 20603, timestamp: 1660946594
# FIELD - swaps
# round 389 of 20603, timestamp: 1639581860
# FIELD - swaps
# round 390 of 20603, timestamp: 1673005223
# FIELD - swaps
# round 391 of 20603, timestamp: 1671825575
# FIELD - swaps
# round 392 of 20603, timestamp: 1674840239
# FIELD - swaps
# round 393 of 20603, timestamp: 1650985142
# FIELD - swaps
# round 394 of 20603, timestamp: 1650460861
# FIELD - swaps
# round 395 of 20603, timestamp: 1677723839
# FIELD - swaps
# round 396 of 20603, timestamp: 1636567234
# FIELD - swaps
# round 397 of 20603, timestamp: 1652033737
# FIELD - swaps
# round 398 of 20603, timestamp: 1666844879
# FIELD - swaps
# round 399 of 20603, timestamp: 1657407695
# FIELD - swaps
# round 400 of 20603, timestamp: 1637746899
# FIELD - swaps
# round 401 of 20603, timestamp: 1655965911
# FIELD - swaps
# round 402 of 20603, timestamp: 1642072284
# FIELD - swaps
# round 403 of 20603, timestamp: 1677199583
# FIELD - swaps
# round 404 of 20603, timestamp: 1671694571
# FIELD - swaps
# round 405 of 20603, timestamp: 1632766188
# FIELD - swaps
# round 406 of 20603, timestamp: 1650591986
# FIELD - swaps
# round 407 of 20603, timestamp: 1651509494
# FIELD - swaps
# round 408 of 20603, timestamp: 1674447107
# FIELD - swaps
# round 409 of 20603, timestamp: 1666713863
# FIELD - swaps
# round 410 of 20603, timestamp: 1677199643
# FIELD - swaps
# round 411 of 20603, timestamp: 1636829471
# FIELD - swaps
# round 412 of 20603, timestamp: 1648888106
# FIELD - swaps
# round 413 of 20603, timestamp: 1676020019
# FIELD - swaps
# round 414 of 20603, timestamp: 1639319875
# FIELD - swaps
# round 415 of 20603, timestamp: 1658718543
# FIELD - swaps
# round 416 of 20603, timestamp: 1674053975
# FIELD - swaps
# round 417 of 20603, timestamp: 1652296030
# FIELD - swaps
# round 418 of 20603, timestamp: 1677461867
# FIELD - swaps
# round 419 of 20603, timestamp: 1641285996
# FIELD - swaps
# round 420 of 20603, timestamp: 1669990775
# FIELD - swaps
# round 421 of 20603, timestamp: 1648363900
# FIELD - swaps
# round 422 of 20603, timestamp: 1675102595
# FIELD - swaps
# round 423 of 20603, timestamp: 1647053187
# FIELD - swaps
# round 424 of 20603, timestamp: 1631979912
# FIELD - swaps
# round 425 of 20603, timestamp: 1660946834
# FIELD - swaps
# round 426 of 20603, timestamp: 1632111018
# FIELD - swaps
# round 427 of 20603, timestamp: 1641810347
# FIELD - swaps
# round 428 of 20603, timestamp: 1676282291
# FIELD - swaps
# round 429 of 20603, timestamp: 1658718643
# FIELD - swaps
# round 430 of 20603, timestamp: 1668549047
# FIELD - swaps
# round 431 of 20603, timestamp: 1642858941
# FIELD - swaps
# round 432 of 20603, timestamp: 1660029377
# FIELD - swaps
# round 433 of 20603, timestamp: 1668155855
# FIELD - swaps
# round 434 of 20603, timestamp: 1676675543
# FIELD - swaps
# round 435 of 20603, timestamp: 1657539033
# FIELD - swaps
# round 436 of 20603, timestamp: 1642072541
# FIELD - swaps
# round 437 of 20603, timestamp: 1636698591
# FIELD - swaps
# round 438 of 20603, timestamp: 1658718690
# FIELD - swaps
# round 439 of 20603, timestamp: 1640368656
# FIELD - swaps
# round 440 of 20603, timestamp: 1650461215
# FIELD - swaps
# round 441 of 20603, timestamp: 1674316331
# FIELD - swaps
# round 442 of 20603, timestamp: 1677199919
# FIELD - swaps
# round 443 of 20603, timestamp: 1658718769
# FIELD - swaps
# round 444 of 20603, timestamp: 1651771959
# FIELD - swaps
# round 445 of 20603, timestamp: 1644038724
# FIELD - swaps
# round 446 of 20603, timestamp: 1647446599
# FIELD - swaps
# round 447 of 20603, timestamp: 1646004808
# FIELD - swaps
# round 448 of 20603, timestamp: 1652296277
# FIELD - swaps
# round 449 of 20603, timestamp: 1675889243
# FIELD - swaps
# round 450 of 20603, timestamp: 1658718816
# FIELD - swaps
# round 451 of 20603, timestamp: 1630407315
# FIELD - swaps
# round 452 of 20603, timestamp: 1642728093
# FIELD - swaps
# round 453 of 20603, timestamp: 1637091997
# FIELD - swaps
# round 454 of 20603, timestamp: 1639058079
# FIELD - swaps
# round 455 of 20603, timestamp: 1643776672
# FIELD - swaps
# round 456 of 20603, timestamp: 1634470561
# FIELD - swaps
# round 457 of 20603, timestamp: 1658325678
# FIELD - swaps
# round 458 of 20603, timestamp: 1629883054
# FIELD - swaps
# round 459 of 20603, timestamp: 1673661107
# FIELD - swaps
# round 460 of 20603, timestamp: 1671039707
# FIELD - swaps
# round 461 of 20603, timestamp: 1663699691
# FIELD - swaps
# round 462 of 20603, timestamp: 1651772139
# FIELD - swaps
# round 463 of 20603, timestamp: 1653869298
# FIELD - swaps
# round 464 of 20603, timestamp: 1648102149
# FIELD - swaps
# round 465 of 20603, timestamp: 1645349649
# FIELD - swaps
# round 466 of 20603, timestamp: 1636305691
# FIELD - swaps
# round 467 of 20603, timestamp: 1654000413
# FIELD - swaps
# round 468 of 20603, timestamp: 1659112230
# FIELD - swaps
# round 469 of 20603, timestamp: 1672350503
# FIELD - swaps
# round 470 of 20603, timestamp: 1673661227
# FIELD - swaps
# round 471 of 20603, timestamp: 1652296504
# FIELD - swaps
# round 472 of 20603, timestamp: 1670777663
# FIELD - swaps
# round 473 of 20603, timestamp: 1651641151
# FIELD - swaps
# round 474 of 20603, timestamp: 1660160846
# FIELD - swaps
# round 475 of 20603, timestamp: 1670908763
# FIELD - swaps
# round 476 of 20603, timestamp: 1666714463
# FIELD - swaps
# round 477 of 20603, timestamp: 1652034403
# FIELD - swaps
# round 478 of 20603, timestamp: 1669598075
# FIELD - swaps
# round 479 of 20603, timestamp: 1673661311
# FIELD - swaps
# round 480 of 20603, timestamp: 1639189379
# FIELD - swaps
# round 481 of 20603, timestamp: 1676675975
# FIELD - swaps
# round 482 of 20603, timestamp: 1667238791
# FIELD - swaps
# round 483 of 20603, timestamp: 1657146254
# FIELD - swaps
# round 484 of 20603, timestamp: 1647446927
# FIELD - swaps
# round 485 of 20603, timestamp: 1645218704
# FIELD - swaps
# round 486 of 20603, timestamp: 1674054575
# FIELD - swaps
# round 487 of 20603, timestamp: 1660029871
# FIELD - swaps
# round 488 of 20603, timestamp: 1639582642
# FIELD - swaps
# round 489 of 20603, timestamp: 1665665975
# FIELD - swaps
# round 490 of 20603, timestamp: 1677724607
# FIELD - swaps
# round 491 of 20603, timestamp: 1663568831
# FIELD - swaps
# round 492 of 20603, timestamp: 1663830983
# FIELD - swaps
# round 493 of 20603, timestamp: 1673661395
# FIELD - swaps
# round 494 of 20603, timestamp: 1669729235
# FIELD - swaps
# round 495 of 20603, timestamp: 1657932757
# FIELD - swaps
# round 496 of 20603, timestamp: 1635781589
# FIELD - swaps
# round 497 of 20603, timestamp: 1654524887
# FIELD - swaps
# round 498 of 20603, timestamp: 1675103195
# FIELD - swaps
# round 499 of 20603, timestamp: 1639058400
# FIELD - swaps
# round 500 of 20603, timestamp: 1664355299
# FIELD - swaps
# round 501 of 20603, timestamp: 1668942839
# FIELD - swaps
# round 502 of 20603, timestamp: 1636961272
# FIELD - swaps
# round 503 of 20603, timestamp: 1676151803
# FIELD - swaps
# round 504 of 20603, timestamp: 1658063877
# FIELD - swaps
# round 505 of 20603, timestamp: 1649282054
# FIELD - swaps
# round 506 of 20603, timestamp: 1673006087
# FIELD - swaps
# round 507 of 20603, timestamp: 1655311375
# FIELD - swaps
# round 508 of 20603, timestamp: 1666976795
# FIELD - swaps
# round 509 of 20603, timestamp: 1650854943
# FIELD - swaps
# round 510 of 20603, timestamp: 1639189538
# FIELD - swaps
# round 511 of 20603, timestamp: 1645874213
# FIELD - swaps
# round 512 of 20603, timestamp: 1648495665
# FIELD - swaps
# round 513 of 20603, timestamp: 1668287543
# FIELD - swaps
# round 514 of 20603, timestamp: 1673530439
# FIELD - swaps
# round 515 of 20603, timestamp: 1657932873
# FIELD - swaps
# round 516 of 20603, timestamp: 1674054731
# FIELD - swaps
# round 517 of 20603, timestamp: 1673661515
# FIELD - swaps
# round 518 of 20603, timestamp: 1661209675
# FIELD - swaps
# round 519 of 20603, timestamp: 1671040079
# FIELD - swaps
# round 520 of 20603, timestamp: 1650986069
# FIELD - swaps
# round 521 of 20603, timestamp: 1629883478
# FIELD - swaps
# round 522 of 20603, timestamp: 1677200471
# FIELD - swaps
# round 523 of 20603, timestamp: 1658850397
# FIELD - swaps
# round 524 of 20603, timestamp: 1641679967
# FIELD - swaps
# round 525 of 20603, timestamp: 1638796386
# FIELD - swaps
# round 526 of 20603, timestamp: 1655311462
# FIELD - swaps
# round 527 of 20603, timestamp: 1673530475
# FIELD - swaps
# round 528 of 20603, timestamp: 1672350839
# FIELD - swaps
# round 529 of 20603, timestamp: 1673006207
# FIELD - swaps
# round 530 of 20603, timestamp: 1634471041
# FIELD - swaps
# round 531 of 20603, timestamp: 1669336199
# FIELD - swaps
# round 532 of 20603, timestamp: 1668156551
# FIELD - swaps
# round 533 of 20603, timestamp: 1642597516
# FIELD - swaps
# round 534 of 20603, timestamp: 1671564431
# FIELD - swaps
# round 535 of 20603, timestamp: 1673268371
# FIELD - swaps
# round 536 of 20603, timestamp: 1648233622
# FIELD - swaps
# round 537 of 20603, timestamp: 1675365539
# FIELD - swaps
# round 538 of 20603, timestamp: 1676151995
# FIELD - swaps
# round 539 of 20603, timestamp: 1650986180
# FIELD - swaps
# round 540 of 20603, timestamp: 1646398665
# FIELD - swaps
# round 541 of 20603, timestamp: 1660554442
# FIELD - swaps
# round 542 of 20603, timestamp: 1648233678
# FIELD - swaps
# round 543 of 20603, timestamp: 1640893652
# FIELD - swaps
# round 544 of 20603, timestamp: 1638927577
# FIELD - swaps
# round 545 of 20603, timestamp: 1669729499
# FIELD - swaps
# round 546 of 20603, timestamp: 1676676323
# FIELD - swaps
# round 547 of 20603, timestamp: 1641811190
# FIELD - swaps
# round 548 of 20603, timestamp: 1647971582
# FIELD - swaps
# round 549 of 20603, timestamp: 1668943127
# FIELD - swaps
# round 550 of 20603, timestamp: 1645743388
# FIELD - swaps
# round 551 of 20603, timestamp: 1636044070
# FIELD - swaps
# round 552 of 20603, timestamp: 1669729583
# FIELD - swaps
# round 553 of 20603, timestamp: 1638534447
# FIELD - swaps
# round 554 of 20603, timestamp: 1651248437
# FIELD - swaps
# round 555 of 20603, timestamp: 1658981689
# FIELD - swaps
# round 556 of 20603, timestamp: 1641680192
# FIELD - swaps
# round 557 of 20603, timestamp: 1665404231
# FIELD - swaps
# round 558 of 20603, timestamp: 1649544522
# FIELD - swaps
# round 559 of 20603, timestamp: 1671040343
# FIELD - swaps
# round 560 of 20603, timestamp: 1666977119
# FIELD - swaps
# round 561 of 20603, timestamp: 1661996389
# FIELD - swaps
# round 562 of 20603, timestamp: 1653607789
# FIELD - swaps
# round 563 of 20603, timestamp: 1642335606
# FIELD - swaps
# round 564 of 20603, timestamp: 1676545403
# FIELD - swaps
# round 565 of 20603, timestamp: 1660030342
# FIELD - swaps
# round 566 of 20603, timestamp: 1633815947
# FIELD - swaps
# round 567 of 20603, timestamp: 1657933204
# FIELD - swaps
# round 568 of 20603, timestamp: 1648496021
# FIELD - swaps
# round 569 of 20603, timestamp: 1647447452
# FIELD - swaps
# round 570 of 20603, timestamp: 1676676515
# FIELD - swaps
# round 571 of 20603, timestamp: 1674317219
# FIELD - swaps
# round 572 of 20603, timestamp: 1669991843
# FIELD - swaps
# round 573 of 20603, timestamp: 1671433643
# FIELD - swaps
# round 574 of 20603, timestamp: 1650855342
# FIELD - swaps
# round 575 of 20603, timestamp: 1668943283
# FIELD - swaps
# round 576 of 20603, timestamp: 1639583157
# FIELD - swaps
# round 577 of 20603, timestamp: 1633947066
# FIELD - swaps
# round 578 of 20603, timestamp: 1653083583
# FIELD - swaps
# round 579 of 20603, timestamp: 1641418176
# FIELD - swaps
# round 580 of 20603, timestamp: 1652166084
# FIELD - swaps
# round 581 of 20603, timestamp: 1650462149
# FIELD - swaps
# round 582 of 20603, timestamp: 1644301764
# FIELD - swaps
# round 583 of 20603, timestamp: 1639058885
# FIELD - swaps
# round 584 of 20603, timestamp: 1653345738
# FIELD - swaps
# round 585 of 20603, timestamp: 1645350369
# FIELD - swaps
# round 586 of 20603, timestamp: 1631325667
# FIELD - swaps
# round 587 of 20603, timestamp: 1673530859
# FIELD - swaps
# round 588 of 20603, timestamp: 1663831535
# FIELD - swaps
# round 589 of 20603, timestamp: 1676283383
# FIELD - swaps
# round 590 of 20603, timestamp: 1666977275
# FIELD - swaps
# round 591 of 20603, timestamp: 1659637250
# FIELD - swaps
# round 592 of 20603, timestamp: 1677331991
# FIELD - swaps
# round 593 of 20603, timestamp: 1660947995
# FIELD - swaps
# round 594 of 20603, timestamp: 1654787619
# FIELD - swaps
# round 595 of 20603, timestamp: 1639845411
# FIELD - swaps
# round 596 of 20603, timestamp: 1639583276
# FIELD - swaps
# round 597 of 20603, timestamp: 1651510830
# FIELD - swaps
# round 598 of 20603, timestamp: 1645612600
# FIELD - swaps
# round 599 of 20603, timestamp: 1652166203
# FIELD - swaps
# round 600 of 20603, timestamp: 1642597949
# FIELD - swaps
# round 601 of 20603, timestamp: 1675365959
# FIELD - swaps
# round 602 of 20603, timestamp: 1641287246
# FIELD - swaps
# round 603 of 20603, timestamp: 1634995795
# FIELD - swaps
# round 604 of 20603, timestamp: 1647316566
# FIELD - swaps
# round 605 of 20603, timestamp: 1643384410
# FIELD - swaps
# round 606 of 20603, timestamp: 1639059038
# FIELD - swaps
# round 607 of 20603, timestamp: 1665535583
# FIELD - swaps
# round 608 of 20603, timestamp: 1648496224
# FIELD - swaps
# round 609 of 20603, timestamp: 1674055271
# FIELD - swaps
# round 610 of 20603, timestamp: 1639845481
# FIELD - swaps
# round 611 of 20603, timestamp: 1652297326
# FIELD - swaps
# round 612 of 20603, timestamp: 1655311984
# FIELD - swaps
# round 613 of 20603, timestamp: 1674055307
# FIELD - swaps
# round 614 of 20603, timestamp: 1635651214
# FIELD - swaps
# round 615 of 20603, timestamp: 1643908760
# FIELD - swaps
# round 616 of 20603, timestamp: 1671433883
# FIELD - swaps
# round 617 of 20603, timestamp: 1674448547
# FIELD - swaps
# round 618 of 20603, timestamp: 1658457769
# FIELD - swaps
# round 619 of 20603, timestamp: 1669598891
# FIELD - swaps
# round 620 of 20603, timestamp: 1631456940
# FIELD - swaps
# round 621 of 20603, timestamp: 1649675953
# FIELD - swaps
# round 622 of 20603, timestamp: 1674055355
# FIELD - swaps
# round 623 of 20603, timestamp: 1631981253
# FIELD - swaps
# round 624 of 20603, timestamp: 1631850182
# FIELD - swaps
# round 625 of 20603, timestamp: 1674841799
# FIELD - swaps
# round 626 of 20603, timestamp: 1635389132
# FIELD - swaps
# round 627 of 20603, timestamp: 1658064589
# FIELD - swaps
# round 628 of 20603, timestamp: 1642073805
# FIELD - swaps
# round 629 of 20603, timestamp: 1674710735
# FIELD - swaps
# round 630 of 20603, timestamp: 1642467026
# FIELD - swaps
# round 631 of 20603, timestamp: 1674055379
# FIELD - swaps
# round 632 of 20603, timestamp: 1676938979
# FIELD - swaps
# round 633 of 20603, timestamp: 1669992167
# FIELD - swaps
# round 634 of 20603, timestamp: 1668419303
# FIELD - swaps
# round 635 of 20603, timestamp: 1645350637
# FIELD - swaps
# round 636 of 20603, timestamp: 1651511022
# FIELD - swaps
# round 637 of 20603, timestamp: 1653083906
# FIELD - swaps
# round 638 of 20603, timestamp: 1649151750
# FIELD - swaps
# round 639 of 20603, timestamp: 1636962058
# FIELD - swaps
# round 640 of 20603, timestamp: 1657933581
# FIELD - swaps
# round 641 of 20603, timestamp: 1657802512
# FIELD - swaps
# round 642 of 20603, timestamp: 1651642129
# FIELD - swaps
# round 643 of 20603, timestamp: 1662390045
# FIELD - swaps
# round 644 of 20603, timestamp: 1634471714
# FIELD - swaps
# round 645 of 20603, timestamp: 1631457063
# FIELD - swaps
# round 646 of 20603, timestamp: 1650986795
# FIELD - swaps
# round 647 of 20603, timestamp: 1658326836
# FIELD - swaps
# round 648 of 20603, timestamp: 1652297528
# FIELD - swaps
# round 649 of 20603, timestamp: 1643122495
# FIELD - swaps
# round 650 of 20603, timestamp: 1631063872
# FIELD - swaps
# round 651 of 20603, timestamp: 1674055499
# FIELD - swaps
# round 652 of 20603, timestamp: 1658064729
# FIELD - swaps
# round 653 of 20603, timestamp: 1673006939
# FIELD - swaps
# round 654 of 20603, timestamp: 1638928226
# FIELD - swaps
# round 655 of 20603, timestamp: 1644957555
# FIELD - swaps
# round 656 of 20603, timestamp: 1657933687
# FIELD - swaps
# round 657 of 20603, timestamp: 1656622968
# FIELD - swaps
# round 658 of 20603, timestamp: 1637224314
# FIELD - swaps
# round 659 of 20603, timestamp: 1635651463
# FIELD - swaps
# round 660 of 20603, timestamp: 1675366283
# FIELD - swaps
# round 661 of 20603, timestamp: 1668943763
# FIELD - swaps
# round 662 of 20603, timestamp: 1640107926
# FIELD - swaps
# round 663 of 20603, timestamp: 1634078617
# FIELD - swaps
# round 664 of 20603, timestamp: 1677463451
# FIELD - swaps
# round 665 of 20603, timestamp: 1655181212
# FIELD - swaps
# round 666 of 20603, timestamp: 1668288419
# FIELD - swaps
# round 667 of 20603, timestamp: 1639190441
# FIELD - swaps
# round 668 of 20603, timestamp: 1673531315
# FIELD - swaps
# round 669 of 20603, timestamp: 1641287603
# FIELD - swaps
# round 670 of 20603, timestamp: 1645612985
# FIELD - swaps
# round 671 of 20603, timestamp: 1639845821
# FIELD - swaps
# round 672 of 20603, timestamp: 1673531339
# FIELD - swaps
# round 673 of 20603, timestamp: 1672875983
# FIELD - swaps
# round 674 of 20603, timestamp: 1628966867
# FIELD - swaps
# round 675 of 20603, timestamp: 1662521301
# FIELD - swaps
# round 676 of 20603, timestamp: 1660555221
# FIELD - swaps
# round 677 of 20603, timestamp: 1649676248
# FIELD - swaps
# round 678 of 20603, timestamp: 1641156568
# FIELD - swaps
# round 679 of 20603, timestamp: 1669730267
# FIELD - swaps
# round 680 of 20603, timestamp: 1638928358
# FIELD - swaps
# round 681 of 20603, timestamp: 1639190504
# FIELD - swaps
# round 682 of 20603, timestamp: 1656754154
# FIELD - swaps
# round 683 of 20603, timestamp: 1640108022
# FIELD - swaps
# round 684 of 20603, timestamp: 1674579959
# FIELD - swaps
# round 685 of 20603, timestamp: 1669599227
# FIELD - swaps
# round 686 of 20603, timestamp: 1671303167
# FIELD - swaps
# round 687 of 20603, timestamp: 1631457286
# FIELD - swaps
# round 688 of 20603, timestamp: 1666846727
# FIELD - swaps
# round 689 of 20603, timestamp: 1661997071
# FIELD - swaps
# round 690 of 20603, timestamp: 1634996265
# FIELD - swaps
# round 691 of 20603, timestamp: 1655836718
# FIELD - swaps
# round 692 of 20603, timestamp: 1658327102
# FIELD - swaps
# round 693 of 20603, timestamp: 1653608546
# FIELD - swaps
# round 694 of 20603, timestamp: 1632899173
# FIELD - swaps
# round 695 of 20603, timestamp: 1657147503
# FIELD - swaps
# round 696 of 20603, timestamp: 1636962421
# FIELD - swaps
# round 697 of 20603, timestamp: 1661472886
# FIELD - swaps
# round 698 of 20603, timestamp: 1677463679
# FIELD - swaps
# round 699 of 20603, timestamp: 1662128255
# FIELD - swaps
# round 700 of 20603, timestamp: 1649676417
# FIELD - swaps
# round 701 of 20603, timestamp: 1672614035
# FIELD - swaps
# round 702 of 20603, timestamp: 1671041171
# FIELD - swaps
# round 703 of 20603, timestamp: 1641418899
# FIELD - swaps
# round 704 of 20603, timestamp: 1659113653
# FIELD - swaps
# round 705 of 20603, timestamp: 1675366583
# FIELD - swaps
# round 706 of 20603, timestamp: 1630408890
# FIELD - swaps
# round 707 of 20603, timestamp: 1655574718
# FIELD - swaps
# round 708 of 20603, timestamp: 1635782854
# FIELD - swaps
# round 709 of 20603, timestamp: 1676153039
# FIELD - swaps
# round 710 of 20603, timestamp: 1668681935
# FIELD - swaps
# round 711 of 20603, timestamp: 1652822243
# FIELD - swaps
# round 712 of 20603, timestamp: 1652035813
# FIELD - swaps
# round 713 of 20603, timestamp: 1662914794
# FIELD - swaps
# round 714 of 20603, timestamp: 1673531627
# FIELD - swaps
# round 715 of 20603, timestamp: 1662128364
# FIELD - swaps
# round 716 of 20603, timestamp: 1644433645
# FIELD - swaps
# round 717 of 20603, timestamp: 1675628783
# FIELD - swaps
# round 718 of 20603, timestamp: 1674055919
# FIELD - swaps
# round 719 of 20603, timestamp: 1673662703
# FIELD - swaps
# round 720 of 20603, timestamp: 1648496882
# FIELD - swaps
# round 721 of 20603, timestamp: 1675235579
# FIELD - swaps
# round 722 of 20603, timestamp: 1652560124
# FIELD - swaps
# round 723 of 20603, timestamp: 1630933254
# FIELD - swaps
# round 724 of 20603, timestamp: 1667109131
# FIELD - swaps
# round 725 of 20603, timestamp: 1671041303
# FIELD - swaps
# round 726 of 20603, timestamp: 1667895587
# FIELD - swaps
# round 727 of 20603, timestamp: 1664356643
# FIELD - swaps
# round 728 of 20603, timestamp: 1638666531
# FIELD - swaps
# round 729 of 20603, timestamp: 1654526264
# FIELD - swaps
# round 730 of 20603, timestamp: 1644433723
# FIELD - swaps
# round 731 of 20603, timestamp: 1655574844
# FIELD - swaps
# round 732 of 20603, timestamp: 1674056003
# FIELD - swaps
# round 733 of 20603, timestamp: 1659113798
# FIELD - swaps
# round 734 of 20603, timestamp: 1669861703
# FIELD - swaps
# round 735 of 20603, timestamp: 1641419080
# FIELD - swaps
# round 736 of 20603, timestamp: 1652429131
# FIELD - swaps
# round 737 of 20603, timestamp: 1668288851
# FIELD - swaps
# round 738 of 20603, timestamp: 1666715987
# FIELD - swaps
# round 739 of 20603, timestamp: 1639321946
# FIELD - swaps
# round 740 of 20603, timestamp: 1634734426
# FIELD - swaps
# round 741 of 20603, timestamp: 1670123879
# FIELD - swaps
# round 742 of 20603, timestamp: 1642336620
# FIELD - swaps
# round 743 of 20603, timestamp: 1639059821
# FIELD - swaps
# round 744 of 20603, timestamp: 1659244911
# FIELD - swaps
# round 745 of 20603, timestamp: 1677070715
# FIELD - swaps
# round 746 of 20603, timestamp: 1673662847
# FIELD - swaps
# round 747 of 20603, timestamp: 1663570307
# FIELD - swaps
# round 748 of 20603, timestamp: 1675628939
# FIELD - swaps
# round 749 of 20603, timestamp: 1667633555
# FIELD - swaps
# round 750 of 20603, timestamp: 1667764631
# FIELD - swaps
# round 751 of 20603, timestamp: 1677070751
# FIELD - swaps
# round 752 of 20603, timestamp: 1676808611
# FIELD - swaps
# round 753 of 20603, timestamp: 1672876463
# FIELD - swaps
# round 754 of 20603, timestamp: 1658065332
# FIELD - swaps
# round 755 of 20603, timestamp: 1643254205
# FIELD - swaps
# round 756 of 20603, timestamp: 1651904959
# FIELD - swaps
# round 757 of 20603, timestamp: 1644040643
# FIELD - swaps
# round 758 of 20603, timestamp: 1644171724
# FIELD - swaps
# round 759 of 20603, timestamp: 1661473234
# FIELD - swaps
# round 760 of 20603, timestamp: 1638928862
# FIELD - swaps
# round 761 of 20603, timestamp: 1630015967
# FIELD - swaps
# round 762 of 20603, timestamp: 1673662955
# FIELD - swaps
# round 763 of 20603, timestamp: 1668026867
# FIELD - swaps
# round 764 of 20603, timestamp: 1634865671
# FIELD - swaps
# round 765 of 20603, timestamp: 1647055380
# FIELD - swaps
# round 766 of 20603, timestamp: 1651249688
# FIELD - swaps
# round 767 of 20603, timestamp: 1669337627
# FIELD - swaps
# round 768 of 20603, timestamp: 1635652126
# FIELD - swaps
# round 769 of 20603, timestamp: 1673400863
# FIELD - swaps
# round 770 of 20603, timestamp: 1672221215
# FIELD - swaps
# round 771 of 20603, timestamp: 1648497185
# FIELD - swaps
# round 772 of 20603, timestamp: 1638273570
# FIELD - swaps
# round 773 of 20603, timestamp: 1669599779
# FIELD - swaps
# round 774 of 20603, timestamp: 1667240483
# FIELD - swaps
# round 775 of 20603, timestamp: 1669075499
# FIELD - swaps
# round 776 of 20603, timestamp: 1675629107
# FIELD - swaps
# round 777 of 20603, timestamp: 1662784062
# FIELD - swaps
# round 778 of 20603, timestamp: 1657803327
# FIELD - swaps
# round 779 of 20603, timestamp: 1630671424
# FIELD - swaps
# round 780 of 20603, timestamp: 1662652999
# FIELD - swaps
# round 781 of 20603, timestamp: 1639715402
# FIELD - swaps
# round 782 of 20603, timestamp: 1661211215
# FIELD - swaps
# round 783 of 20603, timestamp: 1658196561
# FIELD - swaps
# round 784 of 20603, timestamp: 1649283679
# FIELD - swaps
# round 785 of 20603, timestamp: 1659900512
# FIELD - swaps
# round 786 of 20603, timestamp: 1669468775
# FIELD - swaps
# round 787 of 20603, timestamp: 1653740140
# FIELD - swaps
# round 788 of 20603, timestamp: 1669337711
# FIELD - swaps
# round 789 of 20603, timestamp: 1634603632
# FIELD - swaps
# round 790 of 20603, timestamp: 1628836463
# FIELD - swaps
# round 791 of 20603, timestamp: 1644696186
# FIELD - swaps
# round 792 of 20603, timestamp: 1650463368
# FIELD - swaps
# round 793 of 20603, timestamp: 1653346955
# FIELD - swaps
# round 794 of 20603, timestamp: 1629229712
# FIELD - swaps
# round 795 of 20603, timestamp: 1664225939
# FIELD - swaps
# round 796 of 20603, timestamp: 1645220500
# FIELD - swaps
# round 797 of 20603, timestamp: 1636962963
# FIELD - swaps
# round 798 of 20603, timestamp: 1637094039
# FIELD - swaps
# round 799 of 20603, timestamp: 1654788761
# FIELD - swaps
# round 800 of 20603, timestamp: 1642074792
# FIELD - swaps
# round 801 of 20603, timestamp: 1639060145
# FIELD - swaps
# round 802 of 20603, timestamp: 1633817265
# FIELD - swaps
# round 803 of 20603, timestamp: 1673007803
# FIELD - swaps
# round 804 of 20603, timestamp: 1662653118
# FIELD - swaps
# round 805 of 20603, timestamp: 1673138879
# FIELD - swaps
# round 806 of 20603, timestamp: 1639322326
# FIELD - swaps
# round 807 of 20603, timestamp: 1655837403
# FIELD - swaps
# round 808 of 20603, timestamp: 1663308515
# FIELD - swaps
# round 809 of 20603, timestamp: 1651512039
# FIELD - swaps
# round 810 of 20603, timestamp: 1659114216
# FIELD - swaps
# round 811 of 20603, timestamp: 1629885161
# FIELD - swaps
# round 812 of 20603, timestamp: 1656886004
# FIELD - swaps
# round 813 of 20603, timestamp: 1651249908
# FIELD - swaps
# round 814 of 20603, timestamp: 1634603772
# FIELD - swaps
# round 815 of 20603, timestamp: 1665405695
# FIELD - swaps
# round 816 of 20603, timestamp: 1659376384
# FIELD - swaps
# round 817 of 20603, timestamp: 1650987777
# FIELD - swaps
# round 818 of 20603, timestamp: 1637487360
# FIELD - swaps
# round 819 of 20603, timestamp: 1650070284
# FIELD - swaps
# round 820 of 20603, timestamp: 1673663267
# FIELD - swaps
# round 821 of 20603, timestamp: 1634472753
# FIELD - swaps
# round 822 of 20603, timestamp: 1658327862
# FIELD - swaps
# round 823 of 20603, timestamp: 1667896127
# FIELD - swaps
# round 824 of 20603, timestamp: 1659769664
# FIELD - swaps
# round 825 of 20603, timestamp: 1651512137
# FIELD - swaps
# round 826 of 20603, timestamp: 1642337108
# FIELD - swaps
# round 827 of 20603, timestamp: 1668027227
# FIELD - swaps
# round 828 of 20603, timestamp: 1662653275
# FIELD - swaps
# round 829 of 20603, timestamp: 1648235359
# FIELD - swaps
# round 830 of 20603, timestamp: 1672876943
# FIELD - swaps
# round 831 of 20603, timestamp: 1673139095
# FIELD - swaps
# round 832 of 20603, timestamp: 1668944807
# FIELD - swaps
# round 833 of 20603, timestamp: 1642075052
# FIELD - swaps
# round 834 of 20603, timestamp: 1663308719
# FIELD - swaps
# round 835 of 20603, timestamp: 1659507636
# FIELD - swaps
# round 836 of 20603, timestamp: 1631065015
# FIELD - swaps
# round 837 of 20603, timestamp: 1644172218
# FIELD - swaps
# round 838 of 20603, timestamp: 1643516861
# FIELD - swaps
# round 839 of 20603, timestamp: 1629885373
# FIELD - swaps
# round 840 of 20603, timestamp: 1676022719
# FIELD - swaps
# round 841 of 20603, timestamp: 1641944001
# FIELD - swaps
# round 842 of 20603, timestamp: 1649677264
# FIELD - swaps
# round 843 of 20603, timestamp: 1673663447
# FIELD - swaps
# round 844 of 20603, timestamp: 1639322588
# FIELD - swaps
# round 845 of 20603, timestamp: 1639191521
# FIELD - swaps
# round 846 of 20603, timestamp: 1653609445
# FIELD - swaps
# round 847 of 20603, timestamp: 1639322621
# FIELD - swaps
# round 848 of 20603, timestamp: 1653347355
# FIELD - swaps
# round 849 of 20603, timestamp: 1658590244
# FIELD - swaps
# round 850 of 20603, timestamp: 1651250216
# FIELD - swaps
# round 851 of 20603, timestamp: 1639846956
# FIELD - swaps
# round 852 of 20603, timestamp: 1638536239
# FIELD - swaps
# round 853 of 20603, timestamp: 1630409775
# FIELD - swaps
# round 854 of 20603, timestamp: 1634997299
# FIELD - swaps
# round 855 of 20603, timestamp: 1653085265
# FIELD - swaps
# round 856 of 20603, timestamp: 1633162328
# FIELD - swaps
# round 857 of 20603, timestamp: 1677464675
# FIELD - swaps
# round 858 of 20603, timestamp: 1633948772
# FIELD - swaps
# ...
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /usr/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/packages/six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /usr/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1373 try:
# -> 1374     response.begin()
#    1375 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:79, in paginate(schema, doc, pagination_strategy)
#      78 try:
# ---> 79   page_data = client.query(
#      80     url=doc.url,
#      81     query_str=doc.graphql,
#      82     variables=doc.variables | args
#      83   )
#      84   data = merge(data, page_data)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/client.py:154, in query(url, query_str, variables)
#     151 logger.info(
#     152   f'client.query: url = {url}, variables = {variables}\n{query_str}'
#     153 )
# --> 154 resp = requests.post(
#     155   url,
#     156   json=(
#     157     {'query': query_str}
#     158     if variables == {}
#     159     else {'query': query_str, 'variables': variables}
#     160   ),
#     161   headers={'Content-Type': 'application/json'}
#     162 ).json()
#     164 try:
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     104 r"""Sends a POST request.
#     105
#     106 :param url: URL for the new :class:`Request` object.
#    (...)
#     112 :rtype: requests.Response
#     113 """
# --> 115 return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:547, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     546 except (ProtocolError, OSError) as err:
# --> 547     raise ConnectionError(err, request=request)
#     549 except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# PaginationError                           Traceback (most recent call last)
# /home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb Cell 45 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=4'>5</a> swaps_qp = swaps_fp(
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=5'>6</a>     first=10,
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=6'>7</a>     orderBy='timestamp',
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=7'>8</a>     orderDirection='desc',
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=8'>9</a>     where = {'timestamp_lt': cow_timestamps[i], 'amountInUSD_gt': filter_usd, 'amountOutUSD_gt': filter_usd, 'pool': lp}
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=9'>10</a>     )
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=11'>12</a> # run query
# ---> <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=12'>13</a> df = univ3_ds.runQuery(swaps_qp)
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=14'>15</a> if df.empty:
#      <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#X63sZmlsZQ%3D%3D?line=15'>16</a>     print('empty')
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:209, in Streamer.runQuery(self, query_field)
#     200 """
#     201 runQuery() executes the Subgrounds query_df() function to query the Subgraph and return a DataFrame.
#     202
#    (...)
#     205 :return: DataFrame object
#     206 """
#     207 print(f'FIELD - {query_field}')
# --> 209 df = self.sub.query_df(query_field)
#     210 # add endpoint column to df
#     211 # get the values to the right of the last / in the self.endpoint
#     212 endpoint = self.endpoint.split('/')[-1]
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:380, in Subgrounds.query_df(self, fpaths, columns, concat, pagination_strategy)
#     309 """Same as :func:`Subgrounds.query` but formats the response data into a
#     310 Pandas DataFrame. If the response data cannot be flattened to a single query
#     311 (e.g.: when querying multiple list fields that return different entities),
#    (...)
#     372     9       1643213196  2610.686563
#     373 """
#     374 fpaths = list(
#     375   [fpaths]
#     376   | traverse
#     377   | map(FieldPath._auto_select)
#     378   | traverse
#     379 )
# --> 380 json_data = self.query_json(fpaths, pagination_strategy=pagination_strategy)
#     381 return df_of_json(json_data, fpaths, columns, concat)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:274, in Subgrounds.query_json(self, fpaths, pagination_strategy)
#     267 fpaths = list(
#     268   [fpaths]
#     269   | traverse
#     270   | map(FieldPath._auto_select)
#     271   | traverse
#     272 )
#     273 req = self.mk_request(fpaths)
# --> 274 return self.execute(req, pagination_strategy=pagination_strategy)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:199, in Subgrounds.execute(self, req, pagination_strategy)
#     189   match transforms:
#     190     case []:
#     191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#    (...)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False  # Suppress mypy missing return statement warning
# --> 199 return transform_req(self.global_transforms, req)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req(transforms, req)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req.<locals>.<lambda>(doc)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:180, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
# --> 180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
#     183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:172, in Subgrounds.execute.<locals>.execute_document(doc)
#     167 subgraph: Subgraph = next(
#     168   self.subgraphs.values()
#     169   | where(lambda sg: sg._url == doc.url)
#     170 )
#     171 if pagination_strategy is not None and subgraph._is_subgraph:
# --> 172   return paginate(subgraph._schema, doc, pagination_strategy=pagination_strategy)
#     173 else:
#     174   return client.query(doc.url, doc.graphql, variables=doc.variables)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:89, in paginate(schema, doc, pagination_strategy)
#      87       break
#      88     except Exception as exn:
# ---> 89       raise PaginationError(exn.args[0], strategy)
#      91   return data
#      93 except SkipPagination:
#
# PaginationError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
# concat swaps_df_list into a single dataframe.
swaps_df = pd.concat(swaps_df_list)

# %%
swaps_df.shape

# %%
# print min and max swaps_timestamp
print(swaps_df['swaps_timestamp'].min())
print(swaps_df['swaps_timestamp'].max())

# %%
# replace the pool addresses with LP pool names with fees
swaps_df['swaps_pool_id'] = swaps_df['swaps_pool_id'].replace(weth_usdc_list[0], 'USDC_WETH .05%')
swaps_df['swaps_pool_id'] = swaps_df['swaps_pool_id'].replace(weth_usdc_list[1], 'USDC_WETH .3%')

# replace token addresses with symbols
swaps_df['swaps_tokenIn_id'] = swaps_df['swaps_tokenIn_id'].replace(usdc_addr, 'USDC')
swaps_df['swaps_tokenIn_id'] = swaps_df['swaps_tokenIn_id'].replace(weth_addr, 'WETH')
swaps_df['swaps_tokenOut_id'] = swaps_df['swaps_tokenOut_id'].replace(usdc_addr, 'USDC')
swaps_df['swaps_tokenOut_id'] = swaps_df['swaps_tokenOut_id'].replace(weth_addr, 'WETH')

# %%
print(f'query returned {len(swaps_df)} rows\n swaps_df columns are {swaps_df.columns}')

# %%
# save polars to parquet
swaps_df.write_parquet('data/swaps_df.parquet')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb Cell 52 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> # save polars to parquet
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> swaps_df.write_parquet('data/swaps_df.parquet')
#
# NameError: name 'swaps_df' is not defined

# %% [markdown]
# ### Get the Uniswap Gas Data

# %%
univ3_no_messari_ds = Streamer('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3')

# %%
transactions_fp = univ3_no_messari_ds.queryDict.get('transactions')

# %%
transactions_df_list = []

# %%
for lp in weth_usdc_list: # outer loop loops through liquidity pools
    for i in range(0, len(cow_timestamps)): # inner loop through cowswap timestamps
        print(f'round {i} of {len(cow_timestamps)}, timestamp: {cow_timestamps[i]}')
        # define the query path
        txs_qp = transactions_fp(
            first=10,
            orderBy='timestamp',
            orderDirection='desc',
            where = {"swaps_": {'timestamp': cow_timestamps[i], 'pool': lp}}
            )
        
        # run query
        df = univ3_no_messari_ds.runQuery(txs_qp)

        if df.empty:
            print('empty')
            continue
        else:
            transactions_df_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb Cell 57 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> for lp in weth_usdc_list: # outer loop loops through liquidity pools
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a>     for i in range(0, len(cow_timestamps)): # inner loop through cowswap timestamps
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y106sZmlsZQ%3D%3D?line=2'>3</a>         print(f'round {i} of {len(cow_timestamps)}, timestamp: {cow_timestamps[i]}')
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/Feedlot/pipeline/data_pipeline.ipynb#Y106sZmlsZQ%3D%3D?line=3'>4</a>         # define the query path
#
# NameError: name 'cow_timestamps' is not defined

# %%
# concat transactions_df_list
transactions_df = pd.concat(transactions_df_list)

# %%
# save polars to parquet
transactions_df.write_parquet('data/transactions_df.parquet')

# %%
transactions_df.shape

# %% [markdown]
# ### Everything is checkpointed, if it fails again I can just reload the parquet files and run from here

# %%
# get dataframe row types swaps_df
swaps_df.dtypes

# %%
# enforce swaps_df column types. This is necessary because the data types are not enforced by pandas dataframes. We need to enforce the types as a preprocessing step to converting to Polars
swaps_df['swaps_gasLimit'] = swaps_df['swaps_gasLimit'].astype('float64')
swaps_df['swaps_gasUsed'] = swaps_df['swaps_gasUsed'].astype('float64')
swaps_df['swaps_gasPrice'] = swaps_df['swaps_gasPrice'].astype('float64')
swaps_df['swaps_amountIn'] = swaps_df['swaps_amountIn'].astype('float64')
swaps_df['swaps_amountInUSD'] = swaps_df['swaps_amountInUSD'].astype('float64')
swaps_df['swaps_amountOut'] = swaps_df['swaps_amountOut'].astype('float64')
swaps_df['swaps_amountOutUSD'] = swaps_df['swaps_amountOutUSD'].astype('float64')
swaps_df['swaps_blockNumber'] = swaps_df['swaps_blockNumber'].astype('int64')
swaps_df['swaps_timestamp'] = swaps_df['swaps_timestamp'].astype('int64')

# %%
# convert swaps, transactions, and cowswap dataframes to polars
swaps_pl = pl.from_pandas(swaps_df)
transactions_pl = pl.from_pandas(transactions_df)
# recall cow_trades_pl was already created earlier

# %% [markdown]
# ### Merge Swaps and Transactions for Gas

# %%
# merge swaps_pl and transactions_pl polars
uni_complete_pl = swaps_pl.join(transactions_pl, left_on="swaps_hash", right_on="transactions_id", how="inner")

# %%
# drop duplicate rows
uni_complete_pl = uni_complete_pl.unique()

# %%
# drop endpoint column from uni_complete_pl
uni_complete_pl = uni_complete_pl.drop('endpoint')

# %%
# get median transactions_gasUsed amount. Typical V3 swap is 127k gas for One-hop. However with multiple hops, gas will be higher. 352 reflects an avg of 3 hops worth of gas
tx_gas_median = uni_complete_pl['transactions_gasUsed'].median()
print(f'transaction gas median is {tx_gas_median}')

# %%
# to get transaction gas used, we do gasUsed * gasPrice
uni_complete_pl = uni_complete_pl.with_columns([
    (127000 * pl.col("transactions_gasPrice")).alias('transaction_gas_fee_one_hop'),
    (tx_gas_median * pl.col("transactions_gasPrice")).alias('transaction_gas_fee_median')
    ])

# %%
uni_complete_pl = uni_complete_pl.with_columns([
    (pl.col("transaction_gas_fee_one_hop") / 10**18).alias('transaction_gas_fee_one_hop'), # wei is 10^9, but eth is 10^18
        (pl.col("transaction_gas_fee_median") / 10**18).alias('transaction_gas_fee_median') # wei is 10^9, but eth is 10^18
])

# %%
# sort by largest transaction_gas_fee
uni_complete_pl.sort("transaction_gas_fee_one_hop", reverse=False).head(5)

# %% [markdown]
# ### Merge Cow and Univ3

# %%
# merge trades and swaps on timestamp value. We use outer join because we want to keep all trades and swaps data and backfill swap values
cow_uni_outer_pl = cow_complete_pl.join(other=uni_complete_pl, left_on='trades_timestamp', right_on='swaps_timestamp', how='outer')

# %%
cow_uni_outer_pl.columns

# %%
# This truncated dataframe isn't being used right now
cow_uni_trunc_pl = cow_uni_outer_pl[[
    'trades_timestamp', 
    'trades_txHash',
    'trades_feeAmount',
    'trades_sellToken_id', 
    'trades_buyToken_id', 
    'trades_buyAmount',
    'trades_sellAmount',
    # 'trades_sellAmountUsd', 
    # 'trades_buyAmountUsd', 
    'name',
    'environment',
    'swaps_pool_id', 
    'swaps_tokenIn_id', 
    'swaps_tokenOut_id',
    'swaps_amountIn',
    'swaps_amountOut',  
    # 'swaps_amountInUSD',
    # 'swaps_amountOutUSD',
    'swaps_blockNumber',
    # 'transactions_timestamp',
    # 'transactions_gasUsed',
    # 'transactions_gasPrice',
    'transaction_gas_fee_one_hop',
    'transaction_gas_fee_median'
    ]]

# %%
#check pl dataframe size
cow_uni_trunc_pl.shape

# %%
# sort by largest transaction_gas_fee
cow_uni_trunc_pl.sort("transaction_gas_fee_one_hop", reverse=True).head(5)

# %% [markdown]
# ### Chainlink

# %%
# load streamer class
chain_ds = Streamer('https://api.thegraph.com/subgraphs/name/openpredict/chainlink-prices-subgraph')

# %%
chain_price_feed = "ETH/USD"

# %%
chain_dfs_list = []

# %%
# get a query field path from the query dictionary which is automatically populated in the Streamer object
chain_fp = chain_ds.queryDict.get('prices')

# add parameters to the settlements_qp.
chain_qp = chain_fp(
    first=query_size * 5,
    orderBy='timestamp',
    orderDirection='desc',
    where = {'timestamp_lt': timestamp, 'assetPair': chain_price_feed}
    )

# run query
chain_df = chain_ds.runQuery(chain_qp)

# %%
# drop prices_id, endpoint. 
chain_df = chain_df.drop(['prices_id', 'endpoint'], axis=1)
# divide prices_price by 1e8 to get the price in USD
chain_df['prices_price'] = chain_df['prices_price'] / 10 ** 8

# %%
chain_df.shape

# %%
chain_pl = pl.from_pandas(chain_df)

# %%
# outer merge chain_df with cow_uni_outer_pl on timestamp
cow_uni_chain_outer_pl = cow_uni_trunc_pl.join(other=chain_pl, left_on='trades_timestamp', right_on='prices_timestamp', how='outer')

# %%
cow_uni_chain_outer_pl.shape

# %% [markdown]
# ### Price Calculations

# %% [markdown]
# #### Decimal Calculations

# %%
# add decimals to cow trades sell tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('trades_sellToken_id'),
        (
            pl.when(pl.col('trades_sellToken_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('trades_sellToken_decimals'),
    ]
)

# add decimals to cow trades buy tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('trades_buyToken_id'),
        (
            pl.when(pl.col('trades_buyToken_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('trades_buyToken_decimals'),
    ]
)

# add decimals to cow trades sell tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('swaps_tokenIn_id'),
        (
            pl.when(pl.col('swaps_tokenIn_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('swaps_tokenIn_decimals'),
    ]
)

# add decimals to cow trades buy tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('swaps_tokenOut_id'),
        (
            pl.when(pl.col('swaps_tokenOut_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('swaps_tokenOut_decimals'),
    ]
)

# %%
cow_uni_chain_outer_pl.columns # NOTE - the DF has transaction cols

# %% [markdown]
# #### Execution Price Calculations

# %%
# NOTE - Polars can perform these calculations in-column. This means it can convert the values in place without creating a new column. The new column created here is more verbose, but is a good sanity check to see before/after results.
trades_swaps_converted_pl = cow_uni_chain_outer_pl.with_columns([
    (pl.col("trades_buyAmount") / (10**pl.col("trades_buyToken_decimals"))).alias('trades_buyAmount_converted'),
    (pl.col("trades_sellAmount") / (10**pl.col("trades_sellToken_decimals"))).alias('trades_sellAmount_converted'),
    (pl.col("swaps_amountIn") / (10**pl.col("swaps_tokenIn_decimals"))).alias('swaps_amountIn_converted'),
    (pl.col("swaps_amountOut") / (10**pl.col("swaps_tokenOut_decimals"))).alias('swaps_amountOut_converted'),
])

# %%
trades_swaps_converted_trunc_pl = trades_swaps_converted_pl.with_columns([
    (pl.col("trades_buyAmount_converted") / pl.col("trades_sellAmount_converted")).alias('trades_buy_sell_ratio'),
    (pl.col("trades_sellAmount_converted") / pl.col("trades_buyAmount_converted")).alias('trades_sell_buy_ratio'),
    (pl.col("swaps_amountIn_converted") / pl.col("swaps_amountOut_converted")).alias('swaps_amountIn_amountOut_ratio'),
    (pl.col("swaps_amountOut_converted") / pl.col("swaps_amountIn_converted")).alias('swaps_amountOut_amountIn_ratio'),
])

# %%
trades_swaps_converted_trunc_pl = trades_swaps_converted_trunc_pl[
    'trades_timestamp',
    'swaps_blockNumber',
    'trades_txHash',
    'trades_feeAmount',
    'trades_sellToken_id',
    'trades_buyToken_id',
    'trades_sellAmount_converted',
    'trades_buyAmount_converted',
    'name',
    'environment',
    'swaps_pool_id',
    'swaps_tokenIn_id',
    'swaps_tokenOut_id',
    'swaps_amountIn_converted',
    'swaps_amountOut_converted',
    'transaction_gas_fee_one_hop',
    'transaction_gas_fee_median',
    'trades_buy_sell_ratio',
    'trades_sell_buy_ratio',
    'swaps_amountIn_amountOut_ratio',
    'swaps_amountOut_amountIn_ratio',
    'prices_assetPair_id',
    'prices_price'
]

# %%
trades_swaps_converted_trunc_pl.shape

# %%
trades_swaps_converted_trunc_pl.head(10)

# %% [markdown]
# ### Save Data to a local parquet file

# %%
# checkpoint, save to parquet
trades_swaps_converted_trunc_pl.write_parquet('data/cow_uni_chain_outer_pl.parquet')
