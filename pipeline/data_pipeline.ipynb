# %% [markdown]
# # Cow + Univ3 DataPipeline

# %% [markdown]
# ### Setup Jupyter Environment

# %%
from datastreams.datastream import Streamer

# import concurrent.futures
import os
import pandas as pd
import polars as pl

# These commands enlarge the column size of the dataframe so things like 0x... are not truncated
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %% [markdown]
# ### Cowswap Trades

# %%
# instantiate Streamer class. Note that we need two separate streamer classes, otherwise the queries will be overwritten. 
cow_ds1 = Streamer('https://api.thegraph.com/subgraphs/name/cowprotocol/cow')
cow_ds2 = Streamer('https://api.thegraph.com/subgraphs/name/cowprotocol/cow')

# %%
# DEFINE TIMESTAMP HERE. Timstamp is used for replication quality assurance purposes.
timestamp = 1677891498 # current block timestamp is around 1677891498 on March 3rd, 2023 8:06PM

# define ethereum token addresses here to be used in cowswap trades query filter
weth_addr = "0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2"
usdc_addr = "0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48"

# we set a fixed query size number. The Cow settlements and Uniswap swaps query are multiples larger than this initial query size.
query_size = 10000000

#Filter size - We filter trades out that are smaller than $1000 USD size
filter_usd = 1000

# %%
token_addr_list = [weth_addr, usdc_addr]

# %%
# We need to make two queries to the cow schema to get all the trades that match weth/usdc and usdc/weth.
trades_weth_usdc_fp = cow_ds1.queryDict.get('trades')
trades_usdc_weth_fp = cow_ds2.queryDict.get('trades')

# trades query path that gets token a -> token b trades
trades_weth_usdc_qp = trades_weth_usdc_fp(
    first=query_size,
    orderBy='timestamp',
    orderDirection='desc',
    where = {
    'timestamp_lt': timestamp, 
    'buyAmountUsd_gt': filter_usd, 
    'sellAmountUsd_gt': filter_usd, 
    "sellToken_in": token_addr_list, 
    "buyToken_in": token_addr_list
    }
)

# trades query path that gets token b -> token a trades
trades_usdc_weth_qp = trades_usdc_weth_fp(
    first=query_size,
    orderBy='timestamp',
    orderDirection='desc',
    where = {
    'timestamp_lt': timestamp, 
    'buyAmountUsd_gt': filter_usd, 
    'sellAmountUsd_gt': filter_usd, 
    "sellToken_in": token_addr_list, 
    "buyToken_in": token_addr_list
    }
)

# run query
trades_weth_usdc_df = cow_ds1.runQuery(trades_weth_usdc_qp)
trades_usdc_weth_df = cow_ds2.runQuery(trades_usdc_weth_qp)
# Out:
# FIELD - trades
# FIELD - trades

# %%
# combine the trades queries together
trades_df = pd.concat([trades_weth_usdc_df, trades_usdc_weth_df])

# %%
print(f'query returned {len(trades_df)} rows')
# Out:
# query returned 246 rows

# %%
# verify the query results to ensure that only two tokens were queried.
trades_df['trades_buyToken_id'].unique()
# Out:
# array(['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#        '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'], dtype=object)

# %%
# replace addresses with symbols
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].replace(weth_addr, 'WETH')
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].replace(usdc_addr, 'USDC')

trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].replace(weth_addr, 'WETH')
trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].replace(usdc_addr, 'USDC')

# %%
trades_df.columns
# Out:
# Index(['trades_id', 'trades_timestamp', 'trades_gasPrice', 'trades_feeAmount',
#        'trades_txHash', 'trades_settlement_id', 'trades_buyAmount',
#        'trades_sellAmount', 'trades_sellToken_id', 'trades_buyToken_id',
#        'trades_order_id', 'trades_buyAmountEth', 'trades_sellAmountEth',
#        'trades_buyAmountUsd', 'trades_sellAmountUsd', 'endpoint'],
#       dtype='object')

# %% [markdown]
# ### Cowswap Trades-Settlement Merge

# %%
# do same query methood but instead of timestamps, use trades_settlement_id

# get unique trades_settlement_id list
trades_settlement_id_list = trades_df['trades_settlement_id'].unique()

# define field path
settlements_fp = cow_ds1.queryDict.get('settlements')

# %%
settlement_df_list = []

# %%
for i in range(0, len(trades_settlement_id_list)): # inner loop through cowswap timestamps
    print(f'round {i} of {len(trades_settlement_id_list)}')
    # define the query path
    settlements_qp = settlements_fp(
        first=query_size * 3,
        orderBy='firstTradeTimestamp',
        orderDirection='desc',
        where = {'txHash': trades_settlement_id_list[i]} 
        )
    
    # run query
    df = cow_ds1.runQuery(settlements_qp)

    if df.empty:
        print('empty')
        continue
    else:
        settlement_df_list.append(df)
# Out:
# round 0 of 121
# FIELD - settlements
# round 1 of 121
# FIELD - settlements
# round 2 of 121
# FIELD - settlements
# round 3 of 121
# FIELD - settlements
# round 4 of 121
# FIELD - settlements
# round 5 of 121
# FIELD - settlements
# round 6 of 121
# FIELD - settlements
# round 7 of 121
# FIELD - settlements
# round 8 of 121
# FIELD - settlements
# round 9 of 121
# FIELD - settlements
# round 10 of 121
# FIELD - settlements
# round 11 of 121
# FIELD - settlements
# round 12 of 121
# FIELD - settlements
# round 13 of 121
# FIELD - settlements
# round 14 of 121
# FIELD - settlements
# round 15 of 121
# FIELD - settlements
# round 16 of 121
# FIELD - settlements
# round 17 of 121
# FIELD - settlements
# round 18 of 121
# FIELD - settlements
# round 19 of 121
# FIELD - settlements
# round 20 of 121
# FIELD - settlements
# round 21 of 121
# FIELD - settlements
# round 22 of 121
# FIELD - settlements
# round 23 of 121
# FIELD - settlements
# round 24 of 121
# FIELD - settlements
# round 25 of 121
# FIELD - settlements
# round 26 of 121
# FIELD - settlements
# round 27 of 121
# FIELD - settlements
# round 28 of 121
# FIELD - settlements
# round 29 of 121
# FIELD - settlements
# round 30 of 121
# FIELD - settlements
# round 31 of 121
# FIELD - settlements
# round 32 of 121
# FIELD - settlements
# round 33 of 121
# FIELD - settlements
# round 34 of 121
# FIELD - settlements
# round 35 of 121
# FIELD - settlements
# round 36 of 121
# FIELD - settlements
# round 37 of 121
# FIELD - settlements
# round 38 of 121
# FIELD - settlements
# round 39 of 121
# FIELD - settlements
# round 40 of 121
# FIELD - settlements
# round 41 of 121
# FIELD - settlements
# round 42 of 121
# FIELD - settlements
# round 43 of 121
# FIELD - settlements
# round 44 of 121
# FIELD - settlements
# round 45 of 121
# FIELD - settlements
# round 46 of 121
# FIELD - settlements
# round 47 of 121
# FIELD - settlements
# round 48 of 121
# FIELD - settlements
# round 49 of 121
# FIELD - settlements
# round 50 of 121
# FIELD - settlements
# round 51 of 121
# FIELD - settlements
# round 52 of 121
# FIELD - settlements
# round 53 of 121
# FIELD - settlements
# round 54 of 121
# FIELD - settlements
# round 55 of 121
# FIELD - settlements
# round 56 of 121
# FIELD - settlements
# round 57 of 121
# FIELD - settlements
# round 58 of 121
# FIELD - settlements
# round 59 of 121
# FIELD - settlements
# round 60 of 121
# FIELD - settlements
# round 61 of 121
# FIELD - settlements
# round 62 of 121
# FIELD - settlements
# round 63 of 121
# FIELD - settlements
# round 64 of 121
# FIELD - settlements
# round 65 of 121
# FIELD - settlements
# round 66 of 121
# FIELD - settlements
# round 67 of 121
# FIELD - settlements
# round 68 of 121
# FIELD - settlements
# round 69 of 121
# FIELD - settlements
# round 70 of 121
# FIELD - settlements
# round 71 of 121
# FIELD - settlements
# round 72 of 121
# FIELD - settlements
# round 73 of 121
# FIELD - settlements
# round 74 of 121
# FIELD - settlements
# round 75 of 121
# FIELD - settlements
# round 76 of 121
# FIELD - settlements
# round 77 of 121
# FIELD - settlements
# round 78 of 121
# FIELD - settlements
# round 79 of 121
# FIELD - settlements
# round 80 of 121
# FIELD - settlements
# round 81 of 121
# FIELD - settlements
# round 82 of 121
# FIELD - settlements
# round 83 of 121
# FIELD - settlements
# round 84 of 121
# FIELD - settlements
# round 85 of 121
# FIELD - settlements
# round 86 of 121
# FIELD - settlements
# round 87 of 121
# FIELD - settlements
# round 88 of 121
# FIELD - settlements
# round 89 of 121
# FIELD - settlements
# round 90 of 121
# FIELD - settlements
# round 91 of 121
# FIELD - settlements
# round 92 of 121
# FIELD - settlements
# round 93 of 121
# FIELD - settlements
# round 94 of 121
# FIELD - settlements
# round 95 of 121
# FIELD - settlements
# round 96 of 121
# FIELD - settlements
# round 97 of 121
# FIELD - settlements
# round 98 of 121
# FIELD - settlements
# round 99 of 121
# FIELD - settlements
# round 100 of 121
# FIELD - settlements
# round 101 of 121
# FIELD - settlements
# round 102 of 121
# FIELD - settlements
# round 103 of 121
# FIELD - settlements
# round 104 of 121
# FIELD - settlements
# round 105 of 121
# FIELD - settlements
# round 106 of 121
# FIELD - settlements
# round 107 of 121
# FIELD - settlements
# round 108 of 121
# FIELD - settlements
# round 109 of 121
# FIELD - settlements
# round 110 of 121
# FIELD - settlements
# round 111 of 121
# FIELD - settlements
# round 112 of 121
# FIELD - settlements
# round 113 of 121
# FIELD - settlements
# round 114 of 121
# FIELD - settlements
# round 115 of 121
# FIELD - settlements
# round 116 of 121
# FIELD - settlements
# round 117 of 121
# FIELD - settlements
# round 118 of 121
# FIELD - settlements
# round 119 of 121
# FIELD - settlements
# round 120 of 121
# FIELD - settlements

# %%
# concatenate
settlements_df = pd.concat(settlement_df_list)

# %%
# enforce trades_df column types. This is necessary because the data types are not enforced by pandas dataframes. We need to enforce the types as a preprocessing step to converting to Polars
trades_df['trades_buyAmount'] = trades_df['trades_buyAmount'].astype('float64')
trades_df['trades_sellAmount'] = trades_df['trades_sellAmount'].astype('float64')
trades_df['trades_buyAmountUsd'] = trades_df['trades_buyAmountUsd'].astype('float64')
trades_df['trades_sellAmountUsd'] = trades_df['trades_sellAmountUsd'].astype('float64')
trades_df['trades_timestamp'] = trades_df['trades_timestamp'].astype('int64')
trades_df['trades_buyToken_id'] = trades_df['trades_buyToken_id'].astype('str')
trades_df['trades_sellToken_id'] = trades_df['trades_sellToken_id'].astype('str')

# %%
# convert dictionaries into polars dataframes
settlement_pl = pl.from_pandas(settlements_df)
trades_pl = pl.from_pandas(trades_df)

# %%
# merge trades and settlement dataframes on the settlement transaction hash
cow_trades_pl = trades_pl.join(other=settlement_pl, left_on='trades_settlement_id', right_on='settlements_txHash', how='inner')

# %%
cow_trades_pl.shape
# Out:
# (246, 20)

# %%
cow_trades_pl.head(5)
# Out:
# shape: (5, 20)
# ┌─────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ trades_ ┆ trades_tim ┆ trades_gas ┆ trades_fee ┆ ... ┆ settlement ┆ settlement ┆ settlement ┆ endpoint_r │
# │ id      ┆ estamp     ┆ Price      ┆ Amount     ┆     ┆ s_id       ┆ s_firstTra ┆ s_solver_i ┆ ight       │
# │ ---     ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ deTimestam ┆ d          ┆ ---        │
# │ str     ┆ i64        ┆ i64        ┆ i64        ┆     ┆ str        ┆ p          ┆ ---        ┆ str        │
# │         ┆            ┆            ┆            ┆     ┆            ┆ ---        ┆ str        ┆            │
# │         ┆            ┆            ┆            ┆     ┆            ┆ i64        ┆            ┆            │
# ╞═════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 0x2d177 ┆ 1677890687 ┆ 3403193858 ┆ 11504283   ┆ ... ┆ 0xdbeb3db4 ┆ 1677890687 ┆ 0x149d0f92 ┆ cow        │
# │ cbcc3e2 ┆            ┆ 1          ┆            ┆     ┆ bf019dac72 ┆            ┆ 82333681ee ┆            │
# │ 66aa322 ┆            ┆            ┆            ┆     ┆ 1970e0eed1 ┆            ┆ 41d3058982 ┆            │
# │ fff7f41 ┆            ┆            ┆            ┆     ┆ 75...      ┆            ┆ 4b...      ┆            │
# │ 2305... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x47ece ┆ 1677887663 ┆ 3009611088 ┆ 39337855   ┆ ... ┆ 0x8810dcd2 ┆ 1677887663 ┆ 0x149d0f92 ┆ cow        │
# │ 80491bf ┆            ┆ 4          ┆            ┆     ┆ 471391d3c6 ┆            ┆ 82333681ee ┆            │
# │ 75fd702 ┆            ┆            ┆            ┆     ┆ cc430a8080 ┆            ┆ 41d3058982 ┆            │
# │ 5549f9e ┆            ┆            ┆            ┆     ┆ a1...      ┆            ┆ 4b...      ┆            │
# │ 88c7... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x8c129 ┆ 1677885323 ┆ 1968935519 ┆ 27018672   ┆ ... ┆ 0xf8e2a0e1 ┆ 1677885323 ┆ 0xb20b86c4 ┆ cow        │
# │ 381cf3e ┆            ┆ 8          ┆            ┆     ┆ ae139b4b4a ┆            ┆ e6deeb432a ┆            │
# │ a5e26a1 ┆            ┆            ┆            ┆     ┆ f587b97058 ┆            ┆ 22d773a221 ┆            │
# │ ccdec20 ┆            ┆            ┆            ┆     ┆ 95...      ┆            ┆ 89...      ┆            │
# │ b070... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0xc07f4 ┆ 1677882191 ┆ 2122076543 ┆ 4843587156 ┆ ... ┆ 0x4eadf538 ┆ 1677882191 ┆ 0xc9ec550b ┆ cow        │
# │ 5a19d95 ┆            ┆ 2          ┆ 540876     ┆     ┆ 41770fb1ba ┆            ┆ ea1c64d779 ┆            │
# │ d27214a ┆            ┆            ┆            ┆     ┆ 903817d7e3 ┆            ┆ 124b23a262 ┆            │
# │ 7be024c ┆            ┆            ┆            ┆     ┆ 7d...      ┆            ┆ 92...      ┆            │
# │ f2e4... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x7159b ┆ 1677882011 ┆ 2151573490 ┆ 3250564090 ┆ ... ┆ 0xfb4569f8 ┆ 1677882011 ┆ 0x149d0f92 ┆ cow        │
# │ 0217959 ┆            ┆ 6          ┆ 489318     ┆     ┆ 5710f1ba09 ┆            ┆ 82333681ee ┆            │
# │ de58857 ┆            ┆            ┆            ┆     ┆ 3f1001277b ┆            ┆ 41d3058982 ┆            │
# │ 8921983 ┆            ┆            ┆            ┆     ┆ db...      ┆            ┆ 4b...      ┆            │
# │ bd06... ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# └─────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %%
# get unique values in cow_trades_pl trades_sellToken_id column
cow_trades_pl['trades_sellToken_id'].unique()
# Out:
# shape: (2,)
# Series: 'trades_sellToken_id' [str]
# [
# 	"USDC"
# 	"WETH"
# ]

# %% [markdown]
# ### Cowswap Trades-Solver Merge

# %%
solvers = pd.read_csv('data/cowv2_solvers.csv') # load in pandas instead of polars. Having trouble replacing \ symbol in polars

# %%
# rename address to settlements_solver_id in pandas
solvers = solvers.rename(columns={"address": "settlements_solver_id"})

# %%
# NOTE - dune formats addresses as /x... need to convert '/' to '0'
solvers['settlements_solver_id'] = solvers['settlements_solver_id'].str.replace('\\', '0', regex=False)

# %%
# turn solvers into a dictionary
solvers_dict = solvers.to_dict('records')

# convert dict to polars
solvers_pl = pl.from_dicts(solvers_dict)

# %%
# inner join solvers_pl on total_settlement_tokens_pl
cow_complete_pl = cow_trades_pl.join(solvers_pl, on="settlements_solver_id", how="inner")

# %%
# drop endpoint_right column from total_settlement_tokens_solvers
cow_complete_pl = cow_complete_pl.drop('endpoint_right')

# %%
cow_complete_pl.shape
# Out:
# (234, 22)

# %%
# save polars to parquet
cow_complete_pl.write_parquet('data/cow_complete_pl.parquet')

# %% [markdown]
# #### Basic Agg

# %%
# filter by "prod" environments
filter_df = cow_complete_pl.filter(pl.col("environment") == "prod")

# %%
# filter by "prod" environments
filter_df = cow_complete_pl.filter(pl.col("environment") == "prod")

# %%
filter_df.shape
# Out:
# (232, 22)

# %%
# group filter_df by solver name. Check solver count
grouped_df = filter_df.groupby("name").agg(
    pl.count("trades_id").alias("total_trades")).sort("total_trades", reverse=True)

# %%
grouped_df
# Out:
# shape: (7, 2)
# ┌─────────────────┬──────────────┐
# │ name            ┆ total_trades │
# │ ---             ┆ ---          │
# │ str             ┆ u32          │
# ╞═════════════════╪══════════════╡
# │ PLM             ┆ 118          │
# │ Otex            ┆ 50           │
# │ Quasilabs       ┆ 26           │
# │ Gnosis_1inch    ┆ 18           │
# │ Laertes         ┆ 16           │
# │ Gnosis_0x       ┆ 2            │
# │ Gnosis_ParaSwap ┆ 2            │
# └─────────────────┴──────────────┘

# %% [markdown]
# ### Uniswap V3 Swaps

# %%
# instantiate Streamer object. 
# Note - unlike the cow queries, univ3 does not require multiple streamer instantations because the swaps field path is reset each iteration. 
# If the Cow queries were updated to use the same method, we could use the same streamer object for all queries.
univ3_ds = Streamer('https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-ethereum')

# %%
# get a query field path from the query dictionary which is automatically populated in the Streamer object
swaps_fp = univ3_ds.queryDict.get('swaps')

# %%
weth_usdc_list = [
    "0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640", # usdc/weth .05%
    "0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8" #usdc/weth .3%
]

# %%
timestamps_list = cow_trades_pl['trades_timestamp'].to_list()
# get unique values in cow_timestamps
cow_timestamps = list(set(timestamps_list))

swaps_df_list = []

# %%
for lp in weth_usdc_list: # outer loop loops through liquidity pools
    for i in range(0, len(cow_timestamps)): # inner loop through cowswap timestamps
        print(f'round {i} of {len(cow_timestamps)}, timestamp: {cow_timestamps[i]}')
        # define the query path
        swaps_qp = swaps_fp(
            first=10,
            orderBy='timestamp',
            orderDirection='desc',
            where = {'timestamp_lt': cow_timestamps[i], 'amountInUSD_gt': filter_usd, 'amountOutUSD_gt': filter_usd, 'pool': lp} 
            )

        # run query
        df = univ3_ds.runQuery(swaps_qp)

        if df.empty:
            print('empty')
            continue
        else:
            swaps_df_list.append(df)
# Out:
# round 0 of 121, timestamp: 1677785603
# FIELD - swaps
# round 1 of 121, timestamp: 1677774851
# FIELD - swaps
# round 2 of 121, timestamp: 1677869063
# FIELD - swaps
# round 3 of 121, timestamp: 1677839879
# FIELD - swaps
# round 4 of 121, timestamp: 1677773831
# FIELD - swaps
# round 5 of 121, timestamp: 1677874187
# FIELD - swaps
# round 6 of 121, timestamp: 1677833231
# FIELD - swaps
# round 7 of 121, timestamp: 1677807131
# FIELD - swaps
# round 8 of 121, timestamp: 1677793307
# FIELD - swaps
# round 9 of 121, timestamp: 1677850151
# FIELD - swaps
# round 10 of 121, timestamp: 1677844007
# FIELD - swaps
# round 11 of 121, timestamp: 1677812279
# FIELD - swaps
# round 12 of 121, timestamp: 1677832763
# FIELD - swaps
# round 13 of 121, timestamp: 1677786683
# FIELD - swaps
# round 14 of 121, timestamp: 1677807683
# FIELD - swaps
# round 15 of 121, timestamp: 1677797447
# FIELD - swaps
# round 16 of 121, timestamp: 1677774407
# FIELD - swaps
# round 17 of 121, timestamp: 1677819467
# FIELD - swaps
# round 18 of 121, timestamp: 1677790283
# FIELD - swaps
# round 19 of 121, timestamp: 1677785675
# FIELD - swaps
# round 20 of 121, timestamp: 1677879887
# FIELD - swaps
# round 21 of 121, timestamp: 1677809231
# FIELD - swaps
# round 22 of 121, timestamp: 1677877847
# FIELD - swaps
# round 23 of 121, timestamp: 1677810263
# FIELD - swaps
# round 24 of 121, timestamp: 1677881435
# FIELD - swaps
# round 25 of 121, timestamp: 1677818459
# FIELD - swaps
# round 26 of 121, timestamp: 1677774431
# FIELD - swaps
# round 27 of 121, timestamp: 1677789803
# FIELD - swaps
# round 28 of 121, timestamp: 1677788267
# FIELD - swaps
# round 29 of 121, timestamp: 1677782123
# FIELD - swaps
# round 30 of 121, timestamp: 1677874799
# FIELD - swaps
# round 31 of 121, timestamp: 1677868655
# FIELD - swaps
# round 32 of 121, timestamp: 1677826679
# FIELD - swaps
# round 33 of 121, timestamp: 1677835895
# FIELD - swaps
# round 34 of 121, timestamp: 1677760631
# FIELD - swaps
# round 35 of 121, timestamp: 1677890687
# FIELD - swaps
# round 36 of 121, timestamp: 1677876863
# FIELD - swaps
# round 37 of 121, timestamp: 1677763199
# FIELD - swaps
# round 38 of 121, timestamp: 1677771395
# FIELD - swaps
# round 39 of 121, timestamp: 1677808271
# FIELD - swaps
# round 40 of 121, timestamp: 1677774479
# FIELD - swaps
# round 41 of 121, timestamp: 1677777047
# FIELD - swaps
# round 42 of 121, timestamp: 1677882011
# FIELD - swaps
# round 43 of 121, timestamp: 1677832859
# FIELD - swaps
# round 44 of 121, timestamp: 1677775871
# FIELD - swaps
# round 45 of 121, timestamp: 1677773483
# FIELD - swaps
# round 46 of 121, timestamp: 1677887663
# FIELD - swaps
# round 47 of 121, timestamp: 1677788855
# FIELD - swaps
# round 48 of 121, timestamp: 1677849791
# FIELD - swaps
# round 49 of 121, timestamp: 1677761735
# FIELD - swaps
# round 50 of 121, timestamp: 1677863627
# FIELD - swaps
# round 51 of 121, timestamp: 1677766859
# FIELD - swaps
# round 52 of 121, timestamp: 1677807311
# FIELD - swaps
# round 53 of 121, timestamp: 1677775571
# FIELD - swaps
# round 54 of 121, timestamp: 1677870299
# FIELD - swaps
# round 55 of 121, timestamp: 1677873887
# FIELD - swaps
# round 56 of 121, timestamp: 1677790943
# FIELD - swaps
# round 57 of 121, timestamp: 1677849827
# FIELD - swaps
# round 58 of 121, timestamp: 1677781223
# FIELD - swaps
# round 59 of 121, timestamp: 1677808883
# FIELD - swaps
# round 60 of 121, timestamp: 1677758195
# FIELD - swaps
# round 61 of 121, timestamp: 1677786359
# FIELD - swaps
# round 62 of 121, timestamp: 1677777143
# FIELD - swaps
# round 63 of 121, timestamp: 1677761783
# FIELD - swaps
# round 64 of 121, timestamp: 1677755651
# FIELD - swaps
# round 65 of 121, timestamp: 1677812999
# FIELD - swaps
# round 66 of 121, timestamp: 1677819659
# FIELD - swaps
# round 67 of 121, timestamp: 1677869327
# FIELD - swaps
# round 68 of 121, timestamp: 1677838607
# FIELD - swaps
# round 69 of 121, timestamp: 1677832979
# FIELD - swaps
# round 70 of 121, timestamp: 1677790487
# FIELD - swaps
# round 71 of 121, timestamp: 1677785375
# FIELD - swaps
# round 72 of 121, timestamp: 1677821747
# FIELD - swaps
# round 73 of 121, timestamp: 1677879095
# FIELD - swaps
# round 74 of 121, timestamp: 1677782327
# FIELD - swaps
# round 75 of 121, timestamp: 1677816635
# FIELD - swaps
# round 76 of 121, timestamp: 1677762875
# FIELD - swaps
# round 77 of 121, timestamp: 1677828419
# FIELD - swaps
# round 78 of 121, timestamp: 1677838151
# FIELD - swaps
# round 79 of 121, timestamp: 1677882191
# FIELD - swaps
# round 80 of 121, timestamp: 1677775187
# FIELD - swaps
# round 81 of 121, timestamp: 1677874007
# FIELD - swaps
# round 82 of 121, timestamp: 1677771611
# FIELD - swaps
# round 83 of 121, timestamp: 1677878627
# FIELD - swaps
# round 84 of 121, timestamp: 1677860195
# FIELD - swaps
# round 85 of 121, timestamp: 1677833075
# FIELD - swaps
# round 86 of 121, timestamp: 1677844343
# FIELD - swaps
# round 87 of 121, timestamp: 1677785975
# FIELD - swaps
# round 88 of 121, timestamp: 1677878651
# FIELD - swaps
# round 89 of 121, timestamp: 1677811583
# FIELD - swaps
# round 90 of 121, timestamp: 1677885323
# FIELD - swaps
# round 91 of 121, timestamp: 1677876107
# FIELD - swaps
# round 92 of 121, timestamp: 1677853067
# FIELD - swaps
# round 93 of 121, timestamp: 1677842315
# FIELD - swaps
# round 94 of 121, timestamp: 1677868943
# FIELD - swaps
# round 95 of 121, timestamp: 1677836687
# FIELD - swaps
# round 96 of 121, timestamp: 1677788051
# FIELD - swaps
# round 97 of 121, timestamp: 1677769619
# FIELD - swaps
# round 98 of 121, timestamp: 1677863831
# FIELD - swaps
# round 99 of 121, timestamp: 1677870491
# FIELD - swaps
# round 100 of 121, timestamp: 1677782939
# FIELD - swaps
# round 101 of 121, timestamp: 1677772703
# FIELD - swaps
# round 102 of 121, timestamp: 1677786539
# FIELD - swaps
# round 103 of 121, timestamp: 1677788591
# FIELD - swaps
# round 104 of 121, timestamp: 1677812147
# FIELD - swaps
# round 105 of 121, timestamp: 1677779903
# FIELD - swaps
# round 106 of 121, timestamp: 1677790151
# FIELD - swaps
# round 107 of 121, timestamp: 1677787595
# FIELD - swaps
# round 108 of 121, timestamp: 1677763019
# FIELD - swaps
# round 109 of 121, timestamp: 1677797327
# FIELD - swaps
# round 110 of 121, timestamp: 1677774287
# FIELD - swaps
# round 111 of 121, timestamp: 1677767123
# FIELD - swaps
# round 112 of 121, timestamp: 1677782495
# FIELD - swaps
# round 113 of 121, timestamp: 1677816803
# FIELD - swaps
# round 114 of 121, timestamp: 1677766631
# FIELD - swaps
# round 115 of 121, timestamp: 1677879791
# FIELD - swaps
# round 116 of 121, timestamp: 1677876719
# FIELD - swaps
# round 117 of 121, timestamp: 1677791219
# FIELD - swaps
# round 118 of 121, timestamp: 1677782003
# FIELD - swaps
# round 119 of 121, timestamp: 1677807095
# FIELD - swaps
# round 120 of 121, timestamp: 1677788159
# FIELD - swaps
# round 0 of 121, timestamp: 1677785603
# FIELD - swaps
# round 1 of 121, timestamp: 1677774851
# FIELD - swaps
# round 2 of 121, timestamp: 1677869063
# FIELD - swaps
# round 3 of 121, timestamp: 1677839879
# FIELD - swaps
# round 4 of 121, timestamp: 1677773831
# FIELD - swaps
# round 5 of 121, timestamp: 1677874187
# FIELD - swaps
# round 6 of 121, timestamp: 1677833231
# FIELD - swaps
# round 7 of 121, timestamp: 1677807131
# FIELD - swaps
# round 8 of 121, timestamp: 1677793307
# FIELD - swaps
# round 9 of 121, timestamp: 1677850151
# FIELD - swaps
# round 10 of 121, timestamp: 1677844007
# FIELD - swaps
# round 11 of 121, timestamp: 1677812279
# FIELD - swaps
# round 12 of 121, timestamp: 1677832763
# FIELD - swaps
# round 13 of 121, timestamp: 1677786683
# FIELD - swaps
# round 14 of 121, timestamp: 1677807683
# FIELD - swaps
# round 15 of 121, timestamp: 1677797447
# FIELD - swaps
# round 16 of 121, timestamp: 1677774407
# FIELD - swaps
# round 17 of 121, timestamp: 1677819467
# FIELD - swaps
# round 18 of 121, timestamp: 1677790283
# FIELD - swaps
# round 19 of 121, timestamp: 1677785675
# FIELD - swaps
# round 20 of 121, timestamp: 1677879887
# FIELD - swaps
# round 21 of 121, timestamp: 1677809231
# FIELD - swaps
# round 22 of 121, timestamp: 1677877847
# FIELD - swaps
# round 23 of 121, timestamp: 1677810263
# FIELD - swaps
# round 24 of 121, timestamp: 1677881435
# FIELD - swaps
# round 25 of 121, timestamp: 1677818459
# FIELD - swaps
# round 26 of 121, timestamp: 1677774431
# FIELD - swaps
# round 27 of 121, timestamp: 1677789803
# FIELD - swaps
# round 28 of 121, timestamp: 1677788267
# FIELD - swaps
# round 29 of 121, timestamp: 1677782123
# FIELD - swaps
# round 30 of 121, timestamp: 1677874799
# FIELD - swaps
# round 31 of 121, timestamp: 1677868655
# FIELD - swaps
# round 32 of 121, timestamp: 1677826679
# FIELD - swaps
# round 33 of 121, timestamp: 1677835895
# FIELD - swaps
# round 34 of 121, timestamp: 1677760631
# FIELD - swaps
# round 35 of 121, timestamp: 1677890687
# FIELD - swaps
# round 36 of 121, timestamp: 1677876863
# FIELD - swaps
# round 37 of 121, timestamp: 1677763199
# FIELD - swaps
# round 38 of 121, timestamp: 1677771395
# FIELD - swaps
# round 39 of 121, timestamp: 1677808271
# FIELD - swaps
# round 40 of 121, timestamp: 1677774479
# FIELD - swaps
# round 41 of 121, timestamp: 1677777047
# FIELD - swaps
# round 42 of 121, timestamp: 1677882011
# FIELD - swaps
# round 43 of 121, timestamp: 1677832859
# FIELD - swaps
# round 44 of 121, timestamp: 1677775871
# FIELD - swaps
# round 45 of 121, timestamp: 1677773483
# FIELD - swaps
# round 46 of 121, timestamp: 1677887663
# FIELD - swaps
# round 47 of 121, timestamp: 1677788855
# FIELD - swaps
# round 48 of 121, timestamp: 1677849791
# FIELD - swaps
# round 49 of 121, timestamp: 1677761735
# FIELD - swaps
# round 50 of 121, timestamp: 1677863627
# FIELD - swaps
# round 51 of 121, timestamp: 1677766859
# FIELD - swaps
# round 52 of 121, timestamp: 1677807311
# FIELD - swaps
# round 53 of 121, timestamp: 1677775571
# FIELD - swaps
# round 54 of 121, timestamp: 1677870299
# FIELD - swaps
# round 55 of 121, timestamp: 1677873887
# FIELD - swaps
# round 56 of 121, timestamp: 1677790943
# FIELD - swaps
# round 57 of 121, timestamp: 1677849827
# FIELD - swaps
# round 58 of 121, timestamp: 1677781223
# FIELD - swaps
# round 59 of 121, timestamp: 1677808883
# FIELD - swaps
# round 60 of 121, timestamp: 1677758195
# FIELD - swaps
# round 61 of 121, timestamp: 1677786359
# FIELD - swaps
# round 62 of 121, timestamp: 1677777143
# FIELD - swaps
# round 63 of 121, timestamp: 1677761783
# FIELD - swaps
# round 64 of 121, timestamp: 1677755651
# FIELD - swaps
# round 65 of 121, timestamp: 1677812999
# FIELD - swaps
# round 66 of 121, timestamp: 1677819659
# FIELD - swaps
# round 67 of 121, timestamp: 1677869327
# FIELD - swaps
# round 68 of 121, timestamp: 1677838607
# FIELD - swaps
# round 69 of 121, timestamp: 1677832979
# FIELD - swaps
# round 70 of 121, timestamp: 1677790487
# FIELD - swaps
# round 71 of 121, timestamp: 1677785375
# FIELD - swaps
# round 72 of 121, timestamp: 1677821747
# FIELD - swaps
# round 73 of 121, timestamp: 1677879095
# FIELD - swaps
# round 74 of 121, timestamp: 1677782327
# FIELD - swaps
# round 75 of 121, timestamp: 1677816635
# FIELD - swaps
# round 76 of 121, timestamp: 1677762875
# FIELD - swaps
# round 77 of 121, timestamp: 1677828419
# FIELD - swaps
# round 78 of 121, timestamp: 1677838151
# FIELD - swaps
# round 79 of 121, timestamp: 1677882191
# FIELD - swaps
# round 80 of 121, timestamp: 1677775187
# FIELD - swaps
# round 81 of 121, timestamp: 1677874007
# FIELD - swaps
# round 82 of 121, timestamp: 1677771611
# FIELD - swaps
# round 83 of 121, timestamp: 1677878627
# FIELD - swaps
# round 84 of 121, timestamp: 1677860195
# FIELD - swaps
# round 85 of 121, timestamp: 1677833075
# FIELD - swaps
# round 86 of 121, timestamp: 1677844343
# FIELD - swaps
# round 87 of 121, timestamp: 1677785975
# FIELD - swaps
# round 88 of 121, timestamp: 1677878651
# FIELD - swaps
# round 89 of 121, timestamp: 1677811583
# FIELD - swaps
# round 90 of 121, timestamp: 1677885323
# FIELD - swaps
# round 91 of 121, timestamp: 1677876107
# FIELD - swaps
# round 92 of 121, timestamp: 1677853067
# FIELD - swaps
# round 93 of 121, timestamp: 1677842315
# FIELD - swaps
# round 94 of 121, timestamp: 1677868943
# FIELD - swaps
# round 95 of 121, timestamp: 1677836687
# FIELD - swaps
# round 96 of 121, timestamp: 1677788051
# FIELD - swaps
# round 97 of 121, timestamp: 1677769619
# FIELD - swaps
# round 98 of 121, timestamp: 1677863831
# FIELD - swaps
# round 99 of 121, timestamp: 1677870491
# FIELD - swaps
# round 100 of 121, timestamp: 1677782939
# FIELD - swaps
# round 101 of 121, timestamp: 1677772703
# FIELD - swaps
# round 102 of 121, timestamp: 1677786539
# FIELD - swaps
# round 103 of 121, timestamp: 1677788591
# FIELD - swaps
# round 104 of 121, timestamp: 1677812147
# FIELD - swaps
# round 105 of 121, timestamp: 1677779903
# FIELD - swaps
# round 106 of 121, timestamp: 1677790151
# FIELD - swaps
# round 107 of 121, timestamp: 1677787595
# FIELD - swaps
# round 108 of 121, timestamp: 1677763019
# FIELD - swaps
# round 109 of 121, timestamp: 1677797327
# FIELD - swaps
# round 110 of 121, timestamp: 1677774287
# FIELD - swaps
# round 111 of 121, timestamp: 1677767123
# FIELD - swaps
# round 112 of 121, timestamp: 1677782495
# FIELD - swaps
# round 113 of 121, timestamp: 1677816803
# FIELD - swaps
# round 114 of 121, timestamp: 1677766631
# FIELD - swaps
# round 115 of 121, timestamp: 1677879791
# FIELD - swaps
# round 116 of 121, timestamp: 1677876719
# FIELD - swaps
# round 117 of 121, timestamp: 1677791219
# FIELD - swaps
# round 118 of 121, timestamp: 1677782003
# FIELD - swaps
# round 119 of 121, timestamp: 1677807095
# FIELD - swaps
# round 120 of 121, timestamp: 1677788159
# FIELD - swaps

# %%
# concat swaps_df_list into a single dataframe.
swaps_df = pd.concat(swaps_df_list)

# %%
swaps_df.shape
# Out:
# (2420, 20)

# %%
# print min and max swaps_timestamp
print(swaps_df['swaps_timestamp'].min())
print(swaps_df['swaps_timestamp'].max())
# Out:
# 1677747395
# 1677890675

# %%
# replace the pool addresses with LP pool names with fees
swaps_df['swaps_pool_id'] = swaps_df['swaps_pool_id'].replace(weth_usdc_list[0], 'USDC_WETH .05%')
swaps_df['swaps_pool_id'] = swaps_df['swaps_pool_id'].replace(weth_usdc_list[1], 'USDC_WETH .3%')

# replace token addresses with symbols
swaps_df['swaps_tokenIn_id'] = swaps_df['swaps_tokenIn_id'].replace(usdc_addr, 'USDC')
swaps_df['swaps_tokenIn_id'] = swaps_df['swaps_tokenIn_id'].replace(weth_addr, 'WETH')
swaps_df['swaps_tokenOut_id'] = swaps_df['swaps_tokenOut_id'].replace(usdc_addr, 'USDC')
swaps_df['swaps_tokenOut_id'] = swaps_df['swaps_tokenOut_id'].replace(weth_addr, 'WETH')

# %%
print(f'query returned {len(swaps_df)} rows\n swaps_df columns are {swaps_df.columns}')
# Out:
# query returned 2420 rows
#  swaps_df columns are Index(['swaps_id', 'swaps_hash', 'swaps_nonce', 'swaps_logIndex',
#        'swaps_gasLimit', 'swaps_gasUsed', 'swaps_gasPrice',
#        'swaps_protocol_id', 'swaps_account_id', 'swaps_pool_id',
#        'swaps_blockNumber', 'swaps_timestamp', 'swaps_tick',
#        'swaps_tokenIn_id', 'swaps_amountIn', 'swaps_amountInUSD',
#        'swaps_tokenOut_id', 'swaps_amountOut', 'swaps_amountOutUSD',
#        'endpoint'],
#       dtype='object')

# %% [markdown]
# ### Get the Uniswap Gas Data

# %%
univ3_no_messari_ds = Streamer('https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3')

# %%
transactions_fp = univ3_no_messari_ds.queryDict.get('transactions')

# %%
transactions_df_list = []

# %%
for lp in weth_usdc_list: # outer loop loops through liquidity pools
    for i in range(0, len(cow_timestamps)): # inner loop through cowswap timestamps
        print(f'round {i} of {len(cow_timestamps)}, timestamp: {cow_timestamps[i]}')
        # define the query path
        txs_qp = transactions_fp(
            first=10,
            orderBy='timestamp',
            orderDirection='desc',
            where = {"swaps_": {'timestamp': cow_timestamps[i], 'pool': lp}}
            )
        
        # run query
        df = univ3_no_messari_ds.runQuery(txs_qp)

        if df.empty:
            print('empty')
            continue
        else:
            transactions_df_list.append(df)
# Out:
# round 0 of 121, timestamp: 1677785603
# FIELD - transactions
# round 1 of 121, timestamp: 1677774851
# FIELD - transactions
# round 2 of 121, timestamp: 1677869063
# FIELD - transactions
# round 3 of 121, timestamp: 1677839879
# FIELD - transactions
# round 4 of 121, timestamp: 1677773831
# FIELD - transactions
# round 5 of 121, timestamp: 1677874187
# FIELD - transactions
# round 6 of 121, timestamp: 1677833231
# FIELD - transactions
# round 7 of 121, timestamp: 1677807131
# FIELD - transactions
# round 8 of 121, timestamp: 1677793307
# FIELD - transactions
# round 9 of 121, timestamp: 1677850151
# FIELD - transactions
# round 10 of 121, timestamp: 1677844007
# FIELD - transactions
# empty
# round 11 of 121, timestamp: 1677812279
# FIELD - transactions
# round 12 of 121, timestamp: 1677832763
# FIELD - transactions
# round 13 of 121, timestamp: 1677786683
# FIELD - transactions
# round 14 of 121, timestamp: 1677807683
# FIELD - transactions
# round 15 of 121, timestamp: 1677797447
# FIELD - transactions
# empty
# round 16 of 121, timestamp: 1677774407
# FIELD - transactions
# round 17 of 121, timestamp: 1677819467
# FIELD - transactions
# empty
# round 18 of 121, timestamp: 1677790283
# FIELD - transactions
# round 19 of 121, timestamp: 1677785675
# FIELD - transactions
# round 20 of 121, timestamp: 1677879887
# FIELD - transactions
# round 21 of 121, timestamp: 1677809231
# FIELD - transactions
# round 22 of 121, timestamp: 1677877847
# FIELD - transactions
# round 23 of 121, timestamp: 1677810263
# FIELD - transactions
# round 24 of 121, timestamp: 1677881435
# FIELD - transactions
# empty
# round 25 of 121, timestamp: 1677818459
# FIELD - transactions
# round 26 of 121, timestamp: 1677774431
# FIELD - transactions
# round 27 of 121, timestamp: 1677789803
# FIELD - transactions
# empty
# round 28 of 121, timestamp: 1677788267
# FIELD - transactions
# empty
# round 29 of 121, timestamp: 1677782123
# FIELD - transactions
# round 30 of 121, timestamp: 1677874799
# FIELD - transactions
# round 31 of 121, timestamp: 1677868655
# FIELD - transactions
# round 32 of 121, timestamp: 1677826679
# FIELD - transactions
# empty
# round 33 of 121, timestamp: 1677835895
# FIELD - transactions
# round 34 of 121, timestamp: 1677760631
# FIELD - transactions
# round 35 of 121, timestamp: 1677890687
# FIELD - transactions
# round 36 of 121, timestamp: 1677876863
# FIELD - transactions
# empty
# round 37 of 121, timestamp: 1677763199
# FIELD - transactions
# round 38 of 121, timestamp: 1677771395
# FIELD - transactions
# round 39 of 121, timestamp: 1677808271
# FIELD - transactions
# round 40 of 121, timestamp: 1677774479
# FIELD - transactions
# round 41 of 121, timestamp: 1677777047
# FIELD - transactions
# round 42 of 121, timestamp: 1677882011
# FIELD - transactions
# round 43 of 121, timestamp: 1677832859
# FIELD - transactions
# round 44 of 121, timestamp: 1677775871
# FIELD - transactions
# round 45 of 121, timestamp: 1677773483
# FIELD - transactions
# empty
# round 46 of 121, timestamp: 1677887663
# FIELD - transactions
# round 47 of 121, timestamp: 1677788855
# FIELD - transactions
# round 48 of 121, timestamp: 1677849791
# FIELD - transactions
# round 49 of 121, timestamp: 1677761735
# FIELD - transactions
# round 50 of 121, timestamp: 1677863627
# FIELD - transactions
# empty
# round 51 of 121, timestamp: 1677766859
# FIELD - transactions
# round 52 of 121, timestamp: 1677807311
# FIELD - transactions
# round 53 of 121, timestamp: 1677775571
# FIELD - transactions
# round 54 of 121, timestamp: 1677870299
# FIELD - transactions
# round 55 of 121, timestamp: 1677873887
# FIELD - transactions
# round 56 of 121, timestamp: 1677790943
# FIELD - transactions
# round 57 of 121, timestamp: 1677849827
# FIELD - transactions
# round 58 of 121, timestamp: 1677781223
# FIELD - transactions
# round 59 of 121, timestamp: 1677808883
# FIELD - transactions
# round 60 of 121, timestamp: 1677758195
# FIELD - transactions
# round 61 of 121, timestamp: 1677786359
# FIELD - transactions
# round 62 of 121, timestamp: 1677777143
# FIELD - transactions
# empty
# round 63 of 121, timestamp: 1677761783
# FIELD - transactions
# round 64 of 121, timestamp: 1677755651
# FIELD - transactions
# round 65 of 121, timestamp: 1677812999
# FIELD - transactions
# round 66 of 121, timestamp: 1677819659
# FIELD - transactions
# round 67 of 121, timestamp: 1677869327
# FIELD - transactions
# empty
# round 68 of 121, timestamp: 1677838607
# FIELD - transactions
# empty
# round 69 of 121, timestamp: 1677832979
# FIELD - transactions
# round 70 of 121, timestamp: 1677790487
# FIELD - transactions
# round 71 of 121, timestamp: 1677785375
# FIELD - transactions
# round 72 of 121, timestamp: 1677821747
# FIELD - transactions
# round 73 of 121, timestamp: 1677879095
# FIELD - transactions
# round 74 of 121, timestamp: 1677782327
# FIELD - transactions
# round 75 of 121, timestamp: 1677816635
# FIELD - transactions
# round 76 of 121, timestamp: 1677762875
# FIELD - transactions
# empty
# round 77 of 121, timestamp: 1677828419
# FIELD - transactions
# round 78 of 121, timestamp: 1677838151
# FIELD - transactions
# empty
# round 79 of 121, timestamp: 1677882191
# FIELD - transactions
# round 80 of 121, timestamp: 1677775187
# FIELD - transactions
# round 81 of 121, timestamp: 1677874007
# FIELD - transactions
# round 82 of 121, timestamp: 1677771611
# FIELD - transactions
# round 83 of 121, timestamp: 1677878627
# FIELD - transactions
# empty
# round 84 of 121, timestamp: 1677860195
# FIELD - transactions
# round 85 of 121, timestamp: 1677833075
# FIELD - transactions
# round 86 of 121, timestamp: 1677844343
# FIELD - transactions
# empty
# round 87 of 121, timestamp: 1677785975
# FIELD - transactions
# round 88 of 121, timestamp: 1677878651
# FIELD - transactions
# round 89 of 121, timestamp: 1677811583
# FIELD - transactions
# round 90 of 121, timestamp: 1677885323
# FIELD - transactions
# round 91 of 121, timestamp: 1677876107
# FIELD - transactions
# round 92 of 121, timestamp: 1677853067
# FIELD - transactions
# round 93 of 121, timestamp: 1677842315
# FIELD - transactions
# round 94 of 121, timestamp: 1677868943
# FIELD - transactions
# round 95 of 121, timestamp: 1677836687
# FIELD - transactions
# round 96 of 121, timestamp: 1677788051
# FIELD - transactions
# round 97 of 121, timestamp: 1677769619
# FIELD - transactions
# round 98 of 121, timestamp: 1677863831
# FIELD - transactions
# round 99 of 121, timestamp: 1677870491
# FIELD - transactions
# round 100 of 121, timestamp: 1677782939
# FIELD - transactions
# round 101 of 121, timestamp: 1677772703
# FIELD - transactions
# empty
# round 102 of 121, timestamp: 1677786539
# FIELD - transactions
# round 103 of 121, timestamp: 1677788591
# FIELD - transactions
# empty
# round 104 of 121, timestamp: 1677812147
# FIELD - transactions
# round 105 of 121, timestamp: 1677779903
# FIELD - transactions
# round 106 of 121, timestamp: 1677790151
# FIELD - transactions
# round 107 of 121, timestamp: 1677787595
# FIELD - transactions
# round 108 of 121, timestamp: 1677763019
# FIELD - transactions
# round 109 of 121, timestamp: 1677797327
# FIELD - transactions
# round 110 of 121, timestamp: 1677774287
# FIELD - transactions
# round 111 of 121, timestamp: 1677767123
# FIELD - transactions
# round 112 of 121, timestamp: 1677782495
# FIELD - transactions
# round 113 of 121, timestamp: 1677816803
# FIELD - transactions
# round 114 of 121, timestamp: 1677766631
# FIELD - transactions
# round 115 of 121, timestamp: 1677879791
# FIELD - transactions
# round 116 of 121, timestamp: 1677876719
# FIELD - transactions
# round 117 of 121, timestamp: 1677791219
# FIELD - transactions
# round 118 of 121, timestamp: 1677782003
# FIELD - transactions
# round 119 of 121, timestamp: 1677807095
# FIELD - transactions
# round 120 of 121, timestamp: 1677788159
# FIELD - transactions
# round 0 of 121, timestamp: 1677785603
# FIELD - transactions
# empty
# round 1 of 121, timestamp: 1677774851
# FIELD - transactions
# empty
# round 2 of 121, timestamp: 1677869063
# FIELD - transactions
# empty
# round 3 of 121, timestamp: 1677839879
# FIELD - transactions
# empty
# round 4 of 121, timestamp: 1677773831
# FIELD - transactions
# empty
# round 5 of 121, timestamp: 1677874187
# FIELD - transactions
# empty
# round 6 of 121, timestamp: 1677833231
# FIELD - transactions
# empty
# round 7 of 121, timestamp: 1677807131
# FIELD - transactions
# round 8 of 121, timestamp: 1677793307
# FIELD - transactions
# empty
# round 9 of 121, timestamp: 1677850151
# FIELD - transactions
# empty
# round 10 of 121, timestamp: 1677844007
# FIELD - transactions
# empty
# round 11 of 121, timestamp: 1677812279
# FIELD - transactions
# empty
# round 12 of 121, timestamp: 1677832763
# FIELD - transactions
# empty
# round 13 of 121, timestamp: 1677786683
# FIELD - transactions
# empty
# round 14 of 121, timestamp: 1677807683
# FIELD - transactions
# empty
# round 15 of 121, timestamp: 1677797447
# FIELD - transactions
# empty
# round 16 of 121, timestamp: 1677774407
# FIELD - transactions
# empty
# round 17 of 121, timestamp: 1677819467
# FIELD - transactions
# round 18 of 121, timestamp: 1677790283
# FIELD - transactions
# empty
# round 19 of 121, timestamp: 1677785675
# FIELD - transactions
# empty
# round 20 of 121, timestamp: 1677879887
# FIELD - transactions
# empty
# round 21 of 121, timestamp: 1677809231
# FIELD - transactions
# round 22 of 121, timestamp: 1677877847
# FIELD - transactions
# round 23 of 121, timestamp: 1677810263
# FIELD - transactions
# empty
# round 24 of 121, timestamp: 1677881435
# FIELD - transactions
# empty
# round 25 of 121, timestamp: 1677818459
# FIELD - transactions
# empty
# round 26 of 121, timestamp: 1677774431
# FIELD - transactions
# empty
# round 27 of 121, timestamp: 1677789803
# FIELD - transactions
# empty
# round 28 of 121, timestamp: 1677788267
# FIELD - transactions
# empty
# round 29 of 121, timestamp: 1677782123
# FIELD - transactions
# empty
# round 30 of 121, timestamp: 1677874799
# FIELD - transactions
# empty
# round 31 of 121, timestamp: 1677868655
# FIELD - transactions
# empty
# round 32 of 121, timestamp: 1677826679
# FIELD - transactions
# empty
# round 33 of 121, timestamp: 1677835895
# FIELD - transactions
# empty
# round 34 of 121, timestamp: 1677760631
# FIELD - transactions
# empty
# round 35 of 121, timestamp: 1677890687
# FIELD - transactions
# round 36 of 121, timestamp: 1677876863
# FIELD - transactions
# empty
# round 37 of 121, timestamp: 1677763199
# FIELD - transactions
# empty
# round 38 of 121, timestamp: 1677771395
# FIELD - transactions
# empty
# round 39 of 121, timestamp: 1677808271
# FIELD - transactions
# empty
# round 40 of 121, timestamp: 1677774479
# FIELD - transactions
# empty
# round 41 of 121, timestamp: 1677777047
# FIELD - transactions
# empty
# round 42 of 121, timestamp: 1677882011
# FIELD - transactions
# empty
# round 43 of 121, timestamp: 1677832859
# FIELD - transactions
# empty
# round 44 of 121, timestamp: 1677775871
# FIELD - transactions
# empty
# round 45 of 121, timestamp: 1677773483
# FIELD - transactions
# empty
# round 46 of 121, timestamp: 1677887663
# FIELD - transactions
# empty
# round 47 of 121, timestamp: 1677788855
# FIELD - transactions
# empty
# round 48 of 121, timestamp: 1677849791
# FIELD - transactions
# empty
# round 49 of 121, timestamp: 1677761735
# FIELD - transactions
# empty
# round 50 of 121, timestamp: 1677863627
# FIELD - transactions
# empty
# round 51 of 121, timestamp: 1677766859
# FIELD - transactions
# round 52 of 121, timestamp: 1677807311
# FIELD - transactions
# empty
# round 53 of 121, timestamp: 1677775571
# FIELD - transactions
# empty
# round 54 of 121, timestamp: 1677870299
# FIELD - transactions
# empty
# round 55 of 121, timestamp: 1677873887
# FIELD - transactions
# empty
# round 56 of 121, timestamp: 1677790943
# FIELD - transactions
# empty
# round 57 of 121, timestamp: 1677849827
# FIELD - transactions
# empty
# round 58 of 121, timestamp: 1677781223
# FIELD - transactions
# empty
# round 59 of 121, timestamp: 1677808883
# FIELD - transactions
# empty
# round 60 of 121, timestamp: 1677758195
# FIELD - transactions
# empty
# round 61 of 121, timestamp: 1677786359
# FIELD - transactions
# empty
# round 62 of 121, timestamp: 1677777143
# FIELD - transactions
# empty
# round 63 of 121, timestamp: 1677761783
# FIELD - transactions
# empty
# round 64 of 121, timestamp: 1677755651
# FIELD - transactions
# empty
# round 65 of 121, timestamp: 1677812999
# FIELD - transactions
# empty
# round 66 of 121, timestamp: 1677819659
# FIELD - transactions
# empty
# round 67 of 121, timestamp: 1677869327
# FIELD - transactions
# empty
# round 68 of 121, timestamp: 1677838607
# FIELD - transactions
# empty
# round 69 of 121, timestamp: 1677832979
# FIELD - transactions
# empty
# round 70 of 121, timestamp: 1677790487
# FIELD - transactions
# empty
# round 71 of 121, timestamp: 1677785375
# FIELD - transactions
# empty
# round 72 of 121, timestamp: 1677821747
# FIELD - transactions
# empty
# round 73 of 121, timestamp: 1677879095
# FIELD - transactions
# empty
# round 74 of 121, timestamp: 1677782327
# FIELD - transactions
# empty
# round 75 of 121, timestamp: 1677816635
# FIELD - transactions
# empty
# round 76 of 121, timestamp: 1677762875
# FIELD - transactions
# empty
# round 77 of 121, timestamp: 1677828419
# FIELD - transactions
# empty
# round 78 of 121, timestamp: 1677838151
# FIELD - transactions
# empty
# round 79 of 121, timestamp: 1677882191
# FIELD - transactions
# empty
# round 80 of 121, timestamp: 1677775187
# FIELD - transactions
# empty
# round 81 of 121, timestamp: 1677874007
# FIELD - transactions
# empty
# round 82 of 121, timestamp: 1677771611
# FIELD - transactions
# empty
# round 83 of 121, timestamp: 1677878627
# FIELD - transactions
# empty
# round 84 of 121, timestamp: 1677860195
# FIELD - transactions
# empty
# round 85 of 121, timestamp: 1677833075
# FIELD - transactions
# empty
# round 86 of 121, timestamp: 1677844343
# FIELD - transactions
# empty
# round 87 of 121, timestamp: 1677785975
# FIELD - transactions
# empty
# round 88 of 121, timestamp: 1677878651
# FIELD - transactions
# empty
# round 89 of 121, timestamp: 1677811583
# FIELD - transactions
# empty
# round 90 of 121, timestamp: 1677885323
# FIELD - transactions
# empty
# round 91 of 121, timestamp: 1677876107
# FIELD - transactions
# empty
# round 92 of 121, timestamp: 1677853067
# FIELD - transactions
# empty
# round 93 of 121, timestamp: 1677842315
# FIELD - transactions
# empty
# round 94 of 121, timestamp: 1677868943
# FIELD - transactions
# empty
# round 95 of 121, timestamp: 1677836687
# FIELD - transactions
# empty
# round 96 of 121, timestamp: 1677788051
# FIELD - transactions
# empty
# round 97 of 121, timestamp: 1677769619
# FIELD - transactions
# empty
# round 98 of 121, timestamp: 1677863831
# FIELD - transactions
# empty
# round 99 of 121, timestamp: 1677870491
# FIELD - transactions
# empty
# round 100 of 121, timestamp: 1677782939
# FIELD - transactions
# empty
# round 101 of 121, timestamp: 1677772703
# FIELD - transactions
# empty
# round 102 of 121, timestamp: 1677786539
# FIELD - transactions
# empty
# round 103 of 121, timestamp: 1677788591
# FIELD - transactions
# empty
# round 104 of 121, timestamp: 1677812147
# FIELD - transactions
# empty
# round 105 of 121, timestamp: 1677779903
# FIELD - transactions
# empty
# round 106 of 121, timestamp: 1677790151
# FIELD - transactions
# empty
# round 107 of 121, timestamp: 1677787595
# FIELD - transactions
# empty
# round 108 of 121, timestamp: 1677763019
# FIELD - transactions
# empty
# round 109 of 121, timestamp: 1677797327
# FIELD - transactions
# empty
# round 110 of 121, timestamp: 1677774287
# FIELD - transactions
# empty
# round 111 of 121, timestamp: 1677767123
# FIELD - transactions
# empty
# round 112 of 121, timestamp: 1677782495
# FIELD - transactions
# empty
# round 113 of 121, timestamp: 1677816803
# FIELD - transactions
# empty
# round 114 of 121, timestamp: 1677766631
# FIELD - transactions
# empty
# round 115 of 121, timestamp: 1677879791
# FIELD - transactions
# empty
# round 116 of 121, timestamp: 1677876719
# FIELD - transactions
# empty
# round 117 of 121, timestamp: 1677791219
# FIELD - transactions
# empty
# round 118 of 121, timestamp: 1677782003
# FIELD - transactions
# empty
# round 119 of 121, timestamp: 1677807095
# FIELD - transactions
# round 120 of 121, timestamp: 1677788159
# FIELD - transactions
# empty

# %%
# concat transactions_df_list
transactions_df = pd.concat(transactions_df_list)

# %%
transactions_df.shape
# Out:
# (186, 6)

# %%
# get dataframe row types swaps_df
swaps_df.dtypes
# Out:
# swaps_id               object
# swaps_hash             object
# swaps_nonce             int64
# swaps_logIndex          int64
# swaps_gasLimit          int64
# swaps_gasUsed          object
# swaps_gasPrice          int64
# swaps_protocol_id      object
# swaps_account_id       object
# swaps_pool_id          object
# swaps_blockNumber       int64
# swaps_timestamp         int64
# swaps_tick              int64
# swaps_tokenIn_id       object
# swaps_amountIn         object
# swaps_amountInUSD     float64
# swaps_tokenOut_id      object
# swaps_amountOut        object
# swaps_amountOutUSD    float64
# endpoint               object
# dtype: object

# %%
# enforce swaps_df column types. This is necessary because the data types are not enforced by pandas dataframes. We need to enforce the types as a preprocessing step to converting to Polars
swaps_df['swaps_gasLimit'] = swaps_df['swaps_gasLimit'].astype('float64')
swaps_df['swaps_gasUsed'] = swaps_df['swaps_gasUsed'].astype('float64')
swaps_df['swaps_gasPrice'] = swaps_df['swaps_gasPrice'].astype('float64')
swaps_df['swaps_amountIn'] = swaps_df['swaps_amountIn'].astype('float64')
swaps_df['swaps_amountInUSD'] = swaps_df['swaps_amountInUSD'].astype('float64')
swaps_df['swaps_amountOut'] = swaps_df['swaps_amountOut'].astype('float64')
swaps_df['swaps_amountOutUSD'] = swaps_df['swaps_amountOutUSD'].astype('float64')
swaps_df['swaps_blockNumber'] = swaps_df['swaps_blockNumber'].astype('int64')
swaps_df['swaps_timestamp'] = swaps_df['swaps_timestamp'].astype('int64')

# %%
# convert swaps, transactions, and cowswap dataframes to polars
swaps_pl = pl.from_pandas(swaps_df)
transactions_pl = pl.from_pandas(transactions_df)
# recall cow_trades_pl was already created earlier

# %% [markdown]
# ### Merge Swaps and Transactions for Gas

# %%
# merge swaps_pl and transactions_pl polars
uni_complete_pl = swaps_pl.join(transactions_pl, left_on="swaps_hash", right_on="transactions_id", how="inner")

# %%
# drop duplicate rows
uni_complete_pl = uni_complete_pl.unique()

# %%
# drop endpoint column from uni_complete_pl
uni_complete_pl = uni_complete_pl.drop('endpoint')

# %%
# get median transactions_gasUsed amount. Typical V3 swap is 127k gas for One-hop. However with multiple hops, gas will be higher. 352 reflects an avg of 3 hops worth of gas
tx_gas_median = uni_complete_pl['transactions_gasUsed'].median()
print(f'transaction gas median is {tx_gas_median}')
# Out:
# transaction gas median is 316866.0

# %%
# to get transaction gas used, we do gasUsed * gasPrice
uni_complete_pl = uni_complete_pl.with_columns([
    (127000 * pl.col("transactions_gasPrice")).alias('transaction_gas_fee_one_hop'),
    (tx_gas_median * pl.col("transactions_gasPrice")).alias('transaction_gas_fee_median')
    ])

# %%
uni_complete_pl = uni_complete_pl.with_columns([
    (pl.col("transaction_gas_fee_one_hop") / 10**18).alias('transaction_gas_fee_one_hop'), # wei is 10^9, but eth is 10^18
        (pl.col("transaction_gas_fee_median") / 10**18).alias('transaction_gas_fee_median') # wei is 10^9, but eth is 10^18
])

# %%
# sort by largest transaction_gas_fee
uni_complete_pl.sort("transaction_gas_fee_one_hop", reverse=False).head(5)
# Out:
# shape: (5, 26)
# ┌────┬──────────┬───────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ sw ┆ swaps_ha ┆ swaps_non ┆ swaps_logI ┆ ... ┆ transactio ┆ endpoint_r ┆ transactio ┆ transactio │
# │ ap ┆ sh       ┆ ce        ┆ ndex       ┆     ┆ ns_gasPric ┆ ight       ┆ n_gas_fee_ ┆ n_gas_fee_ │
# │ s_ ┆ ---      ┆ ---       ┆ ---        ┆     ┆ e          ┆ ---        ┆ one_hop    ┆ median     │
# │ id ┆ str      ┆ i64       ┆ i64        ┆     ┆ ---        ┆ str        ┆ ---        ┆ ---        │
# │ -- ┆          ┆           ┆            ┆     ┆ i64        ┆            ┆ f64        ┆ f64        │
# │ -  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ st ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ r  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# ╞════╪══════════╪═══════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 0x ┆ 0x04dcd1 ┆ 665       ┆ 446        ┆ ... ┆ 1902000000 ┆ uniswap-v3 ┆ 0.002416   ┆ 0.006027   │
# │ 04 ┆ 21fa48f3 ┆           ┆            ┆     ┆ 0          ┆            ┆            ┆            │
# │ dc ┆ 46dd082b ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d1 ┆ bf350aa6 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 21 ┆ ...      ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ fa ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 48 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ f3 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 46 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ dd ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 08 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 2b ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ bf ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 35 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0a ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a6 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .. ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x ┆ 0x25870f ┆ 23063     ┆ 397        ┆ ... ┆ 1906690894 ┆ uniswap-v3 ┆ 0.002421   ┆ 0.006042   │
# │ 25 ┆ fe85d4ee ┆           ┆            ┆     ┆ 9          ┆            ┆            ┆            │
# │ 87 ┆ fd87d22a ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0f ┆ a9b426f0 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ fe ┆ ...      ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 85 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d4 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ ee ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ fd ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 87 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d2 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 2a ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a9 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ b4 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 26 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ f0 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .. ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x ┆ 0xac096f ┆ 6956      ┆ 322        ┆ ... ┆ 2090333166 ┆ uniswap-v3 ┆ 0.002655   ┆ 0.006624   │
# │ ac ┆ ea13c0d2 ┆           ┆            ┆     ┆ 9          ┆            ┆            ┆            │
# │ 09 ┆ 09931e7c ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 6f ┆ bb480374 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ ea ┆ ...      ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 13 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ c0 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d2 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 09 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 93 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 1e ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 7c ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ bb ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 48 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 03 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 74 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .. ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x ┆ 0xe4e15c ┆ 40        ┆ 247        ┆ ... ┆ 2160941805 ┆ uniswap-v3 ┆ 0.002744   ┆ 0.006847   │
# │ e4 ┆ fa27a1bd ┆           ┆            ┆     ┆ 6          ┆            ┆            ┆            │
# │ e1 ┆ 1c9e3d64 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 5c ┆ 73126471 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ fa ┆ ...      ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 27 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a1 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ bd ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 1c ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 9e ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 3d ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 64 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 73 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 12 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 64 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 71 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .. ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 0x ┆ 0x19c556 ┆ 12        ┆ 252        ┆ ... ┆ 2160941805 ┆ uniswap-v3 ┆ 0.002744   ┆ 0.006847   │
# │ 19 ┆ 2dd359a3 ┆           ┆            ┆     ┆ 6          ┆            ┆            ┆            │
# │ c5 ┆ 42299545 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 56 ┆ d1e4fa25 ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 2d ┆ ...      ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d3 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 59 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ a3 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 42 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 29 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 95 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 45 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ d1 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ e4 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ fa ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 25 ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .. ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# │ .  ┆          ┆           ┆            ┆     ┆            ┆            ┆            ┆            │
# └────┴──────────┴───────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### Merge Cow and Univ3

# %%
# merge trades and swaps on timestamp value. We use outer join because we want to keep all trades and swaps data and backfill swap values
cow_uni_outer_pl = cow_complete_pl.join(other=uni_complete_pl, left_on='trades_timestamp', right_on='swaps_timestamp', how='outer')

# %%
cow_uni_outer_pl.columns
# Out:
# ['trades_id',
#  'trades_timestamp',
#  'trades_gasPrice',
#  'trades_feeAmount',
#  'trades_txHash',
#  'trades_settlement_id',
#  'trades_buyAmount',
#  'trades_sellAmount',
#  'trades_sellToken_id',
#  'trades_buyToken_id',
#  'trades_order_id',
#  'trades_buyAmountEth',
#  'trades_sellAmountEth',
#  'trades_buyAmountUsd',
#  'trades_sellAmountUsd',
#  'endpoint',
#  'settlements_id',
#  'settlements_firstTradeTimestamp',
#  'settlements_solver_id',
#  'environment',
#  'name',
#  'active',
#  'swaps_id',
#  'swaps_hash',
#  'swaps_nonce',
#  'swaps_logIndex',
#  'swaps_gasLimit',
#  'swaps_gasUsed',
#  'swaps_gasPrice',
#  'swaps_protocol_id',
#  'swaps_account_id',
#  'swaps_pool_id',
#  'swaps_blockNumber',
#  'swaps_tick',
#  'swaps_tokenIn_id',
#  'swaps_amountIn',
#  'swaps_amountInUSD',
#  'swaps_tokenOut_id',
#  'swaps_amountOut',
#  'swaps_amountOutUSD',
#  'transactions_blockNumber',
#  'transactions_timestamp',
#  'transactions_gasUsed',
#  'transactions_gasPrice',
#  'endpoint_right',
#  'transaction_gas_fee_one_hop',
#  'transaction_gas_fee_median']

# %%
# This truncated dataframe isn't being used right now
cow_uni_trunc_pl = cow_uni_outer_pl[[
    'trades_timestamp', 
    'trades_txHash',
    'trades_feeAmount',
    'trades_sellToken_id', 
    'trades_buyToken_id', 
    'trades_buyAmount',
    'trades_sellAmount',
    # 'trades_sellAmountUsd', 
    # 'trades_buyAmountUsd', 
    'name',
    'environment',
    'swaps_pool_id', 
    'swaps_tokenIn_id', 
    'swaps_tokenOut_id',
    'swaps_amountIn',
    'swaps_amountOut',  
    # 'swaps_amountInUSD',
    # 'swaps_amountOutUSD',
    'swaps_blockNumber',
    # 'transactions_timestamp',
    # 'transactions_gasUsed',
    # 'transactions_gasPrice',
    'transaction_gas_fee_one_hop',
    'transaction_gas_fee_median'
    ]]

# %%
#check pl dataframe size
cow_uni_trunc_pl.shape
# Out:
# (252, 17)

# %%
# sort by largest transaction_gas_fee
cow_uni_trunc_pl.sort("transaction_gas_fee_one_hop", reverse=True).head(5)
# Out:
# shape: (5, 17)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ trades_tim ┆ trades_txH ┆ trades_fee ┆ trades_sel ┆ ... ┆ swaps_amou ┆ swaps_bloc ┆ transactio ┆ transactio │
# │ estamp     ┆ ash        ┆ Amount     ┆ lToken_id  ┆     ┆ ntOut      ┆ kNumber    ┆ n_gas_fee_ ┆ n_gas_fee_ │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ ---        ┆ ---        ┆ one_hop    ┆ median     │
# │ i64        ┆ str        ┆ i64        ┆ str        ┆     ┆ f64        ┆ i64        ┆ ---        ┆ ---        │
# │            ┆            ┆            ┆            ┆     ┆            ┆            ┆ f64        ┆ f64        │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 1677868943 ┆ 0x3316ecd6 ┆ 0          ┆ WETH       ┆ ... ┆ 3.7296e20  ┆ 16749830   ┆ 0.275402   ┆ 0.687131   │
# │            ┆ b47a225d45 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 7fb761e55e ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 04...      ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 1677868943 ┆ 0x3316ecd6 ┆ 0          ┆ WETH       ┆ ... ┆ 3.7296e20  ┆ 16749830   ┆ 0.275402   ┆ 0.687131   │
# │            ┆ b47a225d45 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 7fb761e55e ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 04...      ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 1677807095 ┆ null       ┆ null       ┆ null       ┆ ... ┆ 7.6905e11  ┆ 16744733   ┆ 0.016494   ┆ 0.041152   │
# │ 1677766859 ┆ 0x4ece7b5f ┆ 7922188    ┆ USDC       ┆ ... ┆ 1.4740e11  ┆ 16741434   ┆ 0.015002   ┆ 0.037431   │
# │            ┆ 5a17a624c6 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 22bdd7d278 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ a8...      ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │ 1677766859 ┆ 0x4ece7b5f ┆ 21497757   ┆ USDC       ┆ ... ┆ 1.4740e11  ┆ 16741434   ┆ 0.015002   ┆ 0.037431   │
# │            ┆ 5a17a624c6 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ 22bdd7d278 ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# │            ┆ a8...      ┆            ┆            ┆     ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### Chainlink

# %%
# load streamer class
chain_ds = Streamer('https://api.thegraph.com/subgraphs/name/openpredict/chainlink-prices-subgraph')

# %%
chain_price_feed = "ETH/USD"

# %%
chain_dfs_list = []

# %%
# get a query field path from the query dictionary which is automatically populated in the Streamer object
chain_fp = chain_ds.queryDict.get('prices')

# add parameters to the settlements_qp.
chain_qp = chain_fp(
    first=query_size * 5,
    orderBy='timestamp',
    orderDirection='desc',
    where = {'timestamp_lt': timestamp, 'assetPair': chain_price_feed}
    )

# run query
chain_df = chain_ds.runQuery(chain_qp)
# Out:
# FIELD - prices

# %%
# drop prices_id, endpoint. 
chain_df = chain_df.drop(['prices_id', 'endpoint'], axis=1)
# divide prices_price by 1e8 to get the price in USD
chain_df['prices_price'] = chain_df['prices_price'] / 10 ** 8

# %%
chain_df.shape
# Out:
# (615, 3)

# %%
chain_pl = pl.from_pandas(chain_df)

# %%
# outer merge chain_df with cow_uni_outer_pl on timestamp
cow_uni_chain_outer_pl = cow_uni_trunc_pl.join(other=chain_pl, left_on='trades_timestamp', right_on='prices_timestamp', how='outer')

# %%
cow_uni_chain_outer_pl.shape
# Out:
# (867, 19)

# %% [markdown]
# ### Price Calculations

# %% [markdown]
# #### Decimal Calculations

# %%
# add decimals to cow trades sell tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('trades_sellToken_id'),
        (
            pl.when(pl.col('trades_sellToken_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('trades_sellToken_decimals'),
    ]
)

# add decimals to cow trades buy tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('trades_buyToken_id'),
        (
            pl.when(pl.col('trades_buyToken_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('trades_buyToken_decimals'),
    ]
)

# add decimals to cow trades sell tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('swaps_tokenIn_id'),
        (
            pl.when(pl.col('swaps_tokenIn_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('swaps_tokenIn_decimals'),
    ]
)

# add decimals to cow trades buy tokens
cow_uni_chain_outer_pl = cow_uni_chain_outer_pl.with_columns(
    [
        pl.col('swaps_tokenOut_id'),
        (
            pl.when(pl.col('swaps_tokenOut_id') == 'WETH')
            .then(18)
            .otherwise(6)
            .cast(pl.UInt8)
        ).alias('swaps_tokenOut_decimals'),
    ]
)

# %%
cow_uni_chain_outer_pl.columns # NOTE - the DF has transaction cols
# Out:
# ['trades_timestamp',
#  'trades_txHash',
#  'trades_feeAmount',
#  'trades_sellToken_id',
#  'trades_buyToken_id',
#  'trades_buyAmount',
#  'trades_sellAmount',
#  'name',
#  'environment',
#  'swaps_pool_id',
#  'swaps_tokenIn_id',
#  'swaps_tokenOut_id',
#  'swaps_amountIn',
#  'swaps_amountOut',
#  'swaps_blockNumber',
#  'transaction_gas_fee_one_hop',
#  'transaction_gas_fee_median',
#  'prices_assetPair_id',
#  'prices_price',
#  'trades_sellToken_decimals',
#  'trades_buyToken_decimals',
#  'swaps_tokenIn_decimals',
#  'swaps_tokenOut_decimals']

# %% [markdown]
# #### Execution Price Calculations

# %%
# NOTE - Polars can perform these calculations in-column. This means it can convert the values in place without creating a new column. The new column created here is more verbose, but is a good sanity check to see before/after results.
trades_swaps_converted_pl = cow_uni_chain_outer_pl.with_columns([
    (pl.col("trades_buyAmount") / (10**pl.col("trades_buyToken_decimals"))).alias('trades_buyAmount_converted'),
    (pl.col("trades_sellAmount") / (10**pl.col("trades_sellToken_decimals"))).alias('trades_sellAmount_converted'),
    (pl.col("swaps_amountIn") / (10**pl.col("swaps_tokenIn_decimals"))).alias('swaps_amountIn_converted'),
    (pl.col("swaps_amountOut") / (10**pl.col("swaps_tokenOut_decimals"))).alias('swaps_amountOut_converted'),
])

# %%
trades_swaps_converted_trunc_pl = trades_swaps_converted_pl.with_columns([
    (pl.col("trades_buyAmount_converted") / pl.col("trades_sellAmount_converted")).alias('trades_buy_sell_ratio'),
    (pl.col("trades_sellAmount_converted") / pl.col("trades_buyAmount_converted")).alias('trades_sell_buy_ratio'),
    (pl.col("swaps_amountIn_converted") / pl.col("swaps_amountOut_converted")).alias('swaps_amountIn_amountOut_ratio'),
    (pl.col("swaps_amountOut_converted") / pl.col("swaps_amountIn_converted")).alias('swaps_amountOut_amountIn_ratio'),
])

# %%
trades_swaps_converted_trunc_pl = trades_swaps_converted_trunc_pl[
    'trades_timestamp',
    'swaps_blockNumber',
    'trades_txHash',
    'trades_feeAmount',
    'trades_sellToken_id',
    'trades_buyToken_id',
    'trades_sellAmount_converted',
    'trades_buyAmount_converted',
    'name',
    'environment',
    'swaps_pool_id',
    'swaps_tokenIn_id',
    'swaps_tokenOut_id',
    'swaps_amountIn_converted',
    'swaps_amountOut_converted',
    'transaction_gas_fee_one_hop',
    'transaction_gas_fee_median',
    'trades_buy_sell_ratio',
    'trades_sell_buy_ratio',
    'swaps_amountIn_amountOut_ratio',
    'swaps_amountOut_amountIn_ratio',
    'prices_assetPair_id',
    'prices_price'
]

# %%
trades_swaps_converted_trunc_pl.shape
# Out:
# (867, 23)

# %%
trades_swaps_converted_trunc_pl.head(10)
# Out:
# shape: (10, 23)
# ┌────────────┬────────────┬────────────┬────────────┬─────┬────────────┬────────────┬────────────┬────────────┐
# │ trades_tim ┆ swaps_bloc ┆ trades_txH ┆ trades_fee ┆ ... ┆ swaps_amou ┆ swaps_amou ┆ prices_ass ┆ prices_pri │
# │ estamp     ┆ kNumber    ┆ ash        ┆ Amount     ┆     ┆ ntIn_amoun ┆ ntOut_amou ┆ etPair_id  ┆ ce         │
# │ ---        ┆ ---        ┆ ---        ┆ ---        ┆     ┆ tOut_ratio ┆ ntIn_ratio ┆ ---        ┆ ---        │
# │ i64        ┆ i64        ┆ str        ┆ i64        ┆     ┆ ---        ┆ ---        ┆ str        ┆ f64        │
# │            ┆            ┆            ┆            ┆     ┆ f64        ┆ f64        ┆            ┆            │
# ╞════════════╪════════════╪════════════╪════════════╪═════╪════════════╪════════════╪════════════╪════════════╡
# │ 1677891335 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1575.11232 │
# │            ┆            ┆            ┆            ┆     ┆            ┆            ┆            ┆ 8          │
# │ 1677887735 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1568.3677  │
# │ 1677884123 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1566.1532  │
# │ 1677880523 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1560.3     │
# │ ...        ┆ ...        ┆ ...        ┆ ...        ┆ ... ┆ ...        ┆ ...        ┆ ...        ┆ ...        │
# │ 1677876947 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1560.62    │
# │ 1677873347 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1566.6014  │
# │ 1677869807 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1561.98543 │
# │ 1677868871 ┆ null       ┆ null       ┆ null       ┆ ... ┆ null       ┆ null       ┆ ETH/USD    ┆ 1556.4     │
# └────────────┴────────────┴────────────┴────────────┴─────┴────────────┴────────────┴────────────┴────────────┘

# %% [markdown]
# ### Save Data to a local parquet file

# %%
# checkpoint, save to parquet
trades_swaps_converted_trunc_pl.write_parquet('data/cow_uni_chain_outer_pl.parquet')
